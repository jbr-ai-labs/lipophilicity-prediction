# %% [markdown]
# # Load model

# %%
import autograd.numpy as np
import autograd.numpy.random as npr
from autograd import grad

# Path to Neural Fingerprint scripts
import sys
sys.path
sys.path.append('../../../scripts/baselines/neuralfingerprints/utils')
sys.path.append('../../../scripts/baselines/neuralfingerprints')

from build_vanilla_net import build_morgan_deep_net, build_standard_net
from build_convnet import build_conv_deep_net, build_convnet_fingerprint_fun
from util import normalize_array, build_batched_grad
from optimizers import adam
from util import rmse
from sklearn.metrics import r2_score

from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import DrawingOptions
import matplotlib.pyplot as plt


from pathlib2 import Path
import time
import os
import json
import pickle
from argparse import ArgumentParser

from training_funcs import load_data
from mol_graph import degrees
from data_util import remove_duplicates

# %%
NUM_EXP = 200

# %%
FIGURE_PATH = '../../../data/raw/baselines/neuralfingerprint'

# %%
# path to datasets
DATASET_PATH = "../../../data/3_final_data/split_data"

# path to logs directory
EXPERIMENTS_DATA = "../../../data/raw/baselines/neuralfingerprint"

# logs path
LOG_PATH=os.path.join(EXPERIMENTS_DATA, "logs")

MODEL_PATH=os.path.join(EXPERIMENTS_DATA, "models")

# %%
path = os.path.join(LOG_PATH,'exp_'+str(NUM_EXP))
LOG_PATH = path

path = os.path.join(MODEL_PATH,'exp_'+str(NUM_EXP))
MODEL_PATH = path

# %%
class Args(object):
    def __init__(self, adict):
        self.__dict__.update(adict)

# %%
with open(os.path.join(LOG_PATH,str(NUM_EXP)+'_parameters.json'),'r') as f:
    args = Args(json.load(f))

# %%
# set data parameters
task_params = {'target_name' : 'logP',
           'data_file'   : args.data_file}

# load data
data = load_data(dataset_path=DATASET_PATH, prefix_name = task_params['data_file'], VALUE_COLUMN = task_params['target_name'])

train_inputs, train_targets = data['train']
val_inputs,   val_targets   = data['validation']
test_inputs,  test_targets  = data['test']

# set parameters of training    
params = {'fp_length': args.fp_length,
        'fp_depth': args.fp_depth,
        'init_scale': np.exp(args.init_scale),
        'learn_rate': np.exp(args.learn_rate),
        'l2_penalty': np.exp(args.l2_penalty),
        'l1_penalty': 0,
          'h1_size':args.h1_size,
        'conv_width':args.conv_width,
         'batch_size':100}
params['num_iters'] = args.num_epochs*len(train_inputs)/params['batch_size']

# %%
vanilla_net_params = dict(
    layer_sizes = [params['fp_length'], params['h1_size']],  # One hidden layer.
    normalize=True, L2_reg = params['l2_penalty'], L1_reg = params['l1_penalty'], nll_func = rmse)

# %%
conv_layer_sizes = [params['conv_width']] * params['fp_depth']
conv_arch_params = {'num_hidden_features' : conv_layer_sizes,
                    'fp_length' : params['fp_length'], 'normalize' : 1}
loss_fun, pred_fun, conv_parser = \
    build_conv_deep_net(conv_arch_params, vanilla_net_params, params['l2_penalty'])
num_weights = len(conv_parser)

# %%
best_model_name = filter(lambda x: x.startswith('model_best'), os.listdir(MODEL_PATH))

# %%
with open(os.path.join(MODEL_PATH, best_model_name[0])) as f:
    best_weights = pickle.load(f)

# %%
def parse_training_params(params):
    nn_train_params = {'num_epochs'  : args.num_epochs,
                       'batch_size'  : 100,
                       'param_scale' : params['init_scale']}

    vanilla_net_params = dict(
        layer_sizes = [params['fp_length'], params['h1_size']],  # One hidden layer.
        normalize=True, L2_reg = params['l2_penalty'], L1_reg = params['l1_penalty'], nll_func = rmse)
    return nn_train_params, vanilla_net_params

# %%
conv_arch_params
# Out:
# {'fp_length': 32, 'normalize': 1, 'num_hidden_features': [10, 10, 10]}

# %%
def draw_molecule_with_highlights(filename, smiles, highlight_atoms):
    drawoptions = DrawingOptions()
    drawoptions.selectColor = highlight_color
    drawoptions.elemDict = {}   # Don't color nodes based on their element.
    drawoptions.bgColor=None

    mol = Chem.MolFromSmiles(smiles)
    fig = Draw.MolToMPL(mol, highlightAtoms=highlight_atoms, size=figsize, options=drawoptions,fitImage=False)

    fig.gca().set_axis_off()
    fig.savefig(filename, bbox_inches='tight')
    plt.close(fig)


def construct_atom_neighbor_list(array_rep):
    atom_neighbour_list = []
    for degree in degrees:
        atom_neighbour_list += [list(neighbours) for neighbours in array_rep[('atom_neighbors', degree)]]
    return atom_neighbour_list


def plot(trained_weights, FIGURE_PATH = FIGURE_PATH):
    
    print "Loading data..."
    data = load_data(dataset_path=DATASET_PATH, prefix_name = task_params['data_file'], VALUE_COLUMN = task_params['target_name'])


    train_smiles, train_targets = data['train']
    val_inputs,   val_targets   = data['validation']
    test_inputs,  test_targets  = data['test']

    print "Convnet fingerprints with neural net"
    conv_arch_params['return_atom_activations'] = True
    output_layer_fun, parser, compute_atom_activations = \
       build_convnet_fingerprint_fun(**conv_arch_params)
    atom_activations, array_rep = compute_atom_activations(trained_weights, train_smiles)

    if not os.path.exists(os.path.join(FIGURE_PATH, 'figures','exp_'+str(NUM_EXP))): \
        os.makedirs(os.path.join(FIGURE_PATH, 'figures','exp_'+str(NUM_EXP)))

    parent_molecule_dict = {}
    for mol_ix, atom_ixs in enumerate(array_rep['atom_list']):
        for atom_ix in atom_ixs:
            parent_molecule_dict[atom_ix] = mol_ix

    atom_neighbor_list = construct_atom_neighbor_list(array_rep)

    def get_neighborhood_ixs(array_rep, cur_atom_ix, radius):
        # Recursive function to get indices of all atoms in a certain radius.
        if radius == 0:
            return set([cur_atom_ix])
        else:
            cur_set = set([cur_atom_ix])
            for n_ix in atom_neighbor_list[cur_atom_ix]:
                cur_set.update(get_neighborhood_ixs(array_rep, n_ix, radius-1))
            return cur_set

    # Recreate trained network.
    nn_train_params, vanilla_net_params = parse_training_params(params)
    conv_arch_params['return_atom_activations'] = False
    _, _, combined_parser = \
        build_conv_deep_net(conv_arch_params, vanilla_net_params, params['l2_penalty'])

    net_loss_fun, net_pred_fun, net_parser = build_standard_net(**vanilla_net_params)
    net_weights = combined_parser.get(trained_weights, 'net weights')
    last_layer_weights = net_parser.get(net_weights, ('weights', 0))

    active_molecules = {}
    
    for fp_ix in range(params['fp_length']):
        active_molecules[fp_ix] = []
        print "FP {0} has linear regression coefficient {1}".format(fp_ix, last_layer_weights[fp_ix][0])
        combined_list = []
        for radius in all_radii:
            fp_activations = atom_activations[radius][:, fp_ix]
            combined_list += [(fp_activation, atom_ix, radius) for atom_ix, fp_activation in enumerate(fp_activations)]

        unique_list = remove_duplicates(combined_list, key_lambda=lambda x: x[0])
        combined_list = sorted(unique_list, key=lambda x: -x[0])

        for fig_ix in range(num_figs_per_fp):
            # Find the most-activating atoms for this fingerprint index, across all molecules and depths.
            activation, most_active_atom_ix, cur_radius = combined_list[fig_ix]
            most_activating_mol_ix = parent_molecule_dict[most_active_atom_ix]
            highlight_list_our_ixs = get_neighborhood_ixs(array_rep, most_active_atom_ix, cur_radius)
            highlight_list_rdkit = [array_rep['rdkit_ix'][our_ix] for our_ix in highlight_list_our_ixs]
            active_molecules[fp_ix].append(train_smiles[most_activating_mol_ix])
            print "radius:", cur_radius, "atom list:", highlight_list_rdkit, "activation", activation
            
            draw_molecule_with_highlights(\
                os.path.join(FIGURE_PATH, 'figures','exp_'+str(NUM_EXP),"fp_{0}_highlight_{1}.png".format(fp_ix, fig_ix)),
                train_smiles[most_activating_mol_ix],
                highlight_atoms=highlight_list_rdkit)
    return active_molecules

# %%
all_radii = range(params['fp_depth'] + 1)
num_figs_per_fp = 11
figsize = (100, 100)
highlight_color = (30.0/255.0, 100.0/255.0, 255.0/255.0)  # A nice light blue.

# %%
active_molecules = plot(best_weights)
# Out:
# Loading data...
# Convnet fingerprints with neural net
# FP 0 has linear regression coefficient 0.453562208734
# radius: 1 atom list: [29, 27, 28, 38] activation 0.9999522859506074
# radius: 1 atom list: [29, 26, 28, 32] activation 0.9998835148950064
# radius: 1 atom list: [5, 25, 26, 28] activation 0.9998727929470793
# radius: 1 atom list: [18, 19, 5, 17] activation 0.9998588159494763
# radius: 1 atom list: [13, 12, 28, 14] activation 0.9998534233729092
# radius: 1 atom list: [3, 5, 2, 1] activation 0.9998151420369541
# radius: 1 atom list: [5, 2, 3, 1] activation 0.9997868213298231
# radius: 1 atom list: [29, 23, 20, 24] activation 0.9997854524738728
# radius: 1 atom list: [25, 26, 29, 24] activation 0.9997255624776673
# radius: 1 atom list: [1, 3, 4, 22] activation 0.999534820511479
# radius: 1 atom list: [34, 12, 11, 13] activation 0.9995164872765586
# FP 1 has linear regression coefficient -0.981680251059
# radius: 0 atom list: [7] activation 0.9868468141781662
# radius: 1 atom list: [8, 9, 7] activation 0.9837082915780103
# radius: 0 atom list: [5] activation 0.9827186903759128
# radius: 0 atom list: [11] activation 0.9814551262666122
# radius: 1 atom list: [2, 3, 4] activation 0.978358185178418
# radius: 1 atom list: [4, 8, 9, 10] activation 0.9746885329476356
# radius: 1 atom list: [6, 4, 5] activation 0.9730325010484197
# radius: 1 atom list: [1, 2, 3, 5] activation 0.9681125568993275
# radius: 0 atom list: [4] activation 0.9680575362923756
# radius: 1 atom list: [8, 9, 10] activation 0.968046539873656
# radius: 1 atom list: [6, 3, 5] activation 0.967229043137776
# FP 2 has linear regression coefficient -0.896610931606
# radius: 0 atom list: [1] activation 0.3204153956255828
# radius: 1 atom list: [41, 40, 37, 39] activation 0.29088685660623964
# radius: 1 atom list: [45, 47, 46, 48] activation 0.2541827625680671
# radius: 1 atom list: [0, 1, 2] activation 0.24948908455796145
# radius: 1 atom list: [2, 0, 1] activation 0.24750733042052722
# radius: 1 atom list: [13, 12, 14, 15] activation 0.24276969072005575
# radius: 1 atom list: [1, 0, 2, 3, 6] activation 0.24092889094981432
# radius: 1 atom list: [2, 3, 4] activation 0.23446879015789865
# radius: 1 atom list: [45, 44, 47, 46] activation 0.230424667405868
# radius: 1 atom list: [1, 0, 2, 3, 4] activation 0.22560377732749887
# radius: 1 atom list: [3, 1, 0, 2] activation 0.22471273065988875
# FP 3 has linear regression coefficient -0.993729488528
# radius: 3 atom list: [3, 0, 14, 15, 17, 18, 19, 1, 13, 16, 2] activation 0.550446666695451
# radius: 3 atom list: [1, 0, 10, 2, 3, 4, 6, 7, 8, 9, 11, 12] activation 0.5409511514160534
# radius: 3 atom list: [12, 13, 15, 16, 7, 11, 4, 5, 14, 3, 6, 17] activation 0.5302037077548502
# radius: 3 atom list: [30, 31, 33, 34, 29, 40, 39, 37, 25, 27, 28, 32, 35, 38] activation 0.5152527716732169
# radius: 3 atom list: [28, 31, 20, 22, 25, 26, 18, 21, 23, 27, 32, 33, 29, 24] activation 0.49396667297624325
# radius: 3 atom list: [10, 14, 31, 32, 23, 30, 11, 34, 15, 17, 12, 13, 16, 8, 24, 9] activation 0.4844490761837045
# radius: 3 atom list: [4, 15, 19, 20, 8, 26, 32, 22, 5, 6, 7, 9, 18, 16, 17, 27] activation 0.4751294533164679
# radius: 3 atom list: [21, 20, 11, 12, 14, 19, 13, 17, 22, 23, 15, 16, 18] activation 0.47053198058251827
# radius: 3 atom list: [29, 8, 18, 7, 5, 6, 4, 21, 23, 28, 19, 20, 22, 26] activation 0.46540258510375043
# radius: 3 atom list: [19, 20, 22, 1, 3, 2, 5, 17, 21, 23, 18, 25, 26, 16] activation 0.44105031407176976
# radius: 3 atom list: [10, 11, 9, 8, 12, 6, 7, 13, 21, 22, 23, 24, 14] activation 0.43975833485082466
# FP 4 has linear regression coefficient 1.53254932334
# radius: 0 atom list: [16] activation 0.9978059915324268
# radius: 0 atom list: [10] activation 0.9973530059402727
# radius: 0 atom list: [6] activation 0.9707514001340467
# radius: 0 atom list: [21] activation 0.9082161431927731
# radius: 0 atom list: [20] activation 0.867250525412898
# radius: 0 atom list: [9] activation 0.8457193343255894
# radius: 0 atom list: [11] activation 0.8258924194345856
# radius: 0 atom list: [12] activation 0.8017755031724787
# radius: 0 atom list: [15] activation 0.6682925865624962
# radius: 0 atom list: [5] activation 0.35854184252106347
# radius: 0 atom list: [10] activation 0.2775177087039465
# FP 5 has linear regression coefficient -0.538747015963
# radius: 0 atom list: [1] activation 0.8921861672441566
# radius: 0 atom list: [13] activation 0.38945321072551964
# radius: 3 atom list: [13, 15, 14, 16, 11, 12] activation 0.31265553062223944
# radius: 3 atom list: [0, 2, 3, 5, 1, 4, 6] activation 0.3005364079599628
# radius: 3 atom list: [1, 0, 3, 4, 2] activation 0.2969423338415372
# radius: 3 atom list: [0, 3, 1, 4, 5, 2, 6] activation 0.27679866263926883
# radius: 3 atom list: [1, 4, 5, 0, 3, 6, 2] activation 0.25183926106551774
# radius: 3 atom list: [0, 6, 1, 5, 2, 3, 4, 7] activation 0.24921846225439356
# radius: 3 atom list: [4, 5, 1, 2, 0, 3] activation 0.24779550399827072
# radius: 3 atom list: [1, 5, 3, 4, 0, 2] activation 0.2456985964818468
# radius: 3 atom list: [9, 13, 14, 15, 11, 12] activation 0.24482750773472126
# FP 6 has linear regression coefficient -3.11033072578
# radius: 3 atom list: [2, 11, 6, 7, 9, 12, 15, 8, 10] activation 0.8548406853593192
# radius: 3 atom list: [5, 6, 9, 11, 17, 18, 10, 12, 8, 14, 16, 4] activation 0.8398966003069562
# radius: 3 atom list: [14, 16, 4, 5, 15, 13, 20, 3, 17, 19, 8, 18] activation 0.8280891155863462
# radius: 3 atom list: [5, 10, 12, 13, 15, 17, 18, 8, 14, 16, 2, 4] activation 0.828071931578588
# radius: 3 atom list: [7, 14, 21, 9, 19, 6, 15, 17, 16, 18, 20, 5] activation 0.8277803763934286
# radius: 3 atom list: [19, 15, 17, 8, 16, 18, 20, 3, 4, 5, 14, 21] activation 0.8258573678329828
# radius: 3 atom list: [6, 11, 14, 16, 2, 10, 15, 17, 9] activation 0.8180467248418108
# radius: 3 atom list: [5, 9, 12, 15, 17, 18, 10, 8, 14, 16, 4] activation 0.8087047355487224
# radius: 3 atom list: [3, 13, 15, 1, 5, 6, 4, 16, 17, 2, 12] activation 0.80856237072847
# radius: 3 atom list: [19, 16, 18, 20, 15, 17, 14, 7, 21, 5, 6, 9] activation 0.807311958946821
# radius: 3 atom list: [2, 1, 9, 25, 0, 22, 24, 26, 7, 10, 11, 23] activation 0.8073119589468195
# FP 7 has linear regression coefficient -3.04337057809
# radius: 2 atom list: [7, 11, 9, 8, 6, 12, 10] activation 0.9999606511957693
# radius: 2 atom list: [11, 12, 13, 10, 8, 14, 9] activation 0.9999596381384875
# radius: 2 atom list: [13, 11, 12, 8, 14, 10, 9] activation 0.9999365531011364
# radius: 2 atom list: [4, 5, 1, 0, 2, 3] activation 0.999929005735583
# radius: 2 atom list: [11, 6, 7, 8, 12, 9, 10] activation 0.9999279828991157
# radius: 2 atom list: [11, 9, 10, 12, 13, 14] activation 0.999925517491037
# radius: 2 atom list: [0, 2, 1, 5, 6, 3, 4] activation 0.9999184661289875
# radius: 2 atom list: [0, 2, 3, 4, 1] activation 0.9999158955547058
# radius: 2 atom list: [2, 1, 3, 4, 5, 0] activation 0.9999120828319054
# radius: 2 atom list: [14, 15, 11, 9, 12, 13, 10] activation 0.9998913918773973
# radius: 2 atom list: [7, 8, 9, 6, 4, 5, 10] activation 0.9998841891182
# FP 8 has linear regression coefficient 1.73521680037
# radius: 0 atom list: [17] activation 0.9514098193284165
# radius: 0 atom list: [12] activation 0.9377362263591993
# radius: 0 atom list: [4] activation 0.9326415421367871
# radius: 0 atom list: [12] activation 0.9029776812466126
# radius: 0 atom list: [0] activation 0.8986653024805624
# radius: 0 atom list: [3] activation 0.8462190050100556
# radius: 0 atom list: [0] activation 0.8392666364247483
# radius: 0 atom list: [1] activation 0.7513163514702851
# radius: 0 atom list: [13] activation 0.5956353939698312
# radius: 0 atom list: [5] activation 0.2938678908444104
# radius: 3 atom list: [1, 0, 3, 4, 2] activation 0.1598460381126561
# FP 9 has linear regression coefficient -0.179980015281
# radius: 3 atom list: [23, 1, 0, 3, 6, 4, 2, 5] activation 0.25439629152242704
# radius: 3 atom list: [0, 2, 5, 6, 8, 9, 11, 3, 4, 7, 12] activation 0.24050107749274993
# radius: 3 atom list: [8, 13, 9, 10, 3, 7, 11, 12, 5, 6] activation 0.2332285555584093
# radius: 3 atom list: [8, 13, 3, 6, 7, 9, 10, 12, 1, 4, 5] activation 0.232759413178815
# radius: 3 atom list: [2, 5, 0, 1, 3, 4, 6] activation 0.2316479358816682
# radius: 3 atom list: [9, 10, 3, 5, 8, 4, 6, 7] activation 0.22390254717882635
# radius: 3 atom list: [11, 16, 15, 3, 4, 7, 2, 5, 6, 9, 0, 8] activation 0.22071379504278335
# radius: 3 atom list: [11, 12, 4, 6, 9, 10, 13, 19, 7, 8, 18] activation 0.22049020022171295
# radius: 3 atom list: [13, 3, 4, 7, 12, 0, 2, 5, 6, 8, 9, 11] activation 0.21467703695984663
# radius: 3 atom list: [7, 8, 10, 12, 13, 15, 16, 17, 18, 9, 11] activation 0.2131560151058939
# radius: 3 atom list: [0, 2, 5, 1, 3, 6, 4, 9] activation 0.2125848586902771
# FP 10 has linear regression coefficient -1.31196266658
# radius: 0 atom list: [1] activation 0.4823450874801345
# radius: 2 atom list: [9, 10, 7, 8, 3, 5, 6, 4] activation 0.3852038857973974
# radius: 2 atom list: [19, 20, 23, 18, 21, 25, 22] activation 0.2919900084836131
# radius: 2 atom list: [20, 24, 21, 23, 25, 17, 22] activation 0.2861136679499768
# radius: 2 atom list: [7, 8, 6, 5, 4, 3, 10] activation 0.2758093018102202
# radius: 2 atom list: [9, 10, 2, 3, 8, 4, 7] activation 0.2642907346700319
# radius: 2 atom list: [8, 0, 1, 3, 15, 2, 4] activation 0.2627484186392583
# radius: 2 atom list: [18, 22, 1, 3, 2, 4, 0] activation 0.2609696387476127
# radius: 2 atom list: [4, 7, 5, 8, 2, 3, 6] activation 0.2604716828712819
# radius: 2 atom list: [0, 2, 1, 9, 4, 8, 10] activation 0.2601877787055547
# radius: 2 atom list: [11, 2, 0, 10, 13, 12, 1] activation 0.2548258072200431
# FP 11 has linear regression coefficient 0.62401866137
# radius: 0 atom list: [10] activation 0.9744767644367688
# radius: 0 atom list: [16] activation 0.9611104176271008
# radius: 0 atom list: [19] activation 0.9448303751526977
# radius: 0 atom list: [20] activation 0.8227805531873307
# radius: 0 atom list: [1] activation 0.7960369067201961
# radius: 0 atom list: [6] activation 0.7749232374686663
# radius: 0 atom list: [5] activation 0.23319334017224155
# radius: 0 atom list: [1] activation 0.04963277692305916
# radius: 0 atom list: [1] activation 0.032380196860152186
# radius: 0 atom list: [5] activation 0.019497648168957736
# radius: 0 atom list: [4] activation 0.018582164293317795
# FP 12 has linear regression coefficient 0.60399706171
# radius: 2 atom list: [13, 1, 11, 0, 2, 12, 3, 14] activation 0.9999714271848749
# radius: 2 atom list: [14, 15, 1, 18, 19, 13, 16, 17] activation 0.9999483562759872
# radius: 2 atom list: [11, 12, 3, 1, 9, 0, 2, 10] activation 0.9995218259702391
# radius: 2 atom list: [15, 0, 2, 1, 3, 4, 16, 17, 21, 5] activation 0.999368955844849
# radius: 2 atom list: [13, 12, 14, 15, 16, 11] activation 0.9993172308742739
# radius: 2 atom list: [11, 0, 2, 3, 4, 5, 1, 6, 7] activation 0.9990470278958496
# radius: 2 atom list: [8, 12, 13, 15, 16, 11, 14, 9, 10, 7] activation 0.9990397186750752
# radius: 2 atom list: [7, 3, 6, 12, 2, 4, 5, 9, 11, 1] activation 0.9989665086324886
# radius: 2 atom list: [1, 0, 4, 2, 6, 3, 5] activation 0.9989072873832441
# radius: 2 atom list: [6, 7, 11, 13, 3, 4, 8, 14, 5] activation 0.9989002996560903
# radius: 2 atom list: [6, 2, 3, 7, 10, 12, 4, 5, 11] activation 0.9988583042933894
# FP 13 has linear regression coefficient -1.90149234014
# radius: 1 atom list: [1, 0, 2, 3] activation 0.6518762809172539
# radius: 1 atom list: [20, 22, 21, 23] activation 0.6121757870300721
# radius: 1 atom list: [2, 7, 1, 0] activation 0.5908185144505643
# radius: 1 atom list: [17, 14, 16, 15] activation 0.5303589661918825
# radius: 1 atom list: [1, 2, 6, 0] activation 0.5234314928531378
# radius: 1 atom list: [13, 12, 14, 15] activation 0.4261680404339492
# radius: 1 atom list: [33, 36, 34, 35] activation 0.4237523199824726
# radius: 1 atom list: [3, 0, 2, 1] activation 0.38449097813019706
# radius: 1 atom list: [45, 44, 47, 46] activation 0.38185190406608244
# radius: 1 atom list: [14, 12, 13, 15] activation 0.376629800151247
# radius: 1 atom list: [3, 4, 1] activation 0.3756084709757708
# FP 14 has linear regression coefficient 0.259486784316
# radius: 1 atom list: [32, 1, 0, 2, 3] activation 0.9999818344262481
# radius: 1 atom list: [0, 2, 3, 1, 4] activation 0.9999527220818047
# radius: 1 atom list: [19, 20, 21, 27] activation 0.9999330611706233
# radius: 1 atom list: [20, 5, 6, 7] activation 0.9999002106793063
# radius: 1 atom list: [3, 4, 2, 10] activation 0.9998537886392936
# radius: 1 atom list: [3, 8, 0, 2, 1] activation 0.9998124587636527
# radius: 1 atom list: [13, 16, 12, 14, 15] activation 0.999809467244792
# radius: 1 atom list: [3, 8, 7, 9] activation 0.9997479768509984
# radius: 1 atom list: [1, 15, 17, 14, 16] activation 0.9996714827302632
# radius: 1 atom list: [3, 6, 2, 1, 4] activation 0.9995694661369307
# radius: 1 atom list: [9, 6, 7, 8, 5] activation 0.9995154408261909
# FP 15 has linear regression coefficient -2.08610582753
# radius: 3 atom list: [13, 14, 16, 18, 1, 2, 11, 3, 6, 7, 9, 12, 15, 17, 0, 4, 5, 8, 10] activation 1.0
# radius: 3 atom list: [4, 1, 5, 7, 9, 11, 10, 13, 15, 16, 2, 6, 3, 12, 14, 0] activation 0.9999999999999929
# radius: 3 atom list: [2, 6, 7, 9, 12, 11, 4, 13, 15, 0, 3, 5, 14, 16, 17, 1] activation 0.9999999999999858
# radius: 3 atom list: [0, 3, 5, 15, 17, 18, 1, 2, 6, 7, 13, 12, 4, 9, 14, 16] activation 0.9999999999999787
# radius: 3 atom list: [14, 0, 3, 5, 12, 7, 8, 9, 1, 2, 6, 10, 15, 4, 11, 13] activation 0.9999999999999645
# radius: 3 atom list: [0, 3, 5, 12, 14, 8, 9, 15, 2, 6, 10, 7, 1, 4, 11, 13] activation 0.999999999999936
# radius: 3 atom list: [14, 4, 6, 9, 12, 15, 18, 24, 27, 30, 33, 7, 8, 10, 11, 13, 16, 17, 28, 29, 31, 32, 34, 35] activation 0.9999999999998934
# radius: 3 atom list: [18, 7, 8, 14, 16, 3, 6, 5, 10, 12, 4, 9, 11, 13, 15, 17] activation 0.9999999999998437
# radius: 3 atom list: [4, 15, 17, 18, 21, 25, 1, 2, 5, 6, 7, 19, 20, 27, 26, 16, 28, 29] activation 0.9999999999996589
# radius: 3 atom list: [0, 5, 9, 12, 14, 3, 2, 1, 4, 7, 10, 13, 6, 8] activation 0.9999999999995737
# radius: 3 atom list: [7, 19, 3, 4, 6, 5, 0, 2, 24, 1, 20, 18] activation 0.9999999999995524
# FP 16 has linear regression coefficient 0.93616404658
# radius: 2 atom list: [1, 3, 7, 11, 13, 17, 2, 5, 6, 12] activation 0.999998982766011
# radius: 2 atom list: [5, 6, 9, 7, 8, 4] activation 0.9999982428132752
# radius: 2 atom list: [12, 13, 10, 9, 14, 11] activation 0.9999971331711872
# radius: 2 atom list: [16, 14, 15, 11, 12, 13] activation 0.9999969999662591
# radius: 2 atom list: [22, 27, 29, 34, 15, 18, 19, 20, 21, 28] activation 0.9999959002182968
# radius: 2 atom list: [6, 9, 10, 7, 8, 11] activation 0.9999951121520296
# radius: 2 atom list: [7, 4, 6, 8, 13, 12, 14, 18, 5] activation 0.9999934465657189
# radius: 2 atom list: [1, 3, 4, 11, 5, 0, 2, 10, 12, 17] activation 0.9999925683787788
# radius: 2 atom list: [14, 19, 15, 9, 5, 8, 1, 6, 7] activation 0.9999908532105042
# radius: 2 atom list: [1, 17, 19, 20, 21, 22] activation 0.9999765358097676
# radius: 2 atom list: [5, 3, 4, 8, 7, 16, 6] activation 0.9999732683999368
# FP 17 has linear regression coefficient 0.292682982479
# radius: 2 atom list: [18, 1, 2, 3, 6, 7, 9, 15, 17, 11, 8] activation 1.0
# radius: 2 atom list: [3, 1, 5, 7, 9, 11, 10, 13, 14, 12, 6] activation 0.9999999999999929
# radius: 2 atom list: [11, 14, 31, 28, 30, 33, 29, 32, 3, 5] activation 0.9999999999999858
# radius: 2 atom list: [2, 3, 15, 6, 22, 14, 16, 21, 4] activation 0.9999999999999787
# radius: 2 atom list: [11, 12, 14, 9, 10, 29, 32, 13, 33, 5] activation 0.9999999999999716
# radius: 2 atom list: [2, 11, 6, 7, 9, 12, 15, 8, 10] activation 0.9999999999999645
# radius: 3 atom list: [29, 6, 8, 10, 13, 9, 26, 28, 14, 7, 27] activation 0.9999999999999574
# radius: 2 atom list: [9, 5, 7, 4, 11, 3, 12, 14, 2, 6] activation 0.9999999999999503
# radius: 2 atom list: [16, 3, 1, 2, 4, 5, 14, 32, 6, 13, 17] activation 0.9999999999999432
# radius: 3 atom list: [38, 39, 0, 1, 3, 36, 40, 34, 37, 4, 35, 2] activation 0.999999999999936
# radius: 3 atom list: [8, 10, 0, 7, 9, 11, 1, 3, 2, 4, 6] activation 0.999999999999929
# FP 18 has linear regression coefficient 0.388638721279
# radius: 3 atom list: [23, 1, 0, 3, 6, 4, 2, 5] activation 0.4082408933951464
# radius: 3 atom list: [7, 8, 10, 12, 13, 15, 16, 17, 18, 9, 11] activation 0.39667047665642424
# radius: 3 atom list: [5, 14, 11, 13, 7, 12, 2, 4, 6, 10, 15, 1, 3] activation 0.3928763157704591
# radius: 3 atom list: [6, 9, 11, 1, 4, 7, 8, 10, 15, 0, 2, 16, 14] activation 0.38976544621341463
# radius: 3 atom list: [1, 3, 5, 11, 13, 2, 4, 6, 7, 10, 15, 12, 14] activation 0.3866074676097393
# radius: 3 atom list: [11, 12, 4, 6, 9, 10, 13, 19, 7, 8, 18] activation 0.3854487371940229
# radius: 3 atom list: [12, 9, 15, 5, 7, 8, 10, 6, 14, 4, 13] activation 0.3720930978764015
# radius: 3 atom list: [0, 2, 5, 1, 3, 6, 4, 9] activation 0.36656936711978894
# radius: 3 atom list: [15, 17, 1, 6, 8, 14, 16, 4, 5, 7, 9, 10, 13] activation 0.36224131087247274
# radius: 3 atom list: [2, 6, 10, 0, 1, 3, 5, 8, 4, 13, 14] activation 0.36145436421117333
# radius: 3 atom list: [7, 2, 3, 4, 5, 6, 8, 10, 11] activation 0.36141729695181496
# FP 19 has linear regression coefficient -0.213768626257
# radius: 3 atom list: [1, 3, 0, 2, 4, 6, 7, 5] activation 0.9999994433752363
# radius: 3 atom list: [9, 10, 1, 3, 5, 0, 2, 4, 6, 7] activation 0.9999718183451791
# radius: 3 atom list: [10, 3, 4, 6, 7, 9, 0, 12, 13, 1, 2, 8] activation 0.9999186549161708
# radius: 3 atom list: [22, 5, 4, 0, 2, 1, 3, 6, 23, 24] activation 0.9997210025860773
# radius: 3 atom list: [10, 11, 17, 20, 21, 4, 6, 7, 9, 18, 8, 19, 5] activation 0.9995435945501407
# radius: 3 atom list: [6, 10, 0, 2, 12, 13, 1, 3, 5, 11, 4] activation 0.9994167900809491
# radius: 3 atom list: [11, 5, 6, 1, 3, 0, 2, 4, 7] activation 0.9991635244903526
# radius: 3 atom list: [4, 5, 0, 2, 23, 24, 1, 3, 6, 22] activation 0.9989245655425563
# radius: 3 atom list: [1, 3, 6, 23, 22, 2, 0, 4, 5, 24] activation 0.9987942614731985
# radius: 3 atom list: [5, 13, 14, 6, 7, 1, 3, 4, 12, 0, 2] activation 0.9979473634289995
# radius: 3 atom list: [3, 4, 7, 8, 10, 11, 1, 2, 9, 0] activation 0.9979434602492
# FP 20 has linear regression coefficient -1.90227436204
# radius: 1 atom list: [14, 12, 22, 13] activation 0.9630967206012276
# radius: 1 atom list: [5, 14, 4, 3] activation 0.9469244560401212
# radius: 0 atom list: [11] activation 0.9423390925629537
# radius: 1 atom list: [1, 0, 7, 2] activation 0.9124192866249768
# radius: 1 atom list: [48, 49, 47, 50] activation 0.9048005508457472
# radius: 1 atom list: [15, 18, 19, 17] activation 0.9012009854880427
# radius: 1 atom list: [10, 11, 29, 9] activation 0.899281977463437
# radius: 1 atom list: [8, 6, 7, 9] activation 0.890865906714624
# radius: 1 atom list: [3, 4, 22, 5] activation 0.8792130584892138
# radius: 1 atom list: [1, 2, 0, 12] activation 0.8769274771470302
# radius: 1 atom list: [1, 3, 2, 15] activation 0.8714528328835941
# FP 21 has linear regression coefficient -0.233132697744
# radius: 2 atom list: [1, 2, 3, 15, 16, 0] activation 0.9999999867119344
# radius: 2 atom list: [0, 2, 1, 3, 4, 8, 9] activation 0.9999999861413756
# radius: 2 atom list: [6, 1, 0, 2, 3, 11, 4, 12, 5] activation 0.9999999782710136
# radius: 2 atom list: [0, 2, 1, 3, 4, 6, 7] activation 0.9999999634387045
# radius: 2 atom list: [0, 1, 3, 4, 16, 18, 19, 2] activation 0.9999999511683176
# radius: 2 atom list: [3, 5, 2, 1, 6, 7, 13, 14, 4] activation 0.9999999358224464
# radius: 2 atom list: [10, 4, 5, 7, 8, 2, 6, 11] activation 0.999999926146237
# radius: 2 atom list: [1, 2, 3, 4, 5, 0] activation 0.9999999231701645
# radius: 2 atom list: [17, 16, 4, 1, 3, 0, 2] activation 0.9999998607180512
# radius: 2 atom list: [5, 3, 4, 6, 7, 10, 11] activation 0.9999998594447376
# radius: 2 atom list: [15, 1, 5, 2, 0, 3] activation 0.9999998576659935
# FP 22 has linear regression coefficient -0.0120047405656
# radius: 0 atom list: [5] activation 0.9498210178922184
# radius: 0 atom list: [18] activation 0.9345116189621797
# radius: 0 atom list: [0] activation 0.21875014935955667
# radius: 0 atom list: [0] activation 0.1110395890082197
# radius: 0 atom list: [6] activation 0.09767145632005061
# radius: 0 atom list: [1] activation 0.06576138593667212
# radius: 3 atom list: [6, 7, 11, 23, 25, 26, 5, 8, 9, 10, 16, 19, 24] activation 0.05856927886675035
# radius: 3 atom list: [8, 12, 4, 5, 6, 7, 9, 10, 11, 13] activation 0.05802168247060832
# radius: 3 atom list: [7, 2, 3, 4, 5, 9, 8, 23, 6] activation 0.056145301657055495
# radius: 3 atom list: [7, 0, 5, 1, 2, 3, 6, 4] activation 0.05604571469239833
# radius: 3 atom list: [9, 2, 3, 4, 5, 8, 7, 6] activation 0.056001436791962254
# FP 23 has linear regression coefficient 0.608464220911
# radius: 2 atom list: [9, 10, 11, 7, 22, 5, 3, 6, 4] activation 0.9993052145104524
# radius: 2 atom list: [7, 4, 6, 17, 5, 9, 18, 19, 8] activation 0.9992248032407922
# radius: 2 atom list: [7, 8, 10, 11, 19, 3, 6, 12, 5] activation 0.9991985273426527
# radius: 2 atom list: [11, 3, 6, 12, 18, 7, 8, 5, 10] activation 0.9989765360246331
# radius: 2 atom list: [5, 7, 10, 6, 12, 13, 9, 1, 8] activation 0.9986846151842722
# radius: 2 atom list: [9, 2, 14, 1, 4, 5, 7, 8, 3] activation 0.9983090806228473
# radius: 2 atom list: [5, 7, 8, 9, 3, 4, 14, 1, 2] activation 0.998012258194497
# radius: 2 atom list: [7, 5, 10, 11, 3, 6, 12, 18, 8] activation 0.9975212842220795
# radius: 2 atom list: [14, 9, 13, 12, 30] activation 0.9963475415497344
# radius: 2 atom list: [4, 6, 15, 5, 2] activation 0.995959102199199
# radius: 2 atom list: [26, 23, 14, 25, 27] activation 0.995958721110159
# FP 24 has linear regression coefficient 0.965122972808
# radius: 1 atom list: [15, 2, 11, 9, 12] activation 0.9999999962594117
# radius: 1 atom list: [12, 15, 2, 5, 11] activation 0.9999999775299353
# radius: 1 atom list: [22, 23, 24, 7, 32] activation 0.9999999015932679
# radius: 1 atom list: [22, 8, 9, 7, 21] activation 0.9999998098342221
# radius: 1 atom list: [30, 12, 8, 13, 19] activation 0.9999997043257285
# radius: 1 atom list: [28, 10, 24, 5, 11] activation 0.9999996900120235
# radius: 1 atom list: [2, 8, 11, 12, 15] activation 0.9999992538792858
# radius: 1 atom list: [18, 8, 6, 9, 30] activation 0.9999991718043458
# radius: 1 atom list: [5, 9, 8, 10, 16] activation 0.9999991446640201
# radius: 1 atom list: [11, 29, 32, 33, 5] activation 0.9999985929621524
# radius: 1 atom list: [3, 1, 4, 7, 13] activation 0.9999984960712862
# FP 25 has linear regression coefficient 1.15697794143
# radius: 1 atom list: [13, 15, 12, 16, 14] activation 0.9991329917574029
# radius: 1 atom list: [15, 16, 17, 19, 18] activation 0.9942887189253442
# radius: 1 atom list: [0, 1, 11, 3, 2] activation 0.9931588910815163
# radius: 1 atom list: [1, 0, 16, 2] activation 0.9924590946354915
# radius: 1 atom list: [6, 4, 5] activation 0.9887962600584843
# radius: 1 atom list: [9, 10, 11] activation 0.9846188178122984
# radius: 1 atom list: [5, 14, 12, 13, 11] activation 0.9838289414565471
# radius: 1 atom list: [2, 1, 6, 0] activation 0.979038863072654
# radius: 1 atom list: [13, 10, 12, 11] activation 0.976037649581965
# radius: 1 atom list: [1, 0, 2, 18] activation 0.9649168456854839
# radius: 1 atom list: [6, 0, 1, 2] activation 0.9498856562371724
# FP 26 has linear regression coefficient 0.914062191968
# radius: 1 atom list: [1, 2, 0] activation 0.9434709382385185
# radius: 1 atom list: [10, 11] activation 0.9314643629280306
# radius: 1 atom list: [8, 9, 14, 7] activation 0.9285497056634114
# radius: 1 atom list: [2, 0, 1] activation 0.9256821209117467
# radius: 1 atom list: [9, 10, 14, 8] activation 0.9115582222129855
# radius: 1 atom list: [0, 2, 1] activation 0.9059577792784124
# radius: 1 atom list: [1, 2, 0] activation 0.8858836851663868
# radius: 1 atom list: [5, 7, 6, 13] activation 0.8817750860527245
# radius: 1 atom list: [0, 2, 1] activation 0.8766695319216323
# radius: 1 atom list: [0, 1, 2] activation 0.8757034833093792
# radius: 1 atom list: [3, 14, 2, 4] activation 0.8704885145971799
# FP 27 has linear regression coefficient -0.970541909161
# radius: 3 atom list: [20, 4, 8, 11, 6, 7, 9, 10, 12] activation 0.9999984808343314
# radius: 3 atom list: [9, 10, 12, 13, 15, 16, 7, 11, 4, 5, 14, 2, 3, 6, 17, 18, 8] activation 0.9999982626609941
# radius: 3 atom list: [11, 12, 14, 15, 18, 9, 13, 16, 17] activation 0.9999976847546016
# radius: 3 atom list: [19, 21, 22, 23, 17, 20, 24, 18] activation 0.99999758919283
# radius: 3 atom list: [12, 1, 2, 7, 10, 15, 8, 9, 5, 11, 13, 3, 6, 14] activation 0.9999967301369203
# radius: 3 atom list: [5, 7, 13, 1, 3, 6, 8, 10, 14, 16, 15, 4, 9] activation 0.9999960630753554
# radius: 3 atom list: [2, 4, 11, 12, 13, 19, 10, 14, 15, 17, 18, 20, 21, 23, 24, 25] activation 0.9999959093094299
# radius: 3 atom list: [0, 1, 2, 3, 8, 10, 5, 12, 13, 14, 6, 4] activation 0.999994695125681
# radius: 3 atom list: [19, 20, 6, 7, 24, 25, 21, 18, 23, 16, 17, 10, 22, 4, 5, 8, 9] activation 0.9999931595415404
# radius: 3 atom list: [8, 13, 14, 12, 9, 4, 5, 7, 1, 6] activation 0.9999888166437529
# radius: 3 atom list: [3, 6, 4, 5, 7, 8, 9, 10] activation 0.9999885925732749
# FP 28 has linear regression coefficient -2.40229140924
# radius: 0 atom list: [12] activation 0.9778667414519614
# radius: 0 atom list: [14] activation 0.9756980825047179
# radius: 1 atom list: [0, 1] activation 0.9370980023052982
# radius: 1 atom list: [0, 1] activation 0.9142912015507825
# radius: 0 atom list: [6] activation 0.9035338971563823
# radius: 1 atom list: [3, 4] activation 0.8893655572558186
# radius: 1 atom list: [0, 1] activation 0.8852593137892769
# radius: 1 atom list: [5, 4] activation 0.868058288836077
# radius: 1 atom list: [19, 17] activation 0.8630546031990239
# radius: 1 atom list: [8, 7] activation 0.8470402135406512
# radius: 2 atom list: [34, 33, 35, 29, 31, 32] activation 0.8383877106121066
# FP 29 has linear regression coefficient 1.44017089027
# radius: 1 atom list: [9, 10, 11, 12] activation 0.9999862628394984
# radius: 1 atom list: [12, 9, 11, 10] activation 0.9999581463926546
# radius: 1 atom list: [12, 11, 10, 13] activation 0.9999126826726243
# radius: 1 atom list: [5, 6, 4, 7] activation 0.9999056461583218
# radius: 1 atom list: [11, 10, 8, 9] activation 0.9998985449653098
# radius: 1 atom list: [11, 14, 13, 12] activation 0.9998550725152755
# radius: 1 atom list: [4, 3, 5, 2] activation 0.9997565141124651
# radius: 1 atom list: [7, 8, 6, 5] activation 0.9997467715999809
# radius: 1 atom list: [16, 13, 15, 17] activation 0.9997073285631336
# radius: 1 atom list: [7, 8, 9, 10] activation 0.9996847616651262
# radius: 1 atom list: [3, 2, 1, 4] activation 0.9995956456305064
# FP 30 has linear regression coefficient 0.445863035679
# radius: 1 atom list: [18, 20, 21, 19] activation 0.7638252071991916
# radius: 1 atom list: [2, 1, 0, 10] activation 0.7532225104335087
# radius: 1 atom list: [1, 3, 0, 2] activation 0.7030213514223675
# radius: 1 atom list: [5, 6, 4, 3] activation 0.6890587880691985
# radius: 1 atom list: [11, 13, 12, 8] activation 0.6408325302087152
# radius: 1 atom list: [10, 9, 7, 8] activation 0.6381712131706245
# radius: 1 atom list: [1, 15, 0, 2] activation 0.5988154029684275
# radius: 2 atom list: [1, 4, 3, 0, 2] activation 0.5668315746763891
# radius: 1 atom list: [4, 2, 6, 5] activation 0.5579633643678535
# radius: 1 atom list: [14, 13, 15, 16] activation 0.541547055870843
# radius: 1 atom list: [6, 7, 8, 5] activation 0.5411110143954189
# FP 31 has linear regression coefficient 0.63800854054
# radius: 3 atom list: [9, 11, 15, 12, 8, 10, 13, 14] activation 0.999730079165974
# radius: 3 atom list: [10, 6, 7, 8, 9, 4, 5, 11] activation 0.9996864312932043
# radius: 3 atom list: [13, 2, 9, 12, 15, 10, 11, 14] activation 0.9996454127950404
# radius: 3 atom list: [1, 4, 0, 2, 3, 6, 7] activation 0.9995312689524929
# radius: 3 atom list: [2, 3, 16, 14, 1, 4, 0, 15] activation 0.9994631785389184
# radius: 3 atom list: [1, 2, 3, 4, 5, 6, 0] activation 0.9993277279587052
# radius: 3 atom list: [2, 3, 4, 7, 0, 6, 1, 5] activation 0.9992849877709143
# radius: 3 atom list: [6, 7, 10, 9, 5, 8, 11, 12] activation 0.9992799942290552
# radius: 3 atom list: [9, 15, 18, 10, 16, 14, 17, 19, 8] activation 0.9992563865435794
# radius: 3 atom list: [17, 18, 19, 2, 16, 14, 1, 3, 5, 15, 0, 4] activation 0.999093881372539
# radius: 3 atom list: [8, 1, 6, 7, 9, 5, 10, 14] activation 0.9990900825634977

# %% [markdown]
# # Get predictions for active molecules

# %%
active_molecules
# Out:
# {0: ['COCCOCCOC(=O)C(Cc1ccc(OC(=O)N(C)C)cc1)NC(=O)C1N(S(=O)(=O)c2cnn(C)c2)CSC1(C)C',
#   'CCCCCCCCOC(=O)n1cnc(CC(NC(=O)c2ccc(O)[nH]2)C(O)N2CCCC2C(N)=O)c1',
#   'CCCC1CC(C(=O)NC(C(C)O)C2OC(SCC)C(O)C(O)C2O)N(CC)C1',
#   'CCC1C2CC3C4N(C)c5ccccc5C4(CCN3C1O)C2O',
#   'COc1cc2c(cc1OC)C13CCN4CC5CCOC6CC(=O)N2C1C6C5CC43',
#   'CCN(CC)S(=O)(=O)c1ccc(/C=C/C(=O)NC2CCCCC2)cc1',
#   'CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1',
#   'O=C(CN1C(=O)c2ccccc2S1(=O)=O)Nc1ccc(S(=O)(=O)N2CCCCCC2)cc1',
#   'COc1cccc2c(O)c3c(O)c4c(c(O)c3c(O)c12)=C(OC1CC(N(CC#N)CC(=O)O)C(O)C(C)O1)CC(O)(C(C)=O)C=4',
#   'CC(C)N(CCC(C(N)=O)(c1ccccc1)c1ccccn1)C(C)C',
#   'c1cnc2c(c1)[nH]c(=NCCCN1CCN(CCCN=c3[nH]c4cccnc4n4cccc34)CC1)c1cccn12'],
#  1: ['CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1',
#   'O=[N+]([O-])c1cccc(SSc2cccc([N+](=O)[O-])c2)c1',
#   'N#Cc1c(N)sc2ccccc12',
#   'CCOP(=S)(CC)Oc1cc(Cl)c(Cl)cc1Cl',
#   'S=C(SSSSC(=S)N1CCCCC1)N1CCCCC1',
#   'CCS(=O)c1sc(Cl)cc1C#N',
#   'CN(C)C(CSS(=O)(=O)c1ccccc1)CSS(=O)(=O)c1ccccc1',
#   'Cc1c(C#N)sc(S(C)=O)c1-c1ccc(Cl)cc1',
#   'CCOP(=S)(CC)Oc1cc(Cl)c(Cl)cc1Cl',
#   'CCOc1ccccc1OS(=O)(=O)NC(=O)N=c1nc(OC)cc(OC)[nH]1',
#   'CN(C)C(=S)SSC(=S)N(C)C'],
#  2: ['NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'CO[C@H]1/C=C\\O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(c5c(c4c3C2=O)=NC2(CCN(CC(C)C)CC2)N=5)NC(=O)C(C)=CC=CC(C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C',
#   'CCC1OC(=O)CC(O)C(C)C(OC2OC(C)C(OC3CC(C)(O)C(O)C(C)O3)C(N(C)C)C2O)C(CC=O)CC(C)C(=O)C=CC(C)=CC1COC1OC(C)C(O)C(OC)C1OC',
#   'CC=C(C)C(=O)OC1CC(OC(C)=O)C2(C(=O)OC)COC3C2C12COC(O)(C(=O)OC)C2C(C)(C12OC1(C)C1CC2OC2OC=CC21O)C3O',
#   'COC(=O)NC1=NC(c2ccccc2Br)CN1',
#   'C=CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O',
#   'CC1(C)C2CCC1(C)C(O)C2',
#   'C=CC=CC',
#   'COc1cc2cc(c1Cl)N(C)C(=O)CC(OC(=O)C(C)N(C)C(C)=O)C1(C)OC1C(C)C1CC(O)(NC(=O)O1)C(OC)C=CC=C(C)C2',
#   'CC(C)(C)C',
#   'CC(C)C#N'],
#  3: ['CN(CCCn1ccnc1C=NO)S(=O)(=O)C(F)(F)F',
#   'O=P1(NCCCl)OCCCN1CCCl',
#   'Cc1ccc(N(SC(F)(Cl)Cl)S(=O)(=O)N(C)C)cc1',
#   'COCCOCCOC(=O)C(Cc1ccc(OC(=O)N(C)C)cc1)NC(=O)C1N(S(=O)(=O)c2cnn(C)c2)CSC1(C)C',
#   'CCOC(=O)c1c(C)[nH]c(C)c1C(=O)COC(=O)c1ccc(F)c(S(=O)(=O)N2CCOCC2)c1',
#   'CCN1C(=O)c2cccc3c(S(=O)(=O)N(C(=O)c4cccnc4)c4ccc(OC)cc4)ccc1c23',
#   'COc1ccc(N(C(=O)C2CCCCC2)S(=O)(=O)c2ccc3c4c(cccc24)C(=O)N3C)cc1',
#   'Cc1ccc(OCCC(=O)N2CCN(S(=O)(=O)c3cccs3)CC2)cc1',
#   'COc1ccc(N(CC(=O)N[C@@H]2CCS(=O)(=O)C2)S(=O)(=O)c2ccc(C)c(Cl)c2)cc1',
#   'COc1ccc(C(=O)Nc2cccc(F)c2)cc1S(=O)(=O)N1CCOCC1',
#   'CCOC(=O)C1CCN(S(=O)(=O)c2nc3nc(C)cc(C)n3n2)CC1'],
#  4: ['COC(=O)c1[nH]c(=NCC(=O)CO)cnc1[NH+]([O-])O',
#   'CCOC(=O)C=NC(=O)C=[NH+][NH-]',
#   'NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'CC(C)CC(NC(=O)C(CC(C)C)NC(=O)C1CCC[NH2+]1)C(=O)[O-]',
#   'CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1',
#   'CCOC(=O)C=NC(=O)C=[NH+][NH-]',
#   'Nc1ccc(S(=O)(=O)N=c2cc[nH]cn2)cc1',
#   'N=c1[nH]cnc2c1ncn2C1OC2CO[PH](=O)(=O)OC1C2O',
#   'c1ccc(OP2OCCO2)cc1',
#   'COc1cc(Cc2c[nH]c(=N)[nH]c2=N)cc(OC)c1CO'],
#  5: ['COC(=O)NC1=NC(c2ccccc2Br)CN1',
#   'CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1',
#   'Cc1cccc(C)c1NC(=O)CCCC(C)N',
#   'CC(O)C(C)(C)C',
#   'CCC(C)N',
#   'C=CC(N)CCC(=O)O',
#   'CCC(C)N=C=S',
#   'CC1CCCC(C)N1',
#   'CCCC(C)O',
#   'CC(N)CCc1ccccc1',
#   'Cc1cccc(C)c1NC(=O)CCC(C)N'],
#  6: ['ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl',
#   'ClC1=C(Cl)C2C(C1Cl)C1(Cl)C(Cl)C(Cl)C2(Cl)C1(Cl)Cl',
#   'CC1CC2C3CC(F)=C4CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C1(O)C(=O)COC(=O)C(C)(C)C',
#   'ClC1=C(Cl)C2C(C1Cl)C1(Cl)C(Cl)C(Cl)C2(Cl)C1(Cl)Cl',
#   'CC1(O)CCC2C3CCC4CC(=O)CCC4(C)C3(F)C(O)CC21C',
#   'CC1CC2C3CC(F)=C4CC(=O)C(Cl)=CC4(C)C3(Cl)C(O)CC2(C)C1(O)C(=O)COC(=O)C(C)(C)C',
#   'ClCC1(C(Cl)Cl)C2C(Cl)CC1(C(Cl)Cl)C(Cl)C2Cl',
#   'ClC1=C(Cl)C2C(C1Cl)C1(Cl)C(Cl)C(Cl)C2(Cl)C1(Cl)Cl',
#   'ClC1=CC2(Cl)C3C(Cl)C(Cl)C(Cl)C3C1(Cl)C2(Cl)Cl',
#   'CC1(O)CCC2C3CC=C4CC(=O)CCC4(C)C3(F)C(O)CC21C',
#   'CC12CCC(=O)C=C1CCC1C3CCC(O)(C(=O)CO)C3(C)CC(O)C12F'],
#  7: ['CN(C)C(=O)n1nc(C(C)(C)C)nc1SCC(=O)O',
#   'CC(C)Oc1cc(-n2nc(C(C)(C)C)oc2=O)c(Cl)cc1Cl',
#   'CN1CC(O)N(c2nnc(C(C)(C)C)s2)C1=O',
#   'CC(C)(C)OCCO',
#   'CNC(=O)ON=C1CSC(C)(C)S1',
#   'CCOP(=S)(OCC)SCSC(C)(C)C',
#   'CC1(C)OCCO1',
#   'CC(C)(C)C',
#   'COC(C)(C)C',
#   'C[C@@H]1CCC2[C@](C)(CC[C@@H]3OC(C)(C)OC[C@@]23C)[C@@]12CCC1(COC(=O)C1)O2',
#   'CSc1nnc(C(C)(C)C)c(=O)n1N'],
#  8: ['NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'O=C(c1ccc(Cl)cc1)c1cc(F)ccc1O',
#   'NC(=O)Cn1ccnc1[N+](=O)[O-]',
#   'CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1',
#   'N#Cc1c(N)sc2ccccc12',
#   'CCOP(=S)(CC)Oc1cc(Cl)c(Cl)cc1Cl',
#   'NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'C[N+](C)(CCCc1ccccc1)CCCS(=O)(=O)[O-]',
#   'CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1',
#   'c1ccc(OP2OCCO2)cc1',
#   'CCC(C)N'],
#  9: ['C[C@H]1C[C@H](C)CN(C(=O)CSc2nnc(-c3ccccc3)n2C)C1',
#   'c1ccc2c(c1)Cc1ccccc1-2',
#   'CCOC(=O)c1c(CC(C)C)csc1N=Cc1c(C)[nH]n(-c2ccccc2)c1=O',
#   'Nc1ccc2c(c1)Cc1ccccc1-2',
#   'C1=CC2CCC1C2',
#   'CCC1(C2=CC3CCC(C2)C3)C(=O)NC(=O)NC1=O',
#   'c1ccc2c(c1)Cc1c-2ccc2ccccc12',
#   'CC(=O)Nc1ccc2c(c1)Cc1cc([N+](=O)[O-])ccc1-2',
#   'c1ccc2c(c1)Cc1ccccc1C2',
#   'O=C(OCC(=O)N1CCC(Cc2ccccc2)CC1)C1CCCCC1',
#   'CC1CC(C)CN(N=O)C1'],
#  10: ['NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'CC1(C)C(C=C(Cl)C(F)(F)F)C1C(=O)OC(C#N)c1cccc(Oc2ccccc2)c1',
#   'CC(CCC(=O)NCC(=O)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)C3CC(O)C12C',
#   'C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C@@]21C)[C@@]1(C)CC[C@@H](O)CC1C[C@H]3O',
#   'CC(=O)OC1CC(C)CCC1C(C)C',
#   'CCC1(C2=CC3CCC(C2)C3)C(=O)NC(=O)NC1=O',
#   'CC1CC2CC=CCC2(N)c2ccccc21',
#   'C[C@H]1C[C@H](NC(=S)NCc2csc3ccccc23)CC(C)(C)C1',
#   'CCC1(C(C)CC(C)O)C(=O)NC(=O)NC1=O',
#   'CC1CCC(C(C)C)C(=O)C1',
#   'CC1=C(C(=O)O)C(C(=O)O)CC(C)C1'],
#  11: ['NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'CCCn1c2ccccc2c2nnc(SCC(=O)N[C@H](C)c3ccccc3)nc21',
#   'N#Cc1[nH]n(-c2c(Cl)cc(C(F)(F)F)cc2Cl)c(=N)c1S(=O)C(F)(F)F',
#   'OB(O)c1ccccc1',
#   'CN(C)C(=S)S[Fe](SC(=S)N(C)C)SC(=S)N(C)C',
#   'c1ccc(OP2OCCO2)cc1',
#   'CC#CC#CC#Cc1ccccc1',
#   'FS(F)(F)(F)(F)c1ccccc1',
#   'NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'NC(=O)Cn1ccnc1[N+](=O)[O-]'],
#  12: ['O=S(=O)(Nc1cccc(F)c1)C(F)(F)F',
#   'CN(CCCn1ccnc1C=NO)S(=O)(=O)C(F)(F)F',
#   'O=S(=O)(c1ccccc1)C(F)(F)F',
#   'CC(=O)N(c1ccc(N2CCOCC2)nn1)n1c(C)ccc1C',
#   'CC(=O)C(C#N)=NNc1ccc(SC(F)(F)F)cc1',
#   'FS(F)(F)(F)(F)c1ccccc1',
#   'CCOCCOCCOP(=S)(N1CC1)N1CC1',
#   'CCC(=O)n1c(=O)[nH]cc(F)c1=O',
#   'O=C(C(F)(F)F)C(F)(F)F',
#   'CCCCOn1c(=O)[nH]c(C)c(Br)c1=O',
#   'CCCOn1c(=O)cc(C)[nH]c1=O'],
#  13: ['CC(C)CC(N)C(=O)NC(CC(C)C)C(=O)NC(CC(C)C)C(=O)NC(C(=O)O)C(C)C',
#   'CCC[C@@H](C)NC(=O)COc1ncnc2sc3c(c12)CC[C@@H](C)C3',
#   'CC1CCC(=O)CC1',
#   'COc1ccc2cc(C(C)C(=O)OCC=C(C)CCC=C(C)C)ccc2c1',
#   'CC(CC(=O)O)CC(=O)c1ccc(-c2ccccc2)cc1',
#   'C=CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O',
#   'CCCCCc1cc(CCCCn2cc(O)c3ccccc3c2=O)c2c(c1)OC(C)(C)C1CC=C(C)CC21',
#   'CC(C)=CC=C(C)C',
#   'COc1cc2cc(c1Cl)N(C)C(=O)CC(OC(=O)C(C)N(C)C(C)=O)C1(C)OC1C(C)C1CC(O)(NC(=O)O1)C(OC)C=CC=C(C)C2',
#   'CC(=O)OC1(C(C)=O)CCC2C3CC(C)=C4CC(=O)C=CC4(C)C3(F)C(O)CC21C',
#   'CC(C)CC(N)C(=O)NC(CC(C)C)C(=O)NC(CC(C)C)C(=O)NC(C(=O)O)C(C)C'],
#  14: ['CC1(C)OC2CC3C4CC(F)=C5CC(=O)C(Cl)=CC5(C)C4(F)C(O)CC3(C)C2(C(=O)CO)O1',
#   'CS(=O)(=O)ON1C(=O)c2ccc(N)cc2C1=O',
#   'COC(=O)C1=C(C)N=C(C)C(C(=O)OCCN2CCN(C(c3ccccc3)c3ccccc3)CC2)C1c1cccc([N+](=O)[O-])c1',
#   'COc1ccc(C(C(=O)Nc2ccc3c(c2)OCCO3)N(C)C(=O)Cc2c[nH]c3ccccc23)cc1',
#   'S=C=NC(c1ccccc1)c1ccccc1',
#   'O=S1(=O)OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl',
#   'CCCCCCCCCCCCOS(=O)(=O)O[Na]',
#   'CN(C)C(N(C)C)=S(I)c1cc(Cl)cc(Cl)c1',
#   'CC1(C)N=C(N=c2[nH]cc([N+](=O)[O-])s2)OC1(C)C',
#   'COC(C)(OC)c1ccc(C(O)(Cn2ccnc2)c2ccc(-c3ccncc3)cc2)cc1',
#   'CCCCCOP(C)(=O)OCCCCC'],
#  15: ['ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl',
#   'ClC1=CC2(Cl)C3CC(Cl)C(Cl)C3C1(Cl)C2(Cl)Cl',
#   'ClC1=C(Cl)C2(Cl)C3C(Cl)C(Cl)CC3C1(Cl)C2(Cl)Cl',
#   'ClC1=C(Cl)C2(Cl)C3C(Cl)C(Cl)(Cl)CC3C1(Cl)C2(Cl)Cl',
#   'ClC1=C(Cl)C2(Cl)C3CC=CC3C1(Cl)C2(Cl)Cl',
#   'ClC1=C(Cl)C2(Cl)C3CC=CC3C1(Cl)C2(Cl)Cl',
#   'FC(F)(F)C1(F)C(F)(F)C(F)(F)C(F)(N2C(F)(F)C(F)(F)C(F)(F)C(F)(F)C2(F)F)C(F)(F)C1(F)F',
#   'O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl',
#   'C=C1C(=O)OC2C1C(OC(=O)C(C)=CC)CC1(CO1)C1C(OC(C)=O)C=C(C)C21O',
#   'CC(C)C1(C(C)C)C(=O)NC(=O)NC1=O',
#   'CC(C)(C)c1cc(C2C(=O)c3ccccc3C2=O)cc(C(C)(C)C)c1'],
#  16: ['N#CC(C#N)=C(c1ccccc1)c1ccccc1',
#   'O=[N+]([O-])c1cc(C(F)F)c(N=c2[nH]cc(C(F)(F)F)cc2Cl)c([N+](=O)[O-])c1',
#   'C=CCNC(=O)CSc1nc(C(F)F)cc(-c2cn(C)nc2C)c1C#N',
#   'Cc1c(CN(C)C(=O)C(C)n2nc(C(F)F)c(Br)c2C)cnn1C',
#   'CC(=O)c1cccc(-n2c(O)c3c(c2O)[C@@H]2C=C[C@H]3C2=C(c2ccc(C)cc2)c2ccc(C)cc2)c1',
#   'Cc1ccc(-c2cc(C(F)F)n3ncc(C(=O)N4CCSCC4)c3n2)cc1',
#   'CN(C)CCOC(c1ccccc1)c1ccccc1',
#   'ClC(Cl)=C(c1ccc(Cl)cc1)c1ccc(Cl)cc1',
#   'Cc1ccccc1C(OCCN(C)C)c1ccccc1',
#   'Cc1nn(-c2cc(NS(C)(=O)=O)c(Cl)cc2Cl)c(=O)n1C(F)F',
#   'CC#CCOC(C)c1ccc(OC)c(OC)c1'],
#  17: ['ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl',
#   'ClC1=CC2(Cl)C3CC(Cl)C(Cl)C3C1(Cl)C2(Cl)Cl',
#   'CCOC1OC2OC3(C)CCC4C(C)C(OC5OC(C(=O)O)C(O)C(O)C5O)CC(C1C)C24OO3',
#   'CCC1C2CC3C4N(C)c5ccccc5C4(CCN3C1O)C2O',
#   'CCOC1OC2OC3(C)CCC4C(C)C(OC5OC(C(=O)O)C(O)C(O)C5O)CC(C1C)C24OO3',
#   'ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl',
#   'O=[N+]([O-])c1ccc(OC2OC(CO)C(OC3OC(CO)C(O)C(O)C3O)C(O)C2O)cc1',
#   'ClC1=CC2(Cl)C3CC(Cl)C(Cl)C3C1(Cl)C2(Cl)Cl',
#   'C=C1C(C)C2C(Cc3ccccc3)NC(=O)C23OC(=O)CCC(=O)CCCC(C)CC=CC3C1O',
#   'CCC1OC(=O)CC(O)C(C)C(OC2OC(C)CC(N(C)C)C2O)C(CC=O)CC(C)C(=O)C=CC2(C)OC2C1C',
#   'COC1CC(Cl)C(Cl)C(Cl)C1Cl'],
#  18: ['C[C@H]1C[C@H](C)CN(C(=O)CSc2nnc(-c3ccccc3)n2C)C1',
#   'O=C(OCC(=O)N1CCC(Cc2ccccc2)CC1)C1CCCCC1',
#   'Cc1cc(Cc2cc(Cl)ccc2Cl)c(Cl)cc1Cl',
#   'Oc1ccc(Cl)cc1Cc1cc(Cl)ccc1O',
#   'Cc1cc(Cc2ccc(Cl)cc2Cl)c(Cl)cc1Cl',
#   'CC(=O)Nc1ccc2c(c1)Cc1cc([N+](=O)[O-])ccc1-2',
#   'CC(=O)NC(CC12CC3CC(CC(C3)C1)C2)C(N)=O',
#   'CC1CC(C)CN(N=O)C1',
#   'Cc1c(Cl)ccc(Cc2ccc(Cl)cc2Cl)c1Cl',
#   'CCC12CC3CC(N)(C1)CC(CC)(C3)C2',
#   'S=C=NCCCc1ccccc1'],
#  19: ['CC(C)C(=O)C(C)C',
#   'CC(C)C(=O)c1ccccc1',
#   'O=S(c1ccccc1)c1ccccc1',
#   'CC(C)N(C=Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1)C(C)C',
#   'COC(=O)c1cc(S(=O)c2ccc(C(F)(F)F)cc2Cl)ccc1[N+](=O)[O-]',
#   'CC(C)N(Cc1cccnc1)C(C)C',
#   'CC(C)C(N)Cc1ccccc1',
#   'CC(C)N(CCC(C(N)=O)c1ccc(-c2ccccc2)cc1)C(C)C',
#   'CC(C)N(CCC(C(N)=O)(c1ccccc1)c1ccccn1)C(C)C',
#   'CC(C)N(C(=O)SCC(Cl)=CCl)C(C)C',
#   'O=C(c1ccc(F)cc1)C1CC1'],
#  20: ['CCOC(=O)C(C)Oc1ccc(Oc2nc3ccc(Cl)cc3o2)cc1',
#   'CC1(C)N=C(N=c2[nH]cc([N+](=O)[O-])s2)OC1(C)C',
#   'NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl',
#   'CCC1OC(=O)C(C)C(OC2CC(C)(OC)C(O)C(C)O2)C(C)C(OC2OC(C)CC(N(C)C)C2O)C(C)(O)CC(C)C(N)C(C)C2OC(=O)OC12C',
#   'C=C1CC23CC1(O)CCC2C12C=CC(O)C(C)(C(=O)O1)C2C3C(=O)O',
#   'COc1cccc(-c2[nH]nc3c2[C@@H](c2cc(OC)c(OC)cc2Br)C(C#N)C(=N)O3)c1',
#   'Cc1cc(C)c2oc(=O)sc2c1',
#   'C#CCOC1=Nc2cc(OC(=O)N3CCCC3)c(Cl)cc2OC1',
#   '[O-][n+]1onc(Cc2ccccc2)c1Cc1ccccc1',
#   'COc1nc(=NC(C)C)[nH]c(=NC(C)C)[nH]1'],
#  21: ['Cc1ccc(C(=O)N(N)c2ccccc2)cc1',
#   'C=Cc1ccc(CC)cc1',
#   'CC(C)(C)c1ccc(C(=O)O)cc1',
#   'CCc1ccccc1',
#   'c1cc2ccc3ccc4ccc5cccc6c(c1)c2c3c4c56',
#   'CCC(C)(C)c1ccc(CC(=O)O)cc1',
#   'CNc1cccc2ccccc12',
#   'Cc1ccsc1',
#   'C=Cc1ccc2c(O)c3ccccc3c(O)c2c1',
#   'CC(=O)C=Cc1ccc(Br)cc1',
#   'Cc1cccc(S(I)=C(N(C)C)N(C)C)c1'],
#  22: ['NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'Cl.NCCCCC(N)C(=O)NC(Cc1ccccc1)C(=O)O',
#   'C#CCOc1ccc(C2C3=C(CC(C)(C)CC3=O)OC3=C2C(=O)CC(C)(C)C3)cc1OCC',
#   'CC(=O)NC(CS)C(N)=O',
#   'C=CCc1cccc2c(=O)c(C)c(-c3ccccc3)oc12',
#   'CCOC(=O)N1CCC(=C2c3ccc(Cl)cc3CCc3cccnc32)CC1',
#   'CS(=O)(=O)CCOCn1ccnc1C=NO',
#   'COCCOCC1COC(c2ccc(Cl)cc2Cl)(n2cncn2)O1',
#   'CCSCS(=O)CC(C)NC(=O)C=Cc1c(C)[nH]c(=O)[nH]c1=O',
#   'CCCCSCS(=O)CC(C)NC(=O)C=Cc1c(C)[nH]c(=O)[nH]c1=O'],
#  23: ['CCCC[C@@]1(c2ccccc2)NC(=S)N(c2ccc(C)cc2)N1',
#   'NS(=O)(=O)c1cc(C2(O)NC(=O)c3ccccc32)ccc1Cl',
#   'O=C1NC(=O)C(c2ccccc2)(c2ccc(O)cc2)N1',
#   'O=C1NC(=O)C(c2ccccc2)(c2ccccc2)N1S(=O)(=O)c1ccccc1',
#   'CN1C(=O)CCC1(O)c1cccnc1',
#   'CCC1(c2ccccc2)C(=O)NC(=O)N1S(=O)(=O)c1ccccc1',
#   'CCC1(c2ccccc2)NC(=O)N(C)C1=O',
#   'O=C1NC(=O)C(c2ccccc2)(c2ccccc2)C(=O)N1',
#   'FC(F)(F)C1(F)C(F)(F)C(F)(F)C(F)(N2C(F)(F)C(F)(F)C(F)(F)C(F)(F)C2(F)F)C(F)(F)C1(F)F',
#   'ClC1=C(Cl)C2(Cl)C(Cl)(Cl)C3CC(Cl)C1C3C2(Cl)Cl',
#   'CCC(=O)OC1(C(=O)CCl)C(C)CC2C3CC=C4CC(=O)C=CC4(C)C3(F)C(=O)CC21C'],
#  24: ['ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl',
#   'ClC=C1C2CC(C(Cl)C2(Cl)Cl)C1(C(Cl)Cl)C(Cl)Cl',
#   'CC=C(C)C(=O)OC1CC(OC(C)=O)C2(C(=O)OC)COC3C2C12COC(O)(C(=O)OC)C2C(C)(C12OC1(C)C1CC2OC2OC=CC21O)C3O',
#   'CCCc1[nH]nc2c1[C@@]1(C(=O)N(CC(N)=O)c3ccccc31)C(C(=O)OC)C(=N)O2',
#   'Cc1cc(C)nc(OC(C(=O)O)C2(c3ccccc3)NCC(=O)N(C)c3ccccc32)n1',
#   'COc1cc2c(cc1OC)C13CCN4CC5CCOC6CC(=O)N2C1C6C5CC43',
#   'ClCC1(C(Cl)Cl)C2CC(Cl)(Cl)C1(C(Cl)Cl)C(Cl)C2Cl',
#   'CCc1cc2c3c(c1)[C@@]1(C(=O)N3C(C)(C)C=C2C)C2=C(CC(C)(C)CC2=O)OC(=N)C1C#N',
#   'ClC1=C(Cl)C2C(C1Cl)C1(Cl)C(Cl)C(Cl)C2(Cl)C1(Cl)Cl',
#   'CCOC1OC2OC3(C)CCC4C(C)C(OC5OC(C(=O)O)C(O)C(O)C5O)CC(C1C)C24OO3',
#   'CC(C)C1(C(C)C)C(=O)NC(=O)NC1=O'],
#  25: ['COc1cc(OC)[nH]c(=NC(=O)NS(=O)(=O)Nc2ccccc2C(=O)C2CC2)n1',
#   'CCCC(=NC(=O)C(Cc1ccccc1)NS(=O)(=O)N1CCOCC1)C(=O)NC(COC(F)(F)C(=O)NCCN1CCOCC1)CC1CCCCC1',
#   'O=S(=O)(Nc1ccc(Cl)cc1)C(F)F',
#   'Nc1ccc(S(=O)(=O)N=c2cc[nH]cn2)cc1',
#   'O=C(O)C=COc1ccccc1',
#   'CC(=O)Oc1ccc(CC=NC=O)cc1',
#   'Cc1ccc(N(SC(F)(Cl)Cl)S(=O)(=O)N(C)C)cc1',
#   'N=c1cc[nH]cc1',
#   'CC1=C(c2ccccc2)CCN(C)C1',
#   'CN1CCN=C(c2ccccc2)c2cc(Cl)ccc21',
#   'C=C1CCC2C(C1)c1c(OC)cc(CCC)cc1OC2(C)C'],
#  26: ['CCNP(=O)(OCC)ON=C(C#N)c1ccc(OC)cc1',
#   'C=CC(=O)NCCCN(CCO)CCO',
#   'OCC1OC(n2cnc3c2N=CNCC3O)CC1O',
#   'CCN=c1cc(-c2nc(=N)[nH][nH]2)cc[nH]1',
#   'CCOC(=O)CCn1nc2ccccc2n1',
#   'CC[N+](C)(C)[N-]C(=O)C(O)(c1ccccc1)c1ccccc1',
#   'CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1',
#   'O=[N+]([O-])c1c[nH]c(=NC2=NCCN2)s1',
#   'CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21',
#   'NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O',
#   'N=c1[nH]c(C=Cc2ccc([N+](=O)[O-])o2)no1'],
#  27: ['CC(C)N(C(=O)CSc1n[nH]c(=NCc2ccccc2)s1)C(C)C',
#   'Cc1ccc(N(SC(F)(Cl)Cl)S(=O)(=O)N(C)C)cc1',
#   'Cc1cc(Br)ccc1NC(=O)CSc1n[nH]c(=N)s1',
#   'O=C(Cn1cnnn1)NC1C(=O)N2C(C(=O)O)=C(CSc3nncs3)CSC12',
#   'ClCC1(CCl)C2CC(Cl)(Cl)C1(C(Cl)Cl)CC2(Cl)Cl',
#   'CN(C)C(=S)S[Fe](SC(=S)N(C)C)SC(=S)N(C)C',
#   'N#Cc1nc(N2CCCC2)nc(N(c2ccccc2)c2ccccc2)n1',
#   'c1nnn(C23CC4CC(CC(C4)C2)C3)n1',
#   'O=[N+]([O-])c1ccc(N(N=Cc2ccccc2)P(=O)(N2CC2)N2CC2)cc1',
#   'CC(C)(C)NSc1nc2ccccc2s1',
#   'c1ccc(CSc2nc[nH]n2)cc1'],
#  28: ['OCC1CC(F)C(n2cnc3c(I)ncnc32)O1',
#   'COC(=O)NC1=NC(c2ccccc2Br)CN1',
#   'FCCCc1ccccc1',
#   'BrCCc1ccccc1',
#   'CCCC(=O)OC1(C(=O)CO)CCC2C3CC=C4CC(=O)CCC4(C)C3C(O)CC21C',
#   'NC(=O)CI',
#   'ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl',
#   'OCC1CC(F)C(n2cnc3c(I)ncnc32)O1',
#   'COC1N(C2CC(F)C(CO)O2)C(=O)NC(=O)C1(C)Br',
#   'COP(=O)(OC)OC(Br)C(Cl)(Cl)Br',
#   'CCC1OC(=O)C(C)C(OC2CC(C)(OC)C(O)C(C)O2)C(C)C(OC2OC(C)C(O)C(N=[N+]=[N-])C2O)C(C)(O)CC(C)C(=O)C(C)C(O)C1(C)O'],
#  29: ['COc1ccc(NC(=O)N=C(N)N)cc1',
#   'Cc1ccc2c(c1)[n+]([O-])nc(N)[n+]2[O-]',
#   'Cc1cc2[nH]cccc2c2nc(=N)n(C)c12',
#   'CN(C)c1nc(=N)nc(N(C)C)[nH]1',
#   'CC(=O)c1cccc(N2C(N)=NC(N)=NC2(C)C)c1',
#   'CC(=O)c1cccc(N2C(N)=NC(N)=NC2(C)C)c1',
#   'CCN=C(N)N=C(N)Nc1ccc(Cl)cc1',
#   'Cc1cc(N=NC(=N)N)ccc1NNC(N)=S',
#   'CCCCN(CCCC)c1cc(N)[n+]([O-])c(=N)[nH]1',
#   'CCN=c1cc(-c2nc(=N)[nH][nH]2)cc[nH]1',
#   'CN=C(N)NC#N'],
#  30: ['CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNC(C)C3)c(F)c21',
#   'CC1COc2ccccc2N1C(=O)C(Cl)Cl',
#   'CC(C)N(C=Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1)C(C)C',
#   'OCC1CC(F)C(n2cnc3c(I)ncnc32)O1',
#   'COC(=O)c1cnc2n(c1=O)C(C)CCC2',
#   'CC12CCC(=O)C=C1C(F)CC1C2C(O)CC2(C)C1CCC2(O)C(=O)CO',
#   'CC1CN(C)C(N=c2[nH]cc([N+](=O)[O-])s2)=N1',
#   'CN(C)NC(=O)CCC(=O)O',
#   'C#CC1(O)C(F)CC2C3CCc4cc(O)ccc4C3CCC21C',
#   'CC(=O)Nc1ccc(OCC(O)CNC(C)C)cc1',
#   'COc1nc(=NC(C)C)[nH]c(=NC(C)C)[nH]1'],
#  31: ['COc1c2ccoc2cc2oc(=O)ccc12',
#   'O=C1CCC(c2ccc[n+]([O-])c2)N1',
#   'COc1c2occc2cc2ccc(=O)oc12',
#   '[O-][n+]1ccc(Cl)cc1',
#   'O=c1ccn(C2C=C(CO)C(O)C2O)c(=O)[nH]1',
#   '[O-][n+]1ccccc1',
#   'O=c1cccc(Cl)[nH]1',
#   'CCOC(O)c1c[nH]c(=O)cc1C(O)OCC',
#   'CC(C(=O)Nc1ccc2c(C(F)(F)F)cc(=O)oc2c1)n1nc(C(F)(F)F)c(Cl)c1C1CC1',
#   'O=c1[nH]c(=O)n(C2CC(O)C(CO)O2)cc1C(F)(F)F',
#   'Cc1ccccc1C(O)c1ccccc1']}

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error

# %%
SMILES_COLUMN = 'smiles'
VALUE_COLUMN = 'logP'
PRED_COLUMN = 'logP_pred'

# %%
DATA_PREDS_PATH = '../../../data/4_best_baselines_predictions/neuralfingerprint'

# %%
train_predictions = pd.read_csv(os.path.join(DATA_PREDS_PATH,'logp_wo_averaging_train_preds.csv'))
val_predictions = pd.read_csv(os.path.join(DATA_PREDS_PATH,'logp_wo_averaging_validation_preds.csv'))
test_predictions = pd.read_csv(os.path.join(DATA_PREDS_PATH,'logp_wo_averaging_test_preds.csv'))

# %%
predictions = pd.concat([train_predictions, val_predictions, test_predictions])

# %%
predictions.head()
# Out:
#                                            smiles  logP  logP_pred
# 0  NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 1              CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1  2.13   3.252617
# 2            C=CCc1cccc2c(=O)c(C)c(-c3ccccc3)oc12  4.67   4.890304
# 3                    COC(=O)NC1=NC(c2ccccc2Br)CN1  1.85   2.262368
# 4                                CC(=O)C=Cc1ccco1  1.35   0.984675

# %%
active_molecules_preds = {}
active_molecules_preds_RMSE = {}
for fp in active_molecules.keys():
    list_of_smiles = active_molecules[fp]
    smiles_preds = predictions[predictions[SMILES_COLUMN].isin(list_of_smiles)]
    active_molecules_preds[fp] = smiles_preds
    active_molecules_preds_RMSE[fp] = mean_squared_error(smiles_preds[VALUE_COLUMN],smiles_preds[PRED_COLUMN])**0.5
    print(smiles_preds)
# Out:
#                                                  smiles  logP  logP_pred
# 1                    CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1  2.13   3.252617
# 38    c1cnc2c(c1)[nH]c(=NCCCN1CCN(CCCN=c3[nH]c4cccnc...  5.05   4.284886
# 84     COc1cc2c(cc1OC)C13CCN4CC5CCOC6CC(=O)N2C1C6C5CC43  0.84   1.417909
# 85    CCCC1CC(C(=O)NC(C(C)O)C2OC(SCC)C(O)C(O)C2O)N(C...  1.91   0.522730
# 434   COCCOCCOC(=O)C(Cc1ccc(OC(=O)N(C)C)cc1)NC(=O)C1...  1.41   2.312944
# 469   COc1cccc2c(O)c3c(O)c4c(c(O)c3c(O)c12)=C(OC1CC(...  0.03   1.267873
# 568       CCN(CC)S(=O)(=O)c1ccc(/C=C/C(=O)NC2CCCCC2)cc1  4.34   4.153650
# 1011  CCCCCCCCOC(=O)n1cnc(CC(NC(=O)c2ccc(O)[nH]2)C(O...  1.82   1.552834
# 1116  O=C(CN1C(=O)c2ccccc2S1(=O)=O)Nc1ccc(S(=O)(=O)N...  4.73   3.830757
# 4592              CCC1C2CC3C4N(C)c5ccccc5C4(CCN3C1O)C2O  1.81   1.971308
# 5300         CC(C)N(CCC(C(N)=O)(c1ccccc1)c1ccccn1)C(C)C  2.58   3.318700
#                                                 smiles  logP  logP_pred
# 1                   CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1  2.13   3.252617
# 8                      CCOP(=S)(CC)Oc1cc(Cl)c(Cl)cc1Cl  5.23   5.254063
# 24                                 N#Cc1c(N)sc2ccccc12  2.17   1.787301
# 317                              CCS(=O)c1sc(Cl)cc1C#N  2.31   2.178018
# 726     CN(C)C(CSS(=O)(=O)c1ccccc1)CSS(=O)(=O)c1ccccc1  3.36   3.212206
# 879                 Cc1c(C#N)sc(S(C)=O)c1-c1ccc(Cl)cc1  3.80   3.494812
# 2559  CCOc1ccccc1OS(=O)(=O)NC(=O)N=c1nc(OC)cc(OC)[nH]1  2.89   1.815306
# 3260    O=[N+]([O-])c1cccc(SSc2cccc([N+](=O)[O-])c2)c1  4.06   3.547421
# 5199                            CN(C)C(=S)SSC(=S)N(C)C  1.73   1.194805
# 6534                    S=C(SSSSC(=S)N1CCCCC1)N1CCCCC1  2.80   4.507696
#                                                  smiles  logP  logP_pred
# 0        NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 3                          COC(=O)NC1=NC(c2ccccc2Br)CN1  1.85   2.262368
# 442                                             C=CC=CC  2.44   2.375023
# 925   CC=C(C)C(=O)OC1CC(OC(C)=O)C2(C(=O)OC)COC3C2C12...  1.09   0.144888
# 990                                           CC(C)(C)C  3.11   2.324060
# 1081  CCC1OC(=O)CC(O)C(C)C(OC2OC(C)C(OC3CC(C)(O)C(O)...  1.63   0.659592
# 1189                              CC1(C)C2CCC1(C)C(O)C2  3.24   2.959116
# 2072        C=CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O  4.78   4.781353
# 2325  CO[C@H]1/C=C\O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(c5c(...  4.50   5.386556
# 4345  COc1cc2cc(c1Cl)N(C)C(=O)CC(OC(=O)C(C)N(C)C(C)=...  1.99   2.122649
# 6760                                           CC(C)C#N  0.46   1.012854
#                                                  smiles  logP  logP_pred
# 434   COCCOCCOC(=O)C(Cc1ccc(OC(=O)N(C)C)cc1)NC(=O)C1...  1.41   2.312944
# 479   COc1ccc(N(C(=O)C2CCCCC2)S(=O)(=O)c2ccc3c4c(ccc...  5.26   4.988897
# 1087                              O=P1(NCCCl)OCCCN1CCCl  0.86   0.152800
# 3453            Cc1ccc(N(SC(F)(Cl)Cl)S(=O)(=O)N(C)C)cc1  3.90   3.921506
# 4672                CN(CCCn1ccnc1C=NO)S(=O)(=O)C(F)(F)F  1.77   1.812614
# 6571     COc1ccc(C(=O)Nc2cccc(F)c2)cc1S(=O)(=O)N1CCOCC1  3.64   3.147920
# 7312     CCOC(=O)C1CCN(S(=O)(=O)c2nc3nc(C)cc(C)n3n2)CC1  2.71   1.355484
# 7360  COc1ccc(N(CC(=O)N[C@@H]2CCS(=O)(=O)C2)S(=O)(=O...  3.32   3.637407
# 7953  CCOC(=O)c1c(C)[nH]c(C)c1C(=O)COC(=O)c1ccc(F)c(...  3.63   3.412735
# 8347      Cc1ccc(OCCC(=O)N2CCN(S(=O)(=O)c3cccs3)CC2)cc1  2.98   3.444304
# 8574  CCN1C(=O)c2cccc3c(S(=O)(=O)N(C(=O)c4cccnc4)c4c...  4.74   4.100272
#                                                  smiles  logP  logP_pred
# 0        NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 1                    CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1  2.13   3.252617
# 14                    Nc1ccc(S(=O)(=O)N=c2cc[nH]cn2)cc1 -0.24  -0.065799
# 26              COc1cc(Cc2c[nH]c(=N)[nH]c2=N)cc(OC)c1CO  0.42   0.323950
# 104         N=c1[nH]cnc2c1ncn2C1OC2CO[PH](=O)(=O)OC1C2O -2.96  -2.888740
# 1633                       CCOC(=O)C=NC(=O)C=[NH+][NH-] -0.08  -0.229402
# 3669                                 c1ccc(OP2OCCO2)cc1  1.42   0.865178
# 5159         COC(=O)c1[nH]c(=NCC(=O)CO)cnc1[NH+]([O-])O -0.10  -0.922534
# 6461  CC(C)CC(NC(=O)C(CC(C)C)NC(=O)C1CCC[NH2+]1)C(=O... -1.64  -0.101653
#                                   smiles  logP  logP_pred
# 1     CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1  2.13   3.252617
# 3           COC(=O)NC1=NC(c2ccccc2Br)CN1  1.85   2.262368
# 3774          Cc1cccc(C)c1NC(=O)CCCC(C)N  1.41   1.501705
# 4122           Cc1cccc(C)c1NC(=O)CCC(C)N  1.08   1.164344
# 4526                     CC(N)CCc1ccccc1  2.12   2.151775
# 5896                         CCC(C)N=C=S  2.81   2.665803
# 6620                       CC(O)C(C)(C)C  1.48   1.321276
# 6713                             CCC(C)N  0.74   0.602885
# 7330                        CC1CCCC(C)N1  1.53   1.226409
# 8873                            CCCC(C)O  1.19   1.448978
# 9574                     C=CC(N)CCC(=O)O -2.16  -1.036715
#                                                  smiles  logP  logP_pred
# 160   CC1CC2C3CC(F)=C4CC(=O)C=CC4(C)C3(F)C(O)CC2(C)C...  3.86   3.125246
# 261      ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl  5.93   5.407768
# 1031  CC12CCC(=O)C=C1CCC1C3CCC(O)(C(=O)CO)C3(C)CC(O)...  1.67   1.450298
# 2888  ClC1=C(Cl)C2C(C1Cl)C1(Cl)C(Cl)C(Cl)C2(Cl)C1(Cl)Cl  6.08   5.752191
# 5047  CC1CC2C3CC(F)=C4CC(=O)C(Cl)=CC4(C)C3(Cl)C(O)CC...  4.73   3.930258
# 5523      ClC1=CC2(Cl)C3C(Cl)C(Cl)C(Cl)C3C1(Cl)C2(Cl)Cl  5.91   5.398331
# 6868       CC1(O)CCC2C3CC=C4CC(=O)CCC4(C)C3(F)C(O)CC21C  2.38   2.564159
# 7203        CC1(O)CCC2C3CCC4CC(=O)CCC4(C)C3(F)C(O)CC21C  2.38   2.611601
# 7454         ClCC1(C(Cl)Cl)C2C(Cl)CC1(C(Cl)Cl)C(Cl)C2Cl  5.19   5.188541
#                                                  smiles  logP  logP_pred
# 990                                           CC(C)(C)C  3.11   2.324060
# 3339                            CNC(=O)ON=C1CSC(C)(C)S1  1.33   1.752953
# 3394                                       CC(C)(C)OCCO  0.39   0.575071
# 3462         CC(C)Oc1cc(-n2nc(C(C)(C)C)oc2=O)c(Cl)cc1Cl  4.80   4.279947
# 4881  C[C@@H]1CCC2[C@](C)(CC[C@@H]3OC(C)(C)OC[C@@]23...  4.24   3.735295
# 5290                           CCOP(=S)(OCC)SCSC(C)(C)C  4.48   4.289609
# 5524                CN(C)C(=O)n1nc(C(C)(C)C)nc1SCC(=O)O  1.62   1.276201
# 6206                                         COC(C)(C)C  0.94   1.138454
# 6519                          CSc1nnc(C(C)(C)C)c(=O)n1N  1.70   1.018859
# 7879                   CN1CC(O)N(c2nnc(C(C)(C)C)s2)C1=O  1.49   1.092583
# 7961                                        CC1(C)OCCO1  0.46   0.509217
#                                               smiles  logP  logP_pred
# 0     NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 1                 CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1  2.13   3.252617
# 8                    CCOP(=S)(CC)Oc1cc(Cl)c(Cl)cc1Cl  5.23   5.254063
# 11                        NC(=O)Cn1ccnc1[N+](=O)[O-] -1.22  -1.258105
# 13                     O=C(c1ccc(Cl)cc1)c1cc(F)ccc1O  4.04   4.279430
# 24                               N#Cc1c(N)sc2ccccc12  2.17   1.787301
# 262            C[N+](C)(CCCc1ccccc1)CCCS(=O)(=O)[O-] -1.57  -1.501252
# 3669                              c1ccc(OP2OCCO2)cc1  1.42   0.865178
# 6713                                         CCC(C)N  0.74   0.602885
#                                                  smiles  logP  logP_pred
# 66          CC(=O)Nc1ccc2c(c1)Cc1cc([N+](=O)[O-])ccc1-2  3.08   3.095670
# 308                              c1ccc2c(c1)Cc1ccccc1-2  4.18   4.233545
# 715                             Nc1ccc2c(c1)Cc1ccccc1-2  3.14   3.308658
# 1812                                       C1=CC2CCC1C2  3.24   2.942290
# 2203                                  CC1CC(C)CN(N=O)C1  1.53   2.192972
# 2365                             c1ccc2c(c1)Cc1ccccc1C2  4.25   4.664574
# 5965   C[C@H]1C[C@H](C)CN(C(=O)CSc2nnc(-c3ccccc3)n2C)C1  3.68   3.970534
# 6216  CCOC(=O)c1c(CC(C)C)csc1N=Cc1c(C)[nH]n(-c2ccccc...  5.16   4.717809
# 7355              CCC1(C2=CC3CCC(C2)C3)C(=O)NC(=O)NC1=O  2.53   2.258411
# 7946                       c1ccc2c(c1)Cc1c-2ccc2ccccc12  5.40   5.362663
# 8440            O=C(OCC(=O)N1CCC(Cc2ccccc2)CC1)C1CCCCC1  4.98   5.015164
#                                                  smiles  logP  logP_pred
# 0        NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 1613  CC(CCC(=O)NCC(=O)O)C1CCC2C3C(O)CC4CC(O)CCC4(C)...  1.65   1.248455
# 4289  C[C@H](CCC(=O)O)[C@H]1CC[C@H]2[C@H]3[C@H](CC[C...  4.15   3.504827
# 4300  CC1(C)C(C=C(Cl)C(F)(F)F)C1C(=O)OC(C#N)c1cccc(O...  6.80   6.201440
# 5646                               CC1CCC(C(C)C)C(=O)C1  3.05   3.244171
# 6390                          CC1CC2CC=CCC2(N)c2ccccc21  3.40   3.774157
# 7355              CCC1(C2=CC3CCC(C2)C3)C(=O)NC(=O)NC1=O  2.53   2.258411
# 7658     C[C@H]1C[C@H](NC(=S)NCc2csc3ccccc23)CC(C)(C)C1  6.21   6.011833
# 8738                      CC1=C(C(=O)O)C(C(=O)O)CC(C)C1  1.53   1.364865
# 9269                            CC(=O)OC1CC(C)CCC1C(C)C  4.00   3.357401
# 9600                   CCC1(C(C)CC(C)O)C(=O)NC(=O)NC1=O  0.35   0.233160
#                                                  smiles  logP  logP_pred
# 0        NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 9                                    CC#CC#CC#Cc1ccccc1  4.91   4.049730
# 11                           NC(=O)Cn1ccnc1[N+](=O)[O-] -1.22  -1.258105
# 136    CCCn1c2ccccc2c2nnc(SCC(=O)N[C@H](C)c3ccccc3)nc21  4.36   4.132452
# 152   N#Cc1[nH]n(-c2c(Cl)cc(C(F)(F)F)cc2Cl)c(=N)c1S(...  4.00   4.176304
# 730             CN(C)C(=S)S[Fe](SC(=S)N(C)C)SC(=S)N(C)C -1.60   0.340562
# 1654                             FS(F)(F)(F)(F)c1ccccc1  3.36   3.588575
# 3669                                 c1ccc(OP2OCCO2)cc1  1.42   0.865178
# 8761                                      OB(O)c1ccccc1  1.58   1.331979
#                                       smiles  logP  logP_pred
# 18             O=S(=O)(Nc1cccc(F)c1)C(F)(F)F  3.42   2.836226
# 42        CC(=O)C(C#N)=NNc1ccc(SC(F)(F)F)cc1  5.04   4.111878
# 368            CCCCOn1c(=O)[nH]c(C)c(Br)c1=O  1.24   0.993362
# 1103             CCC(=O)n1c(=O)[nH]cc(F)c1=O  0.19  -0.642222
# 1654                  FS(F)(F)(F)(F)c1ccccc1  3.36   3.588575
# 2395                CCCOn1c(=O)cc(C)[nH]c1=O  0.30  -0.421255
# 4672     CN(CCCn1ccnc1C=NO)S(=O)(=O)C(F)(F)F  1.77   1.812614
# 4857               O=S(=O)(c1ccccc1)C(F)(F)F  2.69   2.113040
# 5949              CCOCCOCCOP(=S)(N1CC1)N1CC1  0.38   0.705792
# 6486  CC(=O)N(c1ccc(N2CCOCC2)nn1)n1c(C)ccc1C  1.64   1.001242
# 7482                   O=C(C(F)(F)F)C(F)(F)F  1.46   1.626075
#                                                  smiles  logP  logP_pred
# 28    CC(C)CC(N)C(=O)NC(CC(C)C)C(=O)NC(CC(C)C)C(=O)N... -0.51  -0.398213
# 299                CC(CC(=O)O)CC(=O)c1ccc(-c2ccccc2)cc1  3.82   3.952169
# 431                                       CC1CCC(=O)CC1  1.38   1.510291
# 445   CCC[C@@H](C)NC(=O)COc1ncnc2sc3c(c12)CC[C@@H](C)C3  4.55   4.850644
# 1635                                     CC(C)=CC=C(C)C  3.50   3.937905
# 2072        C=CCC1=C(C)C(OC(=O)C2C(C=C(C)C)C2(C)C)CC1=O  4.78   4.781353
# 3767  CC(=O)OC1(C(C)=O)CCC2C3CC(C)=C4CC(=O)C=CC4(C)C...  1.50   2.768006
# 3798       COc1ccc2cc(C(C)C(=O)OCC=C(C)CCC=C(C)C)ccc2c1  7.77   6.784694
# 4308  CCCCCc1cc(CCCCn2cc(O)c3ccccc3c2=O)c2c(c1)OC(C)...  9.07   8.587175
# 4345  COc1cc2cc(c1Cl)N(C)C(=O)CC(OC(=O)C(C)N(C)C(C)=...  1.99   2.122649
#                                                  smiles  logP  logP_pred
# 135        CC1(C)N=C(N=c2[nH]cc([N+](=O)[O-])s2)OC1(C)C  2.40   2.269229
# 176                  CN(C)C(N(C)C)=S(I)c1cc(Cl)cc(Cl)c1  0.52   0.948793
# 858   COC(=O)C1=C(C)N=C(C)C(C(=O)OCCN2CCN(C(c3ccccc3...  5.20   5.372201
# 1257                  CS(=O)(=O)ON1C(=O)c2ccc(N)cc2C1=O  0.80  -1.049698
# 2504  CC1(C)OC2CC3C4CC(F)=C5CC(=O)C(Cl)=CC5(C)C4(F)C...  2.99   2.975926
# 3595                        CCCCCCCCCCCCOS(=O)(=O)O[Na]  1.60   0.923754
# 5123                               CCCCCOP(C)(=O)OCCCCC  3.74   3.314553
# 7430                           S=C=NC(c1ccccc1)c1ccccc1  5.09   4.885232
# 8993  COc1ccc(C(C(=O)Nc2ccc3c(c2)OCCO3)N(C)C(=O)Cc2c...  3.76   3.573282
# 9359  COC(C)(OC)c1ccc(C(O)(Cn2ccnc2)c2ccc(-c3ccncc3)...  3.45   4.024981
# 9364  O=S1(=O)OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl  3.66   2.741395
#                                                  smiles  logP  logP_pred
# 261      ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl  5.93   5.407768
# 665           ClC1=CC2(Cl)C3CC(Cl)C(Cl)C3C1(Cl)C2(Cl)Cl  5.56   5.328644
# 1859  FC(F)(F)C1(F)C(F)(F)C(F)(F)C(F)(N2C(F)(F)C(F)(...  7.10   6.063077
# 2159             ClC1=C(Cl)C2(Cl)C3CC=CC3C1(Cl)C2(Cl)Cl  5.57   5.215457
# 3190      O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl  3.83   3.025488
# 6316                     CC(C)C1(C(C)C)C(=O)NC(=O)NC1=O  1.56   1.003355
# 6813    CC(C)(C)c1cc(C2C(=O)c3ccccc3C2=O)cc(C(C)(C)C)c1  6.86   5.523544
# 6975  ClC1=C(Cl)C2(Cl)C3C(Cl)C(Cl)(Cl)CC3C1(Cl)C2(Cl)Cl  6.20   5.829449
# 7080      ClC1=C(Cl)C2(Cl)C3C(Cl)C(Cl)CC3C1(Cl)C2(Cl)Cl  6.16   5.666363
# 7678  C=C1C(=O)OC2C1C(OC(=O)C(C)=CC)CC1(CO1)C1C(OC(C...  0.76   1.486948
#                                                  smiles  logP  logP_pred
# 260        Cc1c(CN(C)C(=O)C(C)n2nc(C(F)F)c(Br)c2C)cnn1C  3.12   1.891796
# 1122  O=[N+]([O-])c1cc(C(F)F)c(N=c2[nH]cc(C(F)(F)F)c...  3.52   4.134831
# 2844                ClC(Cl)=C(c1ccc(Cl)cc1)c1ccc(Cl)cc1  6.51   5.955868
# 3147                         CC#CCOC(C)c1ccc(OC)c(OC)c1  2.40   2.574349
# 3489  CC(=O)c1cccc(-n2c(O)c3c(c2O)[C@@H]2C=C[C@H]3C2...  6.25   6.397116
# 3999    Cc1nn(-c2cc(NS(C)(=O)=O)c(Cl)cc2Cl)c(=O)n1C(F)F  0.99   2.041328
# 4154    Cc1ccc(-c2cc(C(F)F)n3ncc(C(=O)N4CCSCC4)c3n2)cc1  4.55   4.099327
# 4900       C=CCNC(=O)CSc1nc(C(F)F)cc(-c2cn(C)nc2C)c1C#N  3.74   2.543977
# 5847                        CN(C)CCOC(c1ccccc1)c1ccccc1  3.27   3.589802
# 6268                      N#CC(C#N)=C(c1ccccc1)c1ccccc1  3.55   3.589382
# 6536                       Cc1ccccc1C(OCCN(C)C)c1ccccc1  3.77   4.067174
#                                                  smiles  logP  logP_pred
# 168   CCOC1OC2OC3(C)CCC4C(C)C(OC5OC(C(=O)O)C(O)C(O)C...  0.61   0.711384
# 261      ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl  5.93   5.407768
# 507                            COC1CC(Cl)C(Cl)C(Cl)C1Cl  2.99   3.043210
# 665           ClC1=CC2(Cl)C3CC(Cl)C(Cl)C3C1(Cl)C2(Cl)Cl  5.56   5.328644
# 947   C=C1C(C)C2C(Cc3ccccc3)NC(=O)C23OC(=O)CCC(=O)CC...  3.37   2.915662
# 1118  O=[N+]([O-])c1ccc(OC2OC(CO)C(OC3OC(CO)C(O)C(O)... -1.39  -2.223639
# 1562  CCC1OC(=O)CC(O)C(C)C(OC2OC(C)CC(N(C)C)C2O)C(CC...  2.19   1.491160
# 4592              CCC1C2CC3C4N(C)c5ccccc5C4(CCN3C1O)C2O  1.81   1.971308
#                                                 smiles  logP  logP_pred
# 66         CC(=O)Nc1ccc2c(c1)Cc1cc([N+](=O)[O-])ccc1-2  3.08   3.095670
# 2203                                 CC1CC(C)CN(N=O)C1  1.53   2.192972
# 2449             CC(=O)NC(CC12CC3CC(CC(C3)C1)C2)C(N)=O  1.90   1.231926
# 3118                  Cc1cc(Cc2cc(Cl)ccc2Cl)c(Cl)cc1Cl  7.53   7.101367
# 4016                  Cc1c(Cl)ccc(Cc2ccc(Cl)cc2Cl)c1Cl  7.20   6.929994
# 5965  C[C@H]1C[C@H](C)CN(C(=O)CSc2nnc(-c3ccccc3)n2C)C1  3.68   3.970534
# 7582                  Cc1cc(Cc2ccc(Cl)cc2Cl)c(Cl)cc1Cl  7.43   7.129018
# 8204                                  S=C=NCCCc1ccccc1  3.80   3.829371
# 8422                     CCC12CC3CC(N)(C1)CC(CC)(C3)C2  4.36   3.517562
# 8440           O=C(OCC(=O)N1CCC(Cc2ccccc2)CC1)C1CCCCC1  4.98   5.015164
# 8814                       Oc1ccc(Cl)cc1Cc1cc(Cl)ccc1O  4.26   4.939181
#                                                  smiles  logP  logP_pred
# 314       CC(C)N(C=Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1)C(C)C  0.01  -0.550120
# 679                               O=S(c1ccccc1)c1ccccc1  2.06   1.971745
# 1255                                 CC(C)C(N)Cc1ccccc1  2.59   2.340035
# 1565                      CC(C)N(C(=O)SCC(Cl)=CCl)C(C)C  4.49   3.494007
# 3062                                 CC(C)C(=O)c1ccccc1  2.73   2.726840
# 4947                              O=C(c1ccc(F)cc1)C1CC1  2.61   2.669397
# 5300         CC(C)N(CCC(C(N)=O)(c1ccccc1)c1ccccn1)C(C)C  2.58   3.318700
# 5333                                    CC(C)C(=O)C(C)C  1.86   2.354481
# 7151        CC(C)N(CCC(C(N)=O)c1ccc(-c2ccccc2)cc1)C(C)C  3.66   4.524666
# 8154                             CC(C)N(Cc1cccnc1)C(C)C  2.27   2.310988
# 8654  COC(=O)c1cc(S(=O)c2ccc(C(F)(F)F)cc2Cl)ccc1[N+]...  3.65   3.459997
#                                                  smiles  logP  logP_pred
# 0        NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 135        CC1(C)N=C(N=c2[nH]cc([N+](=O)[O-])s2)OC1(C)C  2.40   2.269229
# 452                  [O-][n+]1onc(Cc2ccccc2)c1Cc1ccccc1  3.65   3.522445
# 597                  COc1nc(=NC(C)C)[nH]c(=NC(C)C)[nH]1  2.99   2.308800
# 671   COc1cccc(-c2[nH]nc3c2[C@@H](c2cc(OC)c(OC)cc2Br...  4.52   4.023254
# 2452  C=C1CC23CC1(O)CCC2C12C=CC(O)C(C)(C(=O)O1)C2C3C...  0.24   0.851500
# 3190      O=S1OCC2C(CO1)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl  3.83   3.025488
# 5249  CCC1OC(=O)C(C)C(OC2CC(C)(OC)C(O)C(C)O2)C(C)C(O...  2.92   1.220838
# 5454                              Cc1cc(C)c2oc(=O)sc2c1  3.25   2.334797
# 5623            C#CCOC1=Nc2cc(OC(=O)N3CCCC3)c(Cl)cc2OC1  2.93   2.693941
# 6744          CCOC(=O)C(C)Oc1ccc(Oc2nc3ccc(Cl)cc3o2)cc1  4.58   4.528868
#                                     smiles  logP  logP_pred
# 19            Cc1ccc(C(=O)N(N)c2ccccc2)cc1  3.00   3.180848
# 46                        CNc1cccc2ccccc12  2.88   2.726474
# 58           C=Cc1ccc2c(O)c3ccccc3c(O)c2c1  4.37   4.846768
# 97                CC(C)(C)c1ccc(C(=O)O)cc1  3.85   2.983201
# 105                  CC(=O)C=Cc1ccc(Br)cc1  3.03   2.893226
# 195          Cc1cccc(S(I)=C(N(C)C)N(C)C)c1 -0.14  -0.158882
# 481                             CCc1ccccc1  3.15   3.170508
# 885   c1cc2ccc3ccc4ccc5cccc6c(c1)c2c3c4c56  6.63   6.611596
# 2439            CCC(C)(C)c1ccc(CC(=O)O)cc1  3.48   3.253791
# 5894                       C=Cc1ccc(CC)cc1  4.19   3.760735
# 6451                              Cc1ccsc1  2.34   2.099501
#                                                  smiles  logP  logP_pred
# 0        NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 2                  C=CCc1cccc2c(=O)c(C)c(-c3ccccc3)oc12  4.67   4.890304
# 53    C#CCOc1ccc(C2C3=C(CC(C)(C)CC3=O)OC3=C2C(=O)CC(...  4.93   4.712489
# 246                                  CC(=O)NC(CS)C(N)=O -0.29  -1.164740
# 689      CCSCS(=O)CC(C)NC(=O)C=Cc1c(C)[nH]c(=O)[nH]c1=O -0.30  -0.104928
# 944                Cl.NCCCCC(N)C(=O)NC(Cc1ccccc1)C(=O)O  0.12  -1.427631
# 3052       CCOC(=O)N1CCC(=C2c3ccc(Cl)cc3CCc3cccnc32)CC1  5.20   5.165107
# 3740                          CS(=O)(=O)CCOCn1ccnc1C=NO -0.84  -1.038114
# 4091             COCCOCC1COC(c2ccc(Cl)cc2Cl)(n2cncn2)O1  2.03   1.933337
# 6142   CCCCSCS(=O)CC(C)NC(=O)C=Cc1c(C)[nH]c(=O)[nH]c1=O  0.82   0.718342
#                                                  smiles  logP  logP_pred
# 1184  O=C1NC(=O)C(c2ccccc2)(c2ccccc2)N1S(=O)(=O)c1cc...  4.04   3.637362
# 1513  CCC(=O)OC1(C(=O)CCl)C(C)CC2C3CC=C4CC(=O)C=CC4(...  3.46   3.487942
# 1805         NS(=O)(=O)c1cc(C2(O)NC(=O)c3ccccc32)ccc1Cl  0.85   1.459636
# 1859  FC(F)(F)C1(F)C(F)(F)C(F)(F)C(F)(N2C(F)(F)C(F)(...  7.10   6.063077
# 3182                       CCC1(c2ccccc2)NC(=O)N(C)C1=O  1.69   1.450186
# 3940               O=C1NC(=O)C(c2ccccc2)(c2ccc(O)cc2)N1  1.70   1.236358
# 4486         CCCC[C@@]1(c2ccccc2)NC(=S)N(c2ccc(C)cc2)N1  5.10   4.685406
# 4748                            CN1C(=O)CCC1(O)c1cccnc1 -0.57  -0.043808
# 4833       CCC1(c2ccccc2)C(=O)NC(=O)N1S(=O)(=O)c1ccccc1  2.44   2.646888
# 4899      ClC1=C(Cl)C2(Cl)C(Cl)(Cl)C3CC(Cl)C1C3C2(Cl)Cl  6.09   5.718973
# 9551             O=C1NC(=O)C(c2ccccc2)(c2ccccc2)C(=O)N1  1.96   1.822342
#                                                  smiles  logP  logP_pred
# 84     COc1cc2c(cc1OC)C13CCN4CC5CCOC6CC(=O)N2C1C6C5CC43  0.84   1.417909
# 168   CCOC1OC2OC3(C)CCC4C(C)C(OC5OC(C(=O)O)C(O)C(O)C...  0.61   0.711384
# 261      ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl  5.93   5.407768
# 925   CC=C(C)C(=O)OC1CC(OC(C)=O)C2(C(=O)OC)COC3C2C12...  1.09   0.144888
# 1572  Cc1cc(C)nc(OC(C(=O)O)C2(c3ccccc3)NCC(=O)N(C)c3... -2.00   1.298161
# 2888  ClC1=C(Cl)C2C(C1Cl)C1(Cl)C(Cl)C(Cl)C2(Cl)C1(Cl)Cl  6.08   5.752191
# 4342  CCCc1[nH]nc2c1[C@@]1(C(=O)N(CC(N)=O)c3ccccc31)...  4.48   1.998521
# 4580        ClC=C1C2CC(C(Cl)C2(Cl)Cl)C1(C(Cl)Cl)C(Cl)Cl  5.49   5.689369
# 6316                     CC(C)C1(C(C)C)C(=O)NC(=O)NC1=O  1.56   1.003355
# 8119     ClCC1(C(Cl)Cl)C2CC(Cl)(Cl)C1(C(Cl)Cl)C(Cl)C2Cl  5.80   5.563060
# 8848  CCc1cc2c3c(c1)[C@@]1(C(=O)N3C(C)(C)C=C2C)C2=C(...  5.39   4.845679
#                                                  smiles  logP  logP_pred
# 14                    Nc1ccc(S(=O)(=O)N=c2cc[nH]cn2)cc1 -0.24  -0.065799
# 36                              CC1=C(c2ccccc2)CCN(C)C1  3.18   2.851261
# 125                                  O=C(O)C=COc1ccccc1  2.27   1.753389
# 382                            CC(=O)Oc1ccc(CC=NC=O)cc1  1.32   1.268367
# 495                         O=S(=O)(Nc1ccc(Cl)cc1)C(F)F  2.84   2.298123
# 548                     CN1CCN=C(c2ccccc2)c2cc(Cl)ccc21  4.41   3.173313
# 3453            Cc1ccc(N(SC(F)(Cl)Cl)S(=O)(=O)N(C)C)cc1  3.90   3.921506
# 3671  CCCC(=NC(=O)C(Cc1ccccc1)NS(=O)(=O)N1CCOCC1)C(=...  3.17   4.304577
# 4263              C=C1CCC2C(C1)c1c(OC)cc(CCC)cc1OC2(C)C  6.26   6.646419
# 6778  COc1cc(OC)[nH]c(=NC(=O)NS(=O)(=O)Nc2ccccc2C(=O...  2.05   2.105955
# 8573                                      N=c1cc[nH]cc1  0.26  -0.005462
#                                               smiles  logP  logP_pred
# 0     NCCCCC(NC(CCc1ccccc1)C(=O)O)C(=O)N1CCCC1C(=O)O -1.01  -0.599925
# 1                 CCN(CC)CCSC(=NO)c1noc(-c2ccccc2)n1  2.13   3.252617
# 6                              C=CC(=O)NCCCN(CCO)CCO -0.60  -0.805757
# 44                O=[N+]([O-])c1c[nH]c(=NC2=NCCN2)s1  1.38   0.674248
# 47               CCN=c1cc(-c2nc(=N)[nH][nH]2)cc[nH]1  1.13   0.812614
# 94                           CCOC(=O)CCn1nc2ccccc2n1  2.12   0.885104
# 296               CCNP(=O)(OCC)ON=C(C#N)c1ccc(OC)cc1  2.39   1.564044
# 391                  CCn1cc(C(=O)O)c(=O)c2ccc(C)nc21  1.41   0.233901
# 1336     CC[N+](C)(C)[N-]C(=O)C(O)(c1ccccc1)c1ccccc1  0.87   1.431714
# 1533          N=c1[nH]c(C=Cc2ccc([N+](=O)[O-])o2)no1  1.30   1.081169
# 2012                    OCC1OC(n2cnc3c2N=CNCC3O)CC1O -2.09  -1.704942
#                                                  smiles  logP  logP_pred
# 730             CN(C)C(=S)S[Fe](SC(=S)N(C)C)SC(=S)N(C)C -1.60   0.340562
# 1604         ClCC1(CCl)C2CC(Cl)(Cl)C1(C(Cl)Cl)CC2(Cl)Cl  5.79   5.371230
# 2196                Cc1cc(Br)ccc1NC(=O)CSc1n[nH]c(=N)s1  2.69   2.445075
# 2219  O=[N+]([O-])c1ccc(N(N=Cc2ccccc2)P(=O)(N2CC2)N2...  0.57   1.876122
# 2369                             c1ccc(CSc2nc[nH]n2)cc1  1.45   2.405151
# 3453            Cc1ccc(N(SC(F)(Cl)Cl)S(=O)(=O)N(C)C)cc1  3.90   3.921506
# 5426  O=C(Cn1cnnn1)NC1C(=O)N2C(C(=O)O)=C(CSc3nncs3)C... -0.67  -0.902409
# 5668                      c1nnn(C23CC4CC(CC(C4)C2)C3)n1  2.95   2.443951
# 5764          N#Cc1nc(N2CCCC2)nc(N(c2ccccc2)c2ccccc2)n1  5.38   4.084727
# 7504                            CC(C)(C)NSc1nc2ccccc2s1  4.67   4.163454
# 8504        CC(C)N(C(=O)CSc1n[nH]c(=NCc2ccccc2)s1)C(C)C  4.09   4.029947
#                                                  smiles  logP  logP_pred
# 3                          COC(=O)NC1=NC(c2ccccc2Br)CN1  1.85   2.262368
# 15    CCCC(=O)OC1(C(=O)CO)CCC2C3CC=C4CC(=O)CCC4(C)C3...  3.18   2.434123
# 120                      OCC1CC(F)C(n2cnc3c(I)ncnc32)O1  0.63   0.094081
# 261      ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl  5.93   5.407768
# 440             COC1N(C2CC(F)C(CO)O2)C(=O)NC(=O)C1(C)Br  0.54   0.505605
# 576                                        FCCCc1ccccc1  2.95   2.948247
# 599                                        BrCCc1ccccc1  3.09   3.270589
# 909                        COP(=O)(OC)OC(Br)C(Cl)(Cl)Br  1.38   1.729178
# 1151  CCC1OC(=O)C(C)C(OC2CC(C)(OC)C(O)C(C)O2)C(C)C(O...  1.79   0.869453
# 1527                                           NC(=O)CI -0.19  -0.633942
#                                       smiles  logP  logP_pred
# 47       CCN=c1cc(-c2nc(=N)[nH][nH]2)cc[nH]1  1.13   0.812614
# 294                COc1ccc(NC(=O)N=C(N)N)cc1  0.56  -0.238008
# 301              CN(C)c1nc(=N)nc(N(C)C)[nH]1  1.20   0.727650
# 401   CCCCN(CCCC)c1cc(N)[n+]([O-])c(=N)[nH]1  3.19   2.147577
# 521             Cc1cc(N=NC(=N)N)ccc1NNC(N)=S  1.66   1.629369
# 1224          Cc1cc2[nH]cccc2c2nc(=N)n(C)c12  1.98   1.682076
# 1273                             CN=C(N)NC#N -0.77  -0.895145
# 1492             CCN=C(N)N=C(N)Nc1ccc(Cl)cc1  2.14   1.203991
# 2444    Cc1ccc2c(c1)[n+]([O-])nc(N)[n+]2[O-]  0.20  -0.527182
# 2709    CC(=O)c1cccc(N2C(N)=NC(N)=NC2(C)C)c1 -0.22   0.393335
#                                                  smiles  logP  logP_pred
# 120                      OCC1CC(F)C(n2cnc3c(I)ncnc32)O1  0.63   0.094081
# 123                      CC(=O)Nc1ccc(OCC(O)CNC(C)C)cc1  0.79   0.896791
# 314       CC(C)N(C=Nc1ccn(C2OC(CO)C(O)C2O)c(=O)n1)C(C)C  0.01  -0.550120
# 597                  COc1nc(=NC(C)C)[nH]c(=NC(C)C)[nH]1  2.99   2.308800
# 745              C#CC1(O)C(F)CC2C3CCc4cc(O)ccc4C3CCC21C  3.30   3.504583
# 1068                        CC1COc2ccccc2N1C(=O)C(Cl)Cl  2.70   1.989564
# 1281                       COC(=O)c1cnc2n(c1=O)C(C)CCC2  0.16   0.095183
# 1972           CC1CN(C)C(N=c2[nH]cc([N+](=O)[O-])s2)=N1  1.95   1.175785
# 2165                                CN(C)NC(=O)CCC(=O)O -1.50  -2.220424
# 2665    CCn1cc(C(=O)O)c(=O)c2cc(F)c(N3CCNC(C)C3)c(F)c21 -0.30   0.568331
# 6658  CC12CCC(=O)C=C1C(F)CC1C2C(O)CC2(C)C1CCC2(O)C(=...  1.67   0.943847
#                                                  smiles  logP  logP_pred
# 748                                 [O-][n+]1ccc(Cl)cc1 -0.44  -0.259203
# 1396                          COc1c2occc2cc2ccc(=O)oc12  2.00   1.481562
# 1574                O=c1ccn(C2C=C(CO)C(O)C2O)c(=O)[nH]1 -2.19  -2.161553
# 1966                       O=C1CCC(c2ccc[n+]([O-])c2)N1 -1.01  -1.584811
# 3070                      CCOC(O)c1c[nH]c(=O)cc1C(O)OCC  0.17  -0.654759
# 3174                          COc1c2ccoc2cc2oc(=O)ccc12  1.93   1.656028
# 4332                              Cc1ccccc1C(O)c1ccccc1  3.06   3.232461
# 4359          O=c1[nH]c(=O)n(C2CC(O)C(CO)O2)cc1C(F)(F)F -0.46  -0.393281
# 6400  CC(C(=O)Nc1ccc2c(C(F)(F)F)cc(=O)oc2c1)n1nc(C(F...  6.63   5.425978
# 6934                                    [O-][n+]1ccccc1 -1.20  -1.068524
# 8279                                  O=c1cccc(Cl)[nH]1  0.93   0.716655

# %%
from collections import OrderedDict
from operator import itemgetter 

RMSE_ordered = OrderedDict(sorted(active_molecules_preds_RMSE.items(), key = itemgetter(1), reverse = True))

print(RMSE_ordered)
# Out:
# OrderedDict([(24, 1.3264892549490843), (27, 0.8978709573919709), (0, 0.8495046903707253), (1, 0.7848611178792266), (11, 0.7586470854435465), (26, 0.7490383404387215), (4, 0.7338106516959658), (20, 0.7208945599414829), (15, 0.7197089270931099), (14, 0.7097850676546701), (16, 0.6860036114915525), (29, 0.6271966319892681), (3, 0.6209123687091349), (30, 0.6050447942152017), (2, 0.6017538144410737), (22, 0.5935095163812439), (25, 0.5832231998277418), (13, 0.5620029741715348), (12, 0.5563283883821553), (19, 0.5183157409766116), (31, 0.5165124911433486), (5, 0.5163368814340218), (28, 0.4986511482051135), (23, 0.4796227340275834), (18, 0.47585498224929573), (17, 0.4683930998150951), (8, 0.46733280682287043), (6, 0.4663410738070103), (7, 0.4445806494341472), (10, 0.4099337252299015), (21, 0.3500682664644944), (9, 0.3144874499226375)])

# %%
active_molecules_preds[24]
# Out:
#                                                  smiles  logP  logP_pred
# 84     COc1cc2c(cc1OC)C13CCN4CC5CCOC6CC(=O)N2C1C6C5CC43  0.84   1.417909
# 168   CCOC1OC2OC3(C)CCC4C(C)C(OC5OC(C(=O)O)C(O)C(O)C...  0.61   0.711384
# 261      ClCC1(C(Cl)Cl)C2C(Cl)C(Cl)C1(C(Cl)Cl)C(Cl)C2Cl  5.93   5.407768
# 925   CC=C(C)C(=O)OC1CC(OC(C)=O)C2(C(=O)OC)COC3C2C12...  1.09   0.144888
# 1572  Cc1cc(C)nc(OC(C(=O)O)C2(c3ccccc3)NCC(=O)N(C)c3... -2.00   1.298161
# 2888  ClC1=C(Cl)C2C(C1Cl)C1(Cl)C(Cl)C(Cl)C2(Cl)C1(Cl)Cl  6.08   5.752191
# 4342  CCCc1[nH]nc2c1[C@@]1(C(=O)N(CC(N)=O)c3ccccc31)...  4.48   1.998521
# 4580        ClC=C1C2CC(C(Cl)C2(Cl)Cl)C1(C(Cl)Cl)C(Cl)Cl  5.49   5.689369
# 6316                     CC(C)C1(C(C)C)C(=O)NC(=O)NC1=O  1.56   1.003355
# 8119     ClCC1(C(Cl)Cl)C2CC(Cl)(Cl)C1(C(Cl)Cl)C(Cl)C2Cl  5.80   5.563060
# 8848  CCc1cc2c3c(c1)[C@@]1(C(=O)N3C(C)(C)C=C2C)C2=C(...  5.39   4.845679

# %%
active_molecules_preds[9]
# Out:
#                                                  smiles  logP  logP_pred
# 66          CC(=O)Nc1ccc2c(c1)Cc1cc([N+](=O)[O-])ccc1-2  3.08   3.095670
# 308                              c1ccc2c(c1)Cc1ccccc1-2  4.18   4.233545
# 715                             Nc1ccc2c(c1)Cc1ccccc1-2  3.14   3.308658
# 1812                                       C1=CC2CCC1C2  3.24   2.942290
# 2203                                  CC1CC(C)CN(N=O)C1  1.53   2.192972
# 2365                             c1ccc2c(c1)Cc1ccccc1C2  4.25   4.664574
# 5965   C[C@H]1C[C@H](C)CN(C(=O)CSc2nnc(-c3ccccc3)n2C)C1  3.68   3.970534
# 6216  CCOC(=O)c1c(CC(C)C)csc1N=Cc1c(C)[nH]n(-c2ccccc...  5.16   4.717809
# 7355              CCC1(C2=CC3CCC(C2)C3)C(=O)NC(=O)NC1=O  2.53   2.258411
# 7946                       c1ccc2c(c1)Cc1c-2ccc2ccccc12  5.40   5.362663
# 8440            O=C(OCC(=O)N1CCC(Cc2ccccc2)CC1)C1CCCCC1  4.98   5.015164

# %%
result = np.array(RMSE_ordered.values())<0.5

for i in range(len(result)):
    if i==0:
        continue
    if not result[i-1] and result[i]:
        print(i)
        threshold = i
        break
# Out:
# 22

# %%
fig, ax = plt.subplots(figsize=(20,15))
# plt.axis('off')
ax.bar(range(32),RMSE_ordered.values())

label = RMSE_ordered.keys()
 
# Text on the top of each barplot
for i in range(len(label)):
    ax.text(x = i-0.25 , y = RMSE_ordered.values()[i]+0.03, s = str(label[i]), size = 15)
_ = ax.set_xticklabels([])

ax.set_ylabel('RMSE of group of molecules', fontsize = 20)
ax.set_xlabel('Fingerprint\'s bit', fontsize = 20)
_ = ax.set_title ('RMSE for 11 molecules which parts activate fingerprint bit most', fontsize = 20)

ax.vlines(x = threshold-0.5, ymin = 0, ymax = max(RMSE_ordered.values()), label = 'RMSE is 0.5')
ax.legend(fontsize=25)

# %% [markdown]
# # Create summary images

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np

imgs = []

for i in range(params["fp_length"]):
    for j in range(num_figs_per_fp):
        img = mpimg.imread(os.path.join(FIGURE_PATH, 'figures','exp_'+str(NUM_EXP),"fp_"+str(i)+"_highlight_"+str(j)+".png"))
        imgs.append(img)
        



fig = plt.figure(figsize=(num_figs_per_fp, params["fp_length"]))

plt.axis('off')


grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(params["fp_length"], num_figs_per_fp),  # creates 2x2 grid of axes
                 axes_pad=0.1,  # pad between axes in inch.
             )

for i, (ax, im) in enumerate(zip(grid, imgs)):
    # Iterating over the grid returns the Axes.
    ax.imshow(im)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
#     print(i, i%num_figs_per_fp)
    if i%num_figs_per_fp==0:
        ax.text(-0.5, 0.5, 'fp_'+str(i//11),
     horizontalalignment='center',
     verticalalignment='center',
     transform = ax.transAxes)
fig.savefig(os.path.join(FIGURE_PATH, 'figures','exp_'+str(NUM_EXP),'summary_write.png'), dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import numpy as np

imgs = []

for i in range(params["fp_length"]):
    imgs.append([])
    for j in range(num_figs_per_fp):
        img = mpimg.imread(os.path.join(FIGURE_PATH, 'figures','exp_'+str(NUM_EXP),"fp_"+str(i)+"_highlight_"+str(j)+".png"))
        imgs[i].append(img)
        

for i, fp_molecules in enumerate(imgs):

    fig = plt.figure(figsize=(num_figs_per_fp, 1))

    plt.axis('off')


    grid = ImageGrid(fig, 111,  # similar to subplot(111)
                     nrows_ncols=(1, num_figs_per_fp),  # creates 2x2 grid of axes
                     axes_pad=0.1,  # pad between axes in inch.
                 )

    for ax, im in zip(grid, fp_molecules):
        # Iterating over the grid returns the Axes.
        ax.imshow(im)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    fig.savefig(os.path.join(FIGURE_PATH, 'figures','exp_'+str(NUM_EXP),'fp_'+str(i)+'_summary.png'), dpi=300)
    plt.show()
