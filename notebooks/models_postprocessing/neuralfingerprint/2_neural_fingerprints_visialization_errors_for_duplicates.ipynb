# %%
# Path to Neural Fingerprint scripts

import sys
sys.path
sys.path.append('../../../scripts/baselines/neuralfingerprints/utils')

# %%
from sklearn.metrics import r2_score

# %%
import os, pickle
import autograd.numpy as np
import autograd.numpy.random as npr
from autograd import grad
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import DrawingOptions
import matplotlib.pyplot as plt

from build_vanilla_net import build_morgan_deep_net, relu, build_standard_net
from build_convnet import build_conv_deep_net, build_convnet_fingerprint_fun
from util import normalize_array, build_batched_grad
from optimizers import adam
from util import rmse
from mol_graph import degrees
from data_util import remove_duplicates
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-bab2789230b6> in <module>()
#       8 import matplotlib.pyplot as plt
#       9
# ---> 10 from build_vanilla_net import build_morgan_deep_net, relu, build_standard_net
#      11 from build_convnet import build_conv_deep_net, build_convnet_fingerprint_fun
#      12 from util import normalize_array, build_batched_grad
#
# ImportError: No module named build_vanilla_net

# %%
# new function for loading our datasets
def load_data(dataset_path = '../../../data/3_final_data/split_data', prefix_name='logP_pH_range_mean', VALUE_COLUMN = 'logP', SMILES_COLUMN='smiles'):
    import pandas as pd
    import os
    from rdkit.Chem import MolFromSmiles
    
    def check_molecules(smiles):
        mol = MolFromSmiles(smiles)
        for atom in mol.GetAtoms():
            if atom.GetDegree() not in [0, 1, 2, 3, 4, 5]:
                with open('../../../data/raw/broken_smiles_'+prefix_name+'.txt', 'a') as f:
                    f.write(smiles+'\n')
                return False
        return True
    
    with open('../../../data/raw/broken_smiles_'+prefix_name+'.txt', 'w') as f:
        pass
    
    data_splits = ['train', 'test', 'validation']
    
    datasets = {}
    
    for split in data_splits:
        data = pd.read_csv(os.path.join(dataset_path,prefix_name+'_'+split+'.csv'))
#         data = data[data[SMILES_COLUMN].map(check_molecules)]
        datasets[split] = (data[SMILES_COLUMN].values, data[VALUE_COLUMN].values)
        
    
    return datasets

# %%
def parse_training_params(params):
    nn_train_params = {'num_epochs'  : num_epochs,
                       'batch_size'  : batch_size,
                       'param_scale' : params['init_scale']}

    vanilla_net_params = {'layer_sizes':[params['fp_length']],  # Linear regression.
                          'normalize':normalize,
                          'L2_reg': params['l2_penalty'],
                          'activation_function':activation}
    return nn_train_params, vanilla_net_params

def train_nn(pred_fun, loss_fun, num_weights, train_smiles, train_raw_targets, train_params,
             validation_smiles=None, validation_raw_targets=None):
    """loss_fun has inputs (weights, smiles, targets)"""
    print "Total number of weights in the network:", num_weights
    npr.seed(0)
    init_weights = npr.randn(num_weights) * train_params['param_scale']

    train_targets, undo_norm = normalize_array(train_raw_targets)
    training_curve = []
    def callback(weights, iter):
        if iter % 10 == 0:
            print "max of weights", np.max(np.abs(weights))
            train_preds = undo_norm(pred_fun(weights, train_smiles))
            cur_loss = loss_fun(weights, train_smiles, train_targets)
            training_curve.append(cur_loss)
            print "Iteration", iter, "loss", cur_loss, "train RMSE", \
                np.sqrt(np.mean((train_preds - train_raw_targets)**2)),
            print "Train R2", iter, ":", \
                    r2_score(train_raw_targets, train_preds),
            if validation_smiles is not None:
                validation_preds = undo_norm(pred_fun(weights, validation_smiles))
                print "Validation RMSE", iter, ":", \
                    np.sqrt(np.mean((validation_preds - validation_raw_targets) ** 2)),
                print "Validation R2", iter, ":", \
                    r2_score(validation_raw_targets, validation_preds),
            dub_preds = undo_norm(pred_fun(weights, dub_smiles))
            uniq_preds = undo_norm(pred_fun(weights, uniq_smiles))
            print "Dub RMSE", iter, ":", rmse(dub_preds, dub_targets)
            print "Unique RMSE", iter, ":", rmse(uniq_preds,  uniq_targets)
            print "Dub R2", iter, ":", r2_score(dub_targets, dub_preds)
            print "Unique R2", iter, ":", r2_score(uniq_targets, uniq_preds)

    grad_fun = grad(loss_fun)
    grad_fun_with_data = build_batched_grad(grad_fun, train_params['batch_size'],
                                            train_smiles, train_targets)

    num_iters = train_params['num_epochs'] * len(train_smiles) / train_params['batch_size']
    trained_weights = adam(grad_fun_with_data, init_weights, callback=callback,
                           num_iters=num_iters)
    
    def predict_func(new_smiles):
        """Returns to the original units that the raw targets were in."""
        return undo_norm(pred_fun(trained_weights, new_smiles))
    return predict_func, trained_weights, training_curve


def train_neural_fingerprint():
    print "Loading data..."
    data = load_data(prefix_name = task_params['data_file'], VALUE_COLUMN = task_params['target_name'])

    train_inputs, train_targets = data['train']
    val_inputs,   val_targets   = data['validation']
    test_inputs,  test_targets  = data['test']

    print "Regression on", len(train_inputs), "training points."
    def print_performance(pred_func):
        train_preds = pred_func(train_inputs)
        test_preds = pred_func(test_inputs)
        dub_preds = pred_func(dub_smiles)
        uniq_preds = pred_func(uniq_smiles)
        print "\nPerformance (RMSE) on " + task_params['target_name'] + ":"
        print "Train:", rmse(train_preds, train_targets)
        print "Test: ", rmse(test_preds,  test_targets)
        print "Dub:", rmse(dub_preds, dub_targets)
        print "Unique: ", rmse(uniq_preds,  uniq_targets)
        
        print "\nPerformance (R2) on " + task_params['target_name'] + ":"
        print "Train:", r2_score(train_targets, train_preds)
        print "Test: ", r2_score(test_targets, test_preds)
        print "Dub:", r2_score(dub_targets, dub_preds)
        print "Unique: ", r2_score(uniq_targets, uniq_preds)
        print "-" * 80
        return rmse(test_preds,  test_targets)

    print "-" * 80
    print "Mean predictor"
    y_train_mean = np.mean(train_targets)
    print_performance(lambda x : y_train_mean*np.ones(len(x)))

    print "Task params", params
    nn_train_params, vanilla_net_params = parse_training_params(params)
    conv_arch_params['return_atom_activations'] = False

    print "Convnet fingerprints with neural net"
    loss_fun, pred_fun, conv_parser = \
        build_conv_deep_net(conv_arch_params, vanilla_net_params, params['l2_penalty'])
    num_weights = len(conv_parser)
    predict_func, trained_weights, conv_training_curve = \
         train_nn(pred_fun, loss_fun, num_weights, train_inputs, train_targets,
                 nn_train_params, validation_smiles=val_inputs, validation_raw_targets=val_targets)
    print_performance(predict_func)
    return trained_weights


def draw_molecule_with_highlights(filename, smiles, highlight_atoms):
    drawoptions = DrawingOptions()
    drawoptions.selectColor = highlight_color
    drawoptions.elemDict = {}   # Don't color nodes based on their element.
    drawoptions.bgColor=None

    mol = Chem.MolFromSmiles(smiles)
    fig = Draw.MolToMPL(mol, highlightAtoms=highlight_atoms, size=figsize, options=drawoptions,fitImage=False)

    fig.gca().set_axis_off()
    fig.savefig(filename, bbox_inches='tight')
    plt.close(fig)


def construct_atom_neighbor_list(array_rep):
    atom_neighbour_list = []
    for degree in degrees:
        atom_neighbour_list += [list(neighbours) for neighbours in array_rep[('atom_neighbors', degree)]]
    return atom_neighbour_list


def plot(trained_weights, FIGURE_PATH = '../../../data/raw'):
    
    print "Loading data..."
    data = load_data(prefix_name = task_params['data_file'], VALUE_COLUMN = task_params['target_name'])

    train_smiles, train_targets = data['train']
    val_inputs,   val_targets   = data['validation']
    test_inputs,  test_targets  = data['test']

    print "Convnet fingerprints with neural net"
    conv_arch_params['return_atom_activations'] = True
    output_layer_fun, parser, compute_atom_activations = \
       build_convnet_fingerprint_fun(**conv_arch_params)
    atom_activations, array_rep = compute_atom_activations(trained_weights, train_smiles)

    if not os.path.exists(os.path.join(FIGURE_PATH, 'figures')): os.makedirs(os.path.join(FIGURE_PATH, 'figures'))

    parent_molecule_dict = {}
    for mol_ix, atom_ixs in enumerate(array_rep['atom_list']):
        for atom_ix in atom_ixs:
            parent_molecule_dict[atom_ix] = mol_ix

    atom_neighbor_list = construct_atom_neighbor_list(array_rep)

    def get_neighborhood_ixs(array_rep, cur_atom_ix, radius):
        # Recursive function to get indices of all atoms in a certain radius.
        if radius == 0:
            return set([cur_atom_ix])
        else:
            cur_set = set([cur_atom_ix])
            for n_ix in atom_neighbor_list[cur_atom_ix]:
                cur_set.update(get_neighborhood_ixs(array_rep, n_ix, radius-1))
            return cur_set

    # Recreate trained network.
    nn_train_params, vanilla_net_params = parse_training_params(params)
    conv_arch_params['return_atom_activations'] = False
    _, _, combined_parser = \
        build_conv_deep_net(conv_arch_params, vanilla_net_params, params['l2_penalty'])

    net_loss_fun, net_pred_fun, net_parser = build_standard_net(**vanilla_net_params)
    net_weights = combined_parser.get(trained_weights, 'net weights')
    last_layer_weights = net_parser.get(net_weights, ('weights', 0))

    for fp_ix in range(params['fp_length']):
        print "FP {0} has linear regression coefficient {1}".format(fp_ix, last_layer_weights[fp_ix][0])
        combined_list = []
        for radius in all_radii:
            fp_activations = atom_activations[radius][:, fp_ix]
            combined_list += [(fp_activation, atom_ix, radius) for atom_ix, fp_activation in enumerate(fp_activations)]

        unique_list = remove_duplicates(combined_list, key_lambda=lambda x: x[0])
        combined_list = sorted(unique_list, key=lambda x: -x[0])

        for fig_ix in range(num_figs_per_fp):
            # Find the most-activating atoms for this fingerprint index, across all molecules and depths.
            activation, most_active_atom_ix, cur_radius = combined_list[fig_ix]
            most_activating_mol_ix = parent_molecule_dict[most_active_atom_ix]
            highlight_list_our_ixs = get_neighborhood_ixs(array_rep, most_active_atom_ix, cur_radius)
            highlight_list_rdkit = [array_rep['rdkit_ix'][our_ix] for our_ix in highlight_list_our_ixs]

            print "radius:", cur_radius, "atom list:", highlight_list_rdkit, "activation", activation
            draw_molecule_with_highlights(\
                os.path.join(FIGURE_PATH, 'figures',"fp_{0}_highlight_{1}.pdf".format(fp_ix, fig_ix)),
                train_smiles[most_activating_mol_ix],
                highlight_atoms=highlight_list_rdkit)

# %%
def get_averaged_and_unique_smiles(dataset_name, \
                                   datasets_path = "../../../data/3_final_data", \
                                   not_averaged_dataset_name = 'logP.csv', \
                                   SMILES_COLUMN = 'smiles',\
                                   VALUE_COLUMN = 'logP'):
    """get smiles and logP with unique and duplicated measurements"""
    logP_dataset = pd.read_csv(os.path.join(datasets_path, not_averaged_dataset_name))
    dataset = pd.read_csv(os.path.join(datasets_path, dataset_name))
    
    duplicates_smiles = logP_dataset.groupby([SMILES_COLUMN]).count()
    
    smiles_dub = list(duplicates_smiles[duplicates_smiles[VALUE_COLUMN]>1].index)   
    smiles_uniq = list(duplicates_smiles[duplicates_smiles[VALUE_COLUMN]==1].index)  
    
    dub_data = dataset[dataset[SMILES_COLUMN].isin(smiles_dub)]
    uniq_data = dataset[dataset[SMILES_COLUMN].isin(smiles_uniq)]
    
    dub_smiles, dub_targets = list(dub_data[SMILES_COLUMN]), list(dub_data[VALUE_COLUMN])
    uniq_smiles, uniq_targets = list(uniq_data[SMILES_COLUMN]), list(uniq_data[VALUE_COLUMN])
    
    return dub_smiles, dub_targets, uniq_smiles, uniq_targets

# %% [markdown]
# ## logP_mean

# %% [markdown]
# ### Visualization

# %%
task_params = {'target_name' : 'logP',
               'data_file'   : 'logp_mean'}

num_epochs = 1
batch_size = 100
normalize = 1
dropout = 0
activation = relu
params = {'fp_length': 20,
            'fp_depth': 3,
            'init_scale':np.exp(-4),
            'learn_rate':np.exp(-4),
                    'b1':np.exp(-4),
                    'b2':np.exp(-4),
            'l2_penalty':np.exp(-4),
            'l1_penalty':np.exp(-5),
            'conv_width':10}

conv_layer_sizes = [params['conv_width']] * params['fp_depth']
conv_arch_params = {'num_hidden_features' : conv_layer_sizes,
                    'fp_length' : params['fp_length'],
                    'normalize' : normalize,
                    'return_atom_activations':False}

all_radii = range(params['fp_depth'] + 1)

# Plotting parameters
num_figs_per_fp = 11
figsize = (100, 100)
highlight_color = (30.0/255.0, 100.0/255.0, 255.0/255.0)  # A nice light blue.

# %%
trained_network_weights = train_neural_fingerprint()
with open('results.pkl', 'w') as f:
    pickle.dump(trained_network_weights, f)

# Plotting.
with open('results.pkl') as f:
    trained_weights = pickle.load(f)
plot(trained_weights)
# Out:
# Loading data...
# Regression on 9631 training points.
# --------------------------------------------------------------------------------
# Mean predictor
#
# Performance (RMSE) on logP:
# Train: 1.8591219922763682
# Test:  1.9087278157747403
# Dub: 2.178198827192713
# Unique:  1.8030779775623207
#
# Performance (R2) on logP:
# Train: 0.0
# Test:  -1.8278865013598988e-05
# Dub: -0.004600498132678821
# Unique:  -0.0018443796611973262
# --------------------------------------------------------------------------------
# Task params {'learn_rate': 0.01831563888873418, 'fp_depth': 3, 'b1': 0.01831563888873418, 'b2': 0.01831563888873418, 'init_scale': 0.01831563888873418, 'fp_length': 20, 'l2_penalty': 0.01831563888873418, 'l1_penalty': 0.006737946999085467, 'conv_width': 10}
# Convnet fingerprints with neural net
# Total number of weights in the network: 9891
# max of weights 0.06962983567500523
# Iteration 0 loss 1.0015408196365463 train RMSE 1.8605440963555582 Train R2 0 : -0.001530451462992577 Validation RMSE 0 : 1.8694340847349085 Validation R2 0 : -0.015949090875271965 Dub RMSE 0 : 2.159168379539997
# Unique RMSE 0 : 1.8258596861743615
# Dub R2 0 : 0.01287676984669528
# Unique R2 0 : -0.027320720409532928
# max of weights 0.06622530347496373
# Iteration 10 loss 0.9843563101898327 train RMSE 1.8445151395058312 Train R2 10 : 0.015651980736639093 Validation RMSE 10 : 1.8452750802264313 Validation R2 10 : 0.010139792097490385 Dub RMSE 10 : 2.1595392720725974
# Unique RMSE 10 : 1.7973102549918136
# Dub R2 10 : 0.012537613268403525
# Unique R2 10 : 0.0045548094409336715
# max of weights 0.07319655519362157
# Iteration 20 loss 0.9817973931474261 train RMSE 1.8421163207474733 Train R2 20 : 0.018210633694498157 Validation RMSE 20 : 1.842750312648219 Validation R2 20 : 0.012846659235501434 Dub RMSE 20 : 2.1576585899879666
# Unique RMSE 20 : 1.7948230781927803
# Dub R2 20 : 0.014256770863397938
# Unique R2 20 : 0.007307962488263597
# max of weights 0.08402873140628807
# Iteration 30 loss 0.9772769291612184 train RMSE 1.8378695642308025 Train R2 30 : 0.022732187863162 Validation RMSE 30 : 1.840696753754687 Validation R2 30 : 0.015045598469010546 Dub RMSE 30 : 2.150086228996275
# Unique RMSE 30 : 1.7946103842035033
# Dub R2 30 : 0.02116361455768656
# Unique R2 30 : 0.007543224806522808
# max of weights 0.09624117372475147
# Iteration 40 loss 0.9717497123141724 train RMSE 1.8326625197888162 Train R2 40 : 0.02826192557601126 Validation RMSE 40 : 1.8343997213491714 Validation R2 40 : 0.021773138722716356 Dub RMSE 40 : 2.1464324088149818
# Unique RMSE 40 : 1.7884391477679416
# Dub R2 40 : 0.024487623777399103
# Unique R2 40 : 0.014357132494278724
# max of weights 0.11032409936608531
# Iteration 50 loss 0.9636074053741966 train RMSE 1.82496446978896 Train R2 50 : 0.0364082999437817 Validation RMSE 50 : 1.8278163707100847 Validation R2 50 : 0.028781921272030164 Dub RMSE 50 : 2.136314982801827
# Unique RMSE 50 : 1.7839119795589482
# Dub R2 50 : 0.03366230209241017
# Unique R2 50 : 0.019340833951436265
# max of weights 0.12550574911104262
# Iteration 60 loss 0.9522494648645269 train RMSE 1.8141715093471202 Train R2 60 : 0.04777208713844672 Validation RMSE 60 : 1.8143904068280776 Validation R2 60 : 0.04299740705099553 Dub RMSE 60 : 2.128628241494374
# Unique RMSE 60 : 1.770984794332313
# Dub R2 60 : 0.04060381073896746
# Unique R2 60 : 0.033502104306081804
# max of weights 0.14117341460004487
# Iteration 70 loss 0.9367292569868925 train RMSE 1.7993190382785351 Train R2 70 : 0.06329988473424197 Validation RMSE 70 : 1.8021960254925735 Validation R2 70 : 0.05581806321699101 Dub RMSE 70 : 2.1068434362400903
# Unique RMSE 70 : 1.7633982267025614
# Dub R2 70 : 0.06014062795547481
# Unique R2 70 : 0.04176496049148748
# max of weights 0.15669689765081898
# Iteration 80 loss 0.9144902508202548 train RMSE 1.7778216310624866 Train R2 80 : 0.08554867107417119 Validation RMSE 80 : 1.7790561342063498 Validation R2 80 : 0.07990867604810414 Dub RMSE 80 : 2.084862237240715
# Unique RMSE 80 : 1.7439507382162132
# Dub R2 80 : 0.07964987498576481
# Unique R2 80 : 0.06278404273225102
# max of weights 0.17220896238088554
# Iteration 90 loss 0.8890674947491587 train RMSE 1.752924065443831 Train R2 90 : 0.11098225412922136 Validation RMSE 90 : 1.7519653855022042 Validation R2 90 : 0.10771688413775415 Dub RMSE 90 : 2.0590768621422466
# Unique RMSE 90 : 1.72058943436529
# Dub R2 90 : 0.10227469677950995
# Unique R2 90 : 0.08772504648601276
#
# Performance (RMSE) on logP:
# Train: 1.7374988928098163
# Test:  1.7946293656919312
# Dub: 2.034374760274564
# Unique:  1.7122168550122385
#
# Performance (R2) on logP:
# Train: 0.12655955876130232
# Test:  0.1159649725152122
# Dub: 0.1236849557267482
# Unique:  0.09658190725689353
# --------------------------------------------------------------------------------
# Loading data...
# Convnet fingerprints with neural net
# FP 0 has linear regression coefficient 0.0206685172037
# radius: 1 atom list: [19, 21, 9, 6] activation 0.0669951431717147
# radius: 2 atom list: [23, 27, 20, 8, 10, 3, 6, 7, 9, 11, 16, 21, 22] activation 0.06626017735905002
# radius: 1 atom list: [2, 7, 15, 17] activation 0.0661369066668209
# radius: 1 atom list: [11, 18, 12, 6] activation 0.06586868289827719
# radius: 1 atom list: [18, 4, 6, 7] activation 0.06559046312641494
# radius: 2 atom list: [6, 11, 13, 18, 20, 5, 12, 19, 24, 1, 4, 3] activation 0.06556422544427828
# radius: 1 atom list: [8, 10, 11, 17] activation 0.0654111971213547
# radius: 1 atom list: [31, 3, 8, 32] activation 0.06540769384069633
# radius: 2 atom list: [9, 11, 31, 18, 19, 25, 28, 30, 10, 8, 7, 5, 6] activation 0.06529389676805747
# radius: 1 atom list: [22, 24, 4, 12] activation 0.0652626128067374
# radius: 1 atom list: [7, 8, 6, 2] activation 0.06499792151103453
# FP 1 has linear regression coefficient -0.0122954244491
# radius: 3 atom list: [0, 3, 5, 4, 6, 8, 7, 2, 1, 10, 9] activation 0.09083896559836457
# radius: 3 atom list: [5, 7, 9, 1, 4, 6, 8, 2, 10, 0, 3] activation 0.09063413689662636
# radius: 3 atom list: [34, 30, 33, 35, 41, 43, 45, 42, 44, 46, 47, 32] activation 0.0896452044291397
# radius: 3 atom list: [2, 0, 3, 5, 6, 1, 4] activation 0.0892125007685188
# radius: 3 atom list: [7, 10, 13, 14, 9, 12, 11, 16, 15] activation 0.08916014540873858
# radius: 3 atom list: [1, 2, 4, 6, 3, 5, 16, 17, 18] activation 0.08897780277938924
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 0, 3, 5, 7, 9] activation 0.08877483938922053
# radius: 3 atom list: [4, 7, 10, 11, 14, 9, 15, 8, 12, 13, 16] activation 0.08873703622375334
# radius: 3 atom list: [7, 1, 3, 6, 0, 2, 4, 5, 8] activation 0.08870212702867324
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 3, 5, 7, 9, 11] activation 0.08867067046559679
# radius: 3 atom list: [0, 2, 32, 33, 1, 3, 5, 4, 31] activation 0.08862961731815436
# FP 2 has linear regression coefficient 0.0169282526112
# radius: 2 atom list: [20, 3, 8, 10, 18, 19, 21] activation 0.06431134960983223
# radius: 1 atom list: [19, 21, 9, 6] activation 0.06407624279592536
# radius: 2 atom list: [21, 3, 5, 17, 18, 20, 19] activation 0.06405245744553231
# radius: 2 atom list: [23, 27, 20, 8, 10, 3, 6, 7, 9, 11, 16, 21, 22] activation 0.06391298157289671
# radius: 2 atom list: [5, 6, 8, 9, 14, 7, 15] activation 0.06390817124582529
# radius: 2 atom list: [3, 7, 9, 14, 16, 13, 15] activation 0.06384498275166076
# radius: 2 atom list: [4, 6, 8, 5, 7, 12, 14] activation 0.06379203026869563
# radius: 2 atom list: [11, 36, 38, 37, 1, 5, 7] activation 0.06378444424484325
# radius: 2 atom list: [5, 7, 6, 8, 9, 18, 21] activation 0.06371828083552296
# radius: 2 atom list: [9, 11, 2, 4, 6, 3, 5] activation 0.06369706544195394
# radius: 2 atom list: [5, 7, 9, 14, 16, 8, 10] activation 0.06368052922515187
# FP 3 has linear regression coefficient -0.0256304061457
# radius: 3 atom list: [0, 3, 5, 4, 6, 8, 7, 2, 1, 10, 9] activation 0.10273511328234254
# radius: 3 atom list: [5, 7, 9, 1, 4, 6, 8, 2, 10, 0, 3] activation 0.10237821179176111
# radius: 3 atom list: [34, 30, 33, 35, 41, 43, 45, 42, 44, 46, 47, 32] activation 0.10073552831717744
# radius: 3 atom list: [2, 0, 3, 5, 6, 1, 4] activation 0.10001761499029095
# radius: 3 atom list: [7, 10, 13, 14, 9, 12, 11, 16, 15] activation 0.09995066338915665
# radius: 3 atom list: [1, 2, 4, 6, 3, 5, 16, 17, 18] activation 0.09966182888234777
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 0, 3, 5, 7, 9] activation 0.09939981253952329
# radius: 3 atom list: [7, 1, 3, 6, 0, 2, 4, 5, 8] activation 0.09927388497075428
# radius: 3 atom list: [4, 7, 10, 11, 14, 9, 15, 8, 12, 13, 16] activation 0.09926514529688635
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 3, 5, 7, 9, 11] activation 0.09923963651257624
# radius: 3 atom list: [0, 2, 32, 33, 1, 3, 5, 4, 31] activation 0.09913396014719324
# FP 4 has linear regression coefficient -0.0370703061898
# radius: 3 atom list: [0, 3, 5, 4, 6, 8, 7, 2, 1, 10, 9] activation 0.09925203115321078
# radius: 3 atom list: [5, 7, 9, 1, 4, 6, 8, 2, 10, 0, 3] activation 0.09895188280117369
# radius: 3 atom list: [34, 30, 33, 35, 41, 43, 45, 42, 44, 46, 47, 32] activation 0.09753845017580777
# radius: 3 atom list: [2, 0, 3, 5, 6, 1, 4] activation 0.09695303982831739
# radius: 3 atom list: [7, 10, 13, 14, 9, 12, 11, 16, 15] activation 0.09687574117479231
# radius: 3 atom list: [1, 2, 4, 6, 3, 5, 16, 17, 18] activation 0.09662608032070982
# radius: 3 atom list: [4, 7, 10, 11, 14, 9, 15, 8, 12, 13, 16] activation 0.0963391644502073
# radius: 3 atom list: [7, 1, 3, 6, 0, 2, 4, 5, 8] activation 0.09622852845867656
# radius: 3 atom list: [0, 2, 32, 33, 1, 3, 5, 4, 31] activation 0.09614877381859363
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 0, 3, 5, 7, 9] activation 0.09609697346056427
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 3, 5, 7, 9, 11] activation 0.09595606140283902
# FP 5 has linear regression coefficient -0.00645436654277
# radius: 2 atom list: [3, 2, 4, 6, 8, 7, 1, 5] activation 0.08756708723241145
# radius: 2 atom list: [2, 1, 4, 0, 5, 6] activation 0.0872801292011519
# radius: 2 atom list: [41, 34, 45, 42, 44, 43, 33, 32] activation 0.08671558422117369
# radius: 2 atom list: [2, 4, 5, 16, 17, 18] activation 0.08646585690288479
# radius: 2 atom list: [18, 19, 11, 13, 12, 17] activation 0.08634280065186281
# radius: 2 atom list: [3, 4, 31, 33, 32, 1] activation 0.08572157828363508
# radius: 2 atom list: [15, 7, 10, 13, 12, 9, 11, 16, 14] activation 0.08539445587919739
# radius: 2 atom list: [4, 5, 8, 9, 10, 3] activation 0.08520601444041259
# radius: 2 atom list: [4, 7, 0, 1, 3, 5, 2, 6] activation 0.08469034313832204
# radius: 2 atom list: [4, 6, 7, 1, 3, 5, 8] activation 0.08458915907647442
# radius: 2 atom list: [0, 2, 1, 3, 5, 4] activation 0.08441813860308146
# FP 6 has linear regression coefficient 0.0292951567481
# radius: 1 atom list: [19, 21, 9, 6] activation 0.07002690713897236
# radius: 1 atom list: [2, 7, 15, 17] activation 0.0689659158510393
# radius: 1 atom list: [11, 18, 12, 6] activation 0.06875526108504873
# radius: 1 atom list: [18, 4, 6, 7] activation 0.06833901176266928
# radius: 1 atom list: [31, 3, 8, 32] activation 0.0683256645700756
# radius: 1 atom list: [22, 24, 4, 12] activation 0.06825788791470085
# radius: 1 atom list: [8, 10, 11, 17] activation 0.06817226278286938
# radius: 1 atom list: [10, 15, 8, 9] activation 0.06779085681802309
# radius: 1 atom list: [7, 8, 6, 2] activation 0.06768546687908711
# radius: 1 atom list: [21, 8, 9, 10] activation 0.06766636409466384
# radius: 1 atom list: [11, 3, 5, 6] activation 0.0675420448025081
# FP 7 has linear regression coefficient 0.0354750095177
# radius: 1 atom list: [19, 21, 9, 6] activation 0.06926733274388064
# radius: 1 atom list: [2, 7, 15, 17] activation 0.06822980378711402
# radius: 1 atom list: [11, 18, 12, 6] activation 0.06800830483249774
# radius: 1 atom list: [18, 4, 6, 7] activation 0.06760699457432108
# radius: 1 atom list: [31, 3, 8, 32] activation 0.06751895290104208
# radius: 1 atom list: [22, 24, 4, 12] activation 0.0674929425488357
# radius: 1 atom list: [8, 10, 11, 17] activation 0.067435212673825
# radius: 1 atom list: [10, 15, 8, 9] activation 0.06703814541864182
# radius: 1 atom list: [7, 8, 6, 2] activation 0.06696186458538345
# radius: 1 atom list: [21, 8, 9, 10] activation 0.06693265875446106
# radius: 1 atom list: [16, 17, 10, 15] activation 0.06681298297434271
# FP 8 has linear regression coefficient 0.0134122458776
# radius: 1 atom list: [19, 21, 9, 6] activation 0.06760730859122933
# radius: 1 atom list: [2, 7, 15, 17] activation 0.06679368318064295
# radius: 1 atom list: [11, 18, 12, 6] activation 0.06659069851202133
# radius: 1 atom list: [18, 4, 6, 7] activation 0.06629715530697182
# radius: 1 atom list: [31, 3, 8, 32] activation 0.06625291341089494
# radius: 1 atom list: [8, 10, 11, 17] activation 0.06615121478652874
# radius: 1 atom list: [22, 24, 4, 12] activation 0.06611921525246486
# radius: 1 atom list: [10, 15, 8, 9] activation 0.06579566783823196
# radius: 1 atom list: [7, 8, 6, 2] activation 0.06576203536704277
# radius: 1 atom list: [21, 8, 9, 10] activation 0.06567696173714549
# radius: 1 atom list: [16, 17, 10, 15] activation 0.06565930956162515
# FP 9 has linear regression coefficient -0.017598316963
# radius: 3 atom list: [0, 3, 5, 4, 6, 8, 7, 2, 1, 10, 9] activation 0.1206100802542086
# radius: 3 atom list: [5, 7, 9, 1, 4, 6, 8, 2, 10, 0, 3] activation 0.11995551408196556
# radius: 3 atom list: [34, 30, 33, 35, 41, 43, 45, 42, 44, 46, 47, 32] activation 0.11702336257222033
# radius: 3 atom list: [2, 0, 3, 5, 6, 1, 4] activation 0.1157963622996299
# radius: 3 atom list: [7, 10, 13, 14, 9, 12, 11, 16, 15] activation 0.11567296697946218
# radius: 3 atom list: [1, 2, 4, 6, 3, 5, 16, 17, 18] activation 0.11518221239548797
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 0, 3, 5, 7, 9] activation 0.11485993145869285
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 3, 5, 7, 9, 11] activation 0.11458853553239895
# radius: 3 atom list: [4, 7, 10, 11, 14, 9, 15, 8, 12, 13, 16] activation 0.11454512731806218
# radius: 3 atom list: [7, 1, 3, 6, 0, 2, 4, 5, 8] activation 0.11450555370300074
# radius: 3 atom list: [0, 2, 32, 33, 1, 3, 5, 4, 31] activation 0.11428191707129948
# FP 10 has linear regression coefficient -0.0104686105987
# radius: 3 atom list: [0, 3, 5, 4, 6, 8, 7, 2, 1, 10, 9] activation 0.0956765260940361
# radius: 3 atom list: [5, 7, 9, 1, 4, 6, 8, 2, 10, 0, 3] activation 0.09544948284814835
# radius: 3 atom list: [34, 30, 33, 35, 41, 43, 45, 42, 44, 46, 47, 32] activation 0.09434437808518631
# radius: 3 atom list: [2, 0, 3, 5, 6, 1, 4] activation 0.0938926759200934
# radius: 3 atom list: [7, 10, 13, 14, 9, 12, 11, 16, 15] activation 0.09381927408039084
# radius: 3 atom list: [1, 2, 4, 6, 3, 5, 16, 17, 18] activation 0.09361979611504101
# radius: 3 atom list: [4, 7, 10, 11, 14, 9, 15, 8, 12, 13, 16] activation 0.09338270425571733
# radius: 3 atom list: [7, 1, 3, 6, 0, 2, 4, 5, 8] activation 0.09327221907920273
# radius: 3 atom list: [0, 2, 32, 33, 1, 3, 5, 4, 31] activation 0.09322383636282232
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 0, 3, 5, 7, 9] activation 0.0932114021290783
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 3, 5, 7, 9, 11] activation 0.09309633258606088
# FP 11 has linear regression coefficient 0.0169177028477
# radius: 2 atom list: [23, 27, 20, 8, 10, 3, 6, 7, 9, 11, 16, 21, 22] activation 0.06901866440290788
# radius: 2 atom list: [6, 11, 13, 18, 20, 5, 12, 19, 24, 1, 4, 3] activation 0.06834936450109132
# radius: 2 atom list: [9, 11, 31, 18, 19, 25, 28, 30, 10, 8, 7, 5, 6] activation 0.06793501095865312
# radius: 2 atom list: [3, 4, 7, 15, 20, 21, 22, 23, 2, 19] activation 0.06671165317906863
# radius: 2 atom list: [3, 9, 11, 15, 17, 21, 0, 2, 1, 4, 10, 16, 5] activation 0.06666815809752716
# radius: 2 atom list: [5, 11, 0, 2, 3, 6, 10, 12, 1, 4, 16] activation 0.06650439341151715
# radius: 2 atom list: [13, 5, 7, 3, 6, 9, 15, 16, 17, 18] activation 0.06649938416160649
# radius: 2 atom list: [0, 2, 11, 3, 16, 1, 10, 9, 4] activation 0.0664864950427374
# radius: 2 atom list: [8, 10, 11, 13, 22, 24, 21, 12, 14, 23, 17] activation 0.06645955945971478
# radius: 2 atom list: [4, 8, 2, 5, 6, 7, 10, 11, 13, 18] activation 0.06635968986975292
# radius: 2 atom list: [12, 8, 10, 6, 9, 13, 16, 17, 18, 14] activation 0.0662869608494538
# FP 12 has linear regression coefficient -0.01066256947
# radius: 3 atom list: [0, 3, 5, 4, 6, 8, 7, 2, 1, 10, 9] activation 0.10034740432967898
# radius: 3 atom list: [5, 7, 9, 1, 4, 6, 8, 2, 10, 0, 3] activation 0.10001208769930942
# radius: 3 atom list: [34, 30, 33, 35, 41, 43, 45, 42, 44, 46, 47, 32] activation 0.09845122939141514
# radius: 3 atom list: [2, 0, 3, 5, 6, 1, 4] activation 0.09778882908647712
# radius: 3 atom list: [7, 10, 13, 14, 9, 12, 11, 16, 15] activation 0.09771076365778882
# radius: 3 atom list: [1, 2, 4, 6, 3, 5, 16, 17, 18] activation 0.09743739501120247
# radius: 3 atom list: [4, 7, 10, 11, 14, 9, 15, 8, 12, 13, 16] activation 0.09708742891611805
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 0, 3, 5, 7, 9] activation 0.09707213774448331
# radius: 3 atom list: [7, 1, 3, 6, 0, 2, 4, 5, 8] activation 0.09703193435640178
# radius: 3 atom list: [0, 2, 32, 33, 1, 3, 5, 4, 31] activation 0.09692153302924106
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 3, 5, 7, 9, 11] activation 0.09691820045912501
# FP 13 has linear regression coefficient -0.019693963584
# radius: 3 atom list: [0, 3, 5, 4, 6, 8, 7, 2, 1, 10, 9] activation 0.09686448990023876
# radius: 3 atom list: [5, 7, 9, 1, 4, 6, 8, 2, 10, 0, 3] activation 0.09661971678910115
# radius: 3 atom list: [34, 30, 33, 35, 41, 43, 45, 42, 44, 46, 47, 32] activation 0.09546331675683599
# radius: 3 atom list: [2, 0, 3, 5, 6, 1, 4] activation 0.09494148814455165
# radius: 3 atom list: [7, 10, 13, 14, 9, 12, 11, 16, 15] activation 0.09489225966481231
# radius: 3 atom list: [1, 2, 4, 6, 3, 5, 16, 17, 18] activation 0.094680271918028
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 0, 3, 5, 7, 9] activation 0.09455043395288354
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 3, 5, 7, 9, 11] activation 0.0944302173087453
# radius: 3 atom list: [4, 7, 10, 11, 14, 9, 15, 8, 12, 13, 16] activation 0.09439947216325323
# radius: 3 atom list: [7, 1, 3, 6, 0, 2, 4, 5, 8] activation 0.09439431489169885
# radius: 3 atom list: [0, 2, 32, 33, 1, 3, 5, 4, 31] activation 0.0942869902235412
# FP 14 has linear regression coefficient -0.0082072909877
# radius: 3 atom list: [0, 3, 5, 4, 6, 8, 7, 2, 1, 10, 9] activation 0.09844370705456625
# radius: 3 atom list: [5, 7, 9, 1, 4, 6, 8, 2, 10, 0, 3] activation 0.09816630906352544
# radius: 3 atom list: [34, 30, 33, 35, 41, 43, 45, 42, 44, 46, 47, 32] activation 0.09684689987311629
# radius: 3 atom list: [2, 0, 3, 5, 6, 1, 4] activation 0.09629840753465403
# radius: 3 atom list: [7, 10, 13, 14, 9, 12, 11, 16, 15] activation 0.0962209550935152
# radius: 3 atom list: [1, 2, 4, 6, 3, 5, 16, 17, 18] activation 0.0959866903837277
# radius: 3 atom list: [4, 7, 10, 11, 14, 9, 15, 8, 12, 13, 16] activation 0.09570890096385277
# radius: 3 atom list: [7, 1, 3, 6, 0, 2, 4, 5, 8] activation 0.09560663230752334
# radius: 3 atom list: [0, 2, 32, 33, 1, 3, 5, 4, 31] activation 0.09553254284657253
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 0, 3, 5, 7, 9] activation 0.09549277578483717
# radius: 3 atom list: [1, 2, 4, 6, 8, 10, 3, 5, 7, 9, 11] activation 0.0953592593161811
# FP 15 has linear regression coefficient 0.0278415070525
# radius: 2 atom list: [20, 3, 8, 10, 18, 19, 21] activation 0.06708198409499878
# radius: 1 atom list: [19, 21, 9, 6] activation 0.06698235123353496
# radius: 2 atom list: [21, 3, 5, 17, 18, 20, 19] activation 0.06671404889172124
# radius: 2 atom list: [5, 6, 8, 9, 14, 7, 15] activation 0.06651353162969725
# radius: 2 atom list: [23, 27, 20, 8, 10, 3, 6, 7, 9, 11, 16, 21, 22] activation 0.06645539474869815
# radius: 2 atom list: [3, 7, 9, 14, 16, 13, 15] activation 0.06641719352808714
# radius: 2 atom list: [4, 6, 8, 5, 7, 12, 14] activation 0.06634545139190547
# radius: 2 atom list: [11, 36, 38, 37, 1, 5, 7] activation 0.06634078318969364
# radius: 2 atom list: [5, 7, 6, 8, 9, 18, 21] activation 0.06623775132147576
# radius: 2 atom list: [9, 11, 2, 4, 6, 3, 5] activation 0.06621288142654783
# radius: 2 atom list: [5, 7, 9, 14, 16, 8, 10] activation 0.06618563185750641
# FP 16 has linear regression coefficient 0.0140721847272
# radius: 2 atom list: [23, 27, 20, 8, 10, 3, 6, 7, 9, 11, 16, 21, 22] activation 0.06357167439146565
# radius: 2 atom list: [3, 4, 7, 15, 20, 21, 22, 23, 2, 19] activation 0.0631035595879226
# radius: 2 atom list: [6, 11, 13, 18, 20, 5, 12, 19, 24, 1, 4, 3] activation 0.06309002621500213
# radius: 2 atom list: [13, 5, 7, 3, 6, 9, 15, 16, 17, 18] activation 0.06294828412841483
# radius: 2 atom list: [9, 11, 31, 18, 19, 25, 28, 30, 10, 8, 7, 5, 6] activation 0.06287213313457231
# radius: 2 atom list: [4, 8, 2, 5, 6, 7, 10, 11, 13, 18] activation 0.06284472332285511
# radius: 2 atom list: [12, 8, 10, 6, 9, 13, 16, 17, 18, 14] activation 0.06279260477443553
# radius: 2 atom list: [2, 7, 9, 14, 3, 4, 8, 10, 15, 16] activation 0.06273712521369477
# radius: 2 atom list: [17, 3, 8, 10, 13, 18, 19, 20, 9, 11] activation 0.06270634515475747
# radius: 2 atom list: [3, 7, 9, 1, 4, 5, 6, 10, 11, 16] activation 0.06268877671232959
# radius: 2 atom list: [2, 4, 6, 7, 8, 16, 18, 19, 9, 5] activation 0.0626575658290455
# FP 17 has linear regression coefficient 0.0335795612663
# radius: 2 atom list: [23, 27, 20, 8, 10, 3, 6, 7, 9, 11, 16, 21, 22] activation 0.06832157586457796
# radius: 2 atom list: [6, 11, 13, 18, 20, 5, 12, 19, 24, 1, 4, 3] activation 0.0676275359983886
# radius: 2 atom list: [9, 11, 31, 18, 19, 25, 28, 30, 10, 8, 7, 5, 6] activation 0.06725289696531431
# radius: 2 atom list: [3, 4, 7, 15, 20, 21, 22, 23, 2, 19] activation 0.06693650434695446
# radius: 2 atom list: [13, 5, 7, 3, 6, 9, 15, 16, 17, 18] activation 0.06671620849453624
# radius: 2 atom list: [4, 8, 2, 5, 6, 7, 10, 11, 13, 18] activation 0.06656969488865001
# radius: 2 atom list: [12, 8, 10, 6, 9, 13, 16, 17, 18, 14] activation 0.06649580533643867
# radius: 2 atom list: [2, 7, 9, 14, 3, 4, 8, 10, 15, 16] activation 0.06641728695129291
# radius: 2 atom list: [17, 3, 8, 10, 13, 18, 19, 20, 9, 11] activation 0.06637380251100607
# radius: 2 atom list: [3, 7, 9, 1, 4, 5, 6, 10, 11, 16] activation 0.0663492218154781
# radius: 2 atom list: [2, 4, 6, 7, 8, 16, 18, 19, 9, 5] activation 0.06630508059004185
# FP 18 has linear regression coefficient -0.00453422356968
# radius: 2 atom list: [3, 2, 4, 6, 8, 7, 1, 5] activation 0.08039629801372046
# radius: 2 atom list: [2, 1, 4, 0, 5, 6] activation 0.0801660257896739
# radius: 2 atom list: [41, 34, 45, 42, 44, 43, 33, 32] activation 0.07971168796464309
# radius: 2 atom list: [2, 4, 5, 16, 17, 18] activation 0.07951094784326161
# radius: 2 atom list: [18, 19, 11, 13, 12, 17] activation 0.07941101712444762
# radius: 2 atom list: [3, 4, 31, 33, 32, 1] activation 0.07890883692297432
# radius: 2 atom list: [15, 7, 10, 13, 12, 9, 11, 16, 14] activation 0.07864185033476567
# radius: 2 atom list: [4, 5, 8, 9, 10, 3] activation 0.07849078870880072
# radius: 2 atom list: [4, 7, 0, 1, 3, 5, 2, 6] activation 0.07807105926282375
# radius: 2 atom list: [4, 6, 7, 1, 3, 5, 8] activation 0.0779874954718166
# radius: 2 atom list: [0, 2, 1, 3, 5, 4] activation 0.07784954724395896
# FP 19 has linear regression coefficient 0.013986844022
# radius: 1 atom list: [19, 21, 9, 6] activation 0.06908628750240578
# radius: 1 atom list: [2, 7, 15, 17] activation 0.06792809753379403
# radius: 1 atom list: [11, 18, 12, 6] activation 0.06771820550182
# radius: 1 atom list: [18, 4, 6, 7] activation 0.06725092929580465
# radius: 1 atom list: [31, 3, 8, 32] activation 0.06724209703258142
# radius: 1 atom list: [22, 24, 4, 12] activation 0.0672196677415178
# radius: 1 atom list: [8, 10, 11, 17] activation 0.06707734869669083
# radius: 1 atom list: [10, 15, 8, 9] activation 0.06669145844245197
# radius: 1 atom list: [21, 8, 9, 10] activation 0.0665710695944369
# radius: 1 atom list: [7, 8, 6, 2] activation 0.06655534940025987
# radius: 1 atom list: [11, 3, 5, 6] activation 0.06639831152477421

# %%
task_params = {'target_name' : 'logP',
               'data_file'   : 'logp_mean'}

num_epochs = 5
batch_size = 100
normalize = 1
dropout = 0
activation = relu
params = {'fp_length': 50,
            'fp_depth': 4,
            'init_scale':np.exp(-4),
            'learn_rate':np.exp(-4),
                    'b1':np.exp(-4),
                    'b2':np.exp(-4),
            'l2_penalty':np.exp(-4),
            'l1_penalty':np.exp(-5),
            'conv_width':20}

conv_layer_sizes = [params['conv_width']] * params['fp_depth']
conv_arch_params = {'num_hidden_features' : conv_layer_sizes,
                    'fp_length' : params['fp_length'],
                    'normalize' : normalize,
                    'return_atom_activations':False}

all_radii = range(params['fp_depth'] + 1)

# Plotting parameters
num_figs_per_fp = 11
figsize = (100, 100)
highlight_color = (30.0/255.0, 100.0/255.0, 255.0/255.0)  # A nice light blue.

# %%
trained_network_weights = train_neural_fingerprint()
with open('results.pkl', 'w') as f:
    pickle.dump(trained_network_weights, f)

# Plotting.
with open('results.pkl') as f:
    trained_weights = pickle.load(f)
plot(trained_weights)
# Out:
# Loading data...
# Regression on 9631 training points.
# --------------------------------------------------------------------------------
# Mean predictor
#
# Performance (RMSE) on logP:
# Train: 1.8591219922763682
# Test:  1.9087278157747403
# Dub: 2.178198827192713
# Unique:  1.8030779775623207
#
# Performance (R2) on logP:
# Train: 0.0
# Test:  -1.8278865013598988e-05
# Dub: -0.004600498132678821
# Unique:  -0.0018443796611973262
# --------------------------------------------------------------------------------
# Task params {'learn_rate': 0.01831563888873418, 'fp_depth': 4, 'b1': 0.01831563888873418, 'b2': 0.01831563888873418, 'init_scale': 0.01831563888873418, 'fp_length': 50, 'l2_penalty': 0.01831563888873418, 'l1_penalty': 0.006737946999085467, 'conv_width': 20}
# Convnet fingerprints with neural net
# Total number of weights in the network: 30571
# max of weights 0.08535001578936458
# Iteration 0 loss 1.0049397981323287 train RMSE 1.86369714187141 Train R2 0 : -0.004927895158615581 Validation RMSE 0 : 1.8582204651665832 Validation R2 0 : -0.00379750083632735 Dub RMSE 0 : 2.1849295612650397
# Unique RMSE 0 : 1.804783763283979
# Dub R2 0 : -0.010818613482577177
# Unique R2 0 : -0.003740848054946122
# max of weights 0.08124790290117585
# Iteration 10 loss 0.9831377086854514 train RMSE 1.84337090138825 Train R2 10 : 0.016872875207637694 Validation RMSE 10 : 1.8445288524301713 Validation R2 10 : 0.01094022760161295 Dub RMSE 10 : 2.157665827611346
# Unique RMSE 10 : 1.796991169032218
# Dub R2 10 : 0.014250157722430656
# Unique R2 10 : 0.0049082313250844445
# max of weights 0.08121948753056427
# Iteration 20 loss 0.979152026744827 train RMSE 1.8396305590850655 Train R2 20 : 0.02085850965297753 Validation RMSE 20 : 1.840171331299673 Validation R2 20 : 0.015607823937882959 Dub RMSE 20 : 2.1548686384651217
# Unique RMSE 20 : 1.7926666068778798
# Dub R2 20 : 0.016804345149964983
# Unique R2 20 : 0.009691958885322594
# max of weights 0.0927685805126056
# Iteration 30 loss 0.9704066182490682 train RMSE 1.8313953356880313 Train R2 30 : 0.029605266548489384 Validation RMSE 30 : 1.8341634841706203 Validation R2 30 : 0.022025078003656606 Dub RMSE 30 : 2.14261513567299
# Unique RMSE 30 : 1.789231539444854
# Dub R2 30 : 0.027954293333449565
# Unique R2 30 : 0.013483534725894697
# max of weights 0.1058153308543096
# Iteration 40 loss 0.9560897438784289 train RMSE 1.8178322875825654 Train R2 40 : 0.04392524877983994 Validation RMSE 40 : 1.8199695092152208 Validation R2 40 : 0.03710294877285647 Dub RMSE 40 : 2.1285667469815825
# Unique RMSE 40 : 1.7767945395199938
# Dub R2 40 : 0.04065924244647123
# Unique R2 40 : 0.02715047809029225
# max of weights 0.11995524063427628
# Iteration 50 loss 0.9329016033632618 train RMSE 1.7956477552446308 Train R2 50 : 0.06711842147678193 Validation RMSE 50 : 1.7985385716297335 Validation R2 50 : 0.05964650106025804 Dub RMSE 50 : 2.1027270788011596
# Unique RMSE 50 : 1.7592118344773373
# Dub R2 50 : 0.06380964067573225
# Unique R2 50 : 0.04630935194546992
# max of weights 0.13417589497512683
# Iteration 60 loss 0.8978345307445065 train RMSE 1.7615680573230736 Train R2 60 : 0.10219281530416857 Validation RMSE 60 : 1.7618649326419311 Validation R2 60 : 0.09760463534128716 Dub RMSE 60 : 2.068399846181689
# Unique RMSE 60 : 1.7254536823661333
# Dub R2 60 : 0.09412694253196041
# Unique R2 60 : 0.08255960240769222
# max of weights 0.14773444477099537
# Iteration 70 loss 0.8508204964239643 train RMSE 1.7148159307401412 Train R2 70 : 0.1492161402737595 Validation RMSE 70 : 1.7187326723313388 Validation R2 70 : 0.141246939034938 Dub RMSE 70 : 2.0035050219481496
# Unique RMSE 70 : 1.689114960695127
# Dub R2 70 : 0.15007770805411869
# Unique R2 70 : 0.12079597997435043
# max of weights 0.1617460019193778
# Iteration 80 loss 0.7871469980492134 train RMSE 1.6493871312019917 Train R2 80 : 0.21290087984764694 Validation RMSE 80 : 1.6496580327899177 Validation R2 80 : 0.20888524470580838 Dub RMSE 80 : 1.9260514907168143
# Unique RMSE 80 : 1.6236809844594384
# Dub R2 80 : 0.21452180036858426
# Unique R2 80 : 0.18759486998922703
# max of weights 0.17534829089031428
# Iteration 90 loss 0.7154415651224834 train RMSE 1.57244943797842 Train R2 90 : 0.28461866864481 Validation RMSE 90 : 1.574201187312761 Validation R2 90 : 0.27960265472004975 Dub RMSE 90 : 1.8093148064698052
# Unique RMSE 90 : 1.5541548002772079
# Dub R2 90 : 0.3068509634691614
# Unique R2 90 : 0.25567981544378493
# max of weights 0.18552927274647035
# Iteration 100 loss 0.630725331258254 train RMSE 1.4763949899530113 Train R2 100 : 0.36934862220642406 Validation RMSE 100 : 1.4755982743818028 Validation R2 100 : 0.36702302889358396 Dub RMSE 100 : 1.661474246908021
# Unique RMSE 100 : 1.4534122966103764
# Dub R2 100 : 0.4154985706789158
# Unique R2 100 : 0.3490480856385807
# max of weights 0.19443165890850303
# Iteration 110 loss 0.5615798450758085 train RMSE 1.3930915529893 Train R2 110 : 0.4385080411416238 Validation RMSE 110 : 1.3855848137981917 Validation R2 110 : 0.4418924957288075 Dub RMSE 110 : 1.5456494455440053
# Unique RMSE 110 : 1.3610701833662695
# Dub R2 110 : 0.4941516306988174
# Unique R2 110 : 0.4291364836682402
# max of weights 0.20800636711373907
# Iteration 120 loss 0.505453939011549 train RMSE 1.3216154695479254 Train R2 120 : 0.4946474631359429 Validation RMSE 120 : 1.317940755417405 Validation R2 120 : 0.49505577596406125 Dub RMSE 120 : 1.397524603313927
# Unique RMSE 120 : 1.3022211316721732
# Dub R2 120 : 0.5864602373772927
# Unique R2 120 : 0.4774345106588237
# max of weights 0.22255888933495818
# Iteration 130 loss 0.4684858645846397 train RMSE 1.2723436871267697 Train R2 130 : 0.531625651485104 Validation RMSE 130 : 1.2582014903627554 Validation R2 130 : 0.5397942686064928 Dub RMSE 130 : 1.3411327683686889
# Unique RMSE 130 : 1.2294717911761115
# Dub R2 130 : 0.6191605780915802
# Unique R2 130 : 0.5341904526648139
# max of weights 0.23572915371136932
# Iteration 140 loss 0.41809164934954146 train RMSE 1.2019338940237847 Train R2 140 : 0.5820297337365992 Validation RMSE 140 : 1.1869762478101522 Validation R2 140 : 0.5904228784272623 Dub RMSE 140 : 1.2244640374219948
# Unique RMSE 140 : 1.1734300673495193
# Dub R2 140 : 0.6825389720204116
# Unique R2 140 : 0.5756876500914776
# max of weights 0.24683040588410576
# Iteration 150 loss 0.3801088393783648 train RMSE 1.1460088588637176 Train R2 150 : 0.6200204947255956 Validation RMSE 150 : 1.1297922918165288 Validation R2 150 : 0.628935978329975 Dub RMSE 150 : 1.1835239302108944
# Unique RMSE 150 : 1.1122331941900818
# Dub R2 150 : 0.7034127777657614
# Unique R2 150 : 0.6187911691575808
# max of weights 0.2565983713744351
# Iteration 160 loss 0.35639123176206133 train RMSE 1.109653464600781 Train R2 160 : 0.6437466390395007 Validation RMSE 160 : 1.09129719867105 Validation R2 160 : 0.6537915104109048 Dub RMSE 160 : 1.1458394318596914
# Unique RMSE 160 : 1.0708153681929582
# Dub R2 160 : 0.7219993082409364
# Unique R2 160 : 0.6466537886560011
# max of weights 0.2611059411370303
# Iteration 170 loss 0.340936908020668 train RMSE 1.0853073088519665 Train R2 170 : 0.6592077744078062 Validation RMSE 170 : 1.0724594767271283 Validation R2 170 : 0.6656406941905176 Dub RMSE 170 : 1.0843692655810027
# Unique RMSE 170 : 1.0634755731264152
# Dub R2 170 : 0.7510267152529299
# Unique R2 170 : 0.6514811388285986
# max of weights 0.26473556151001615
# Iteration 180 loss 0.35074811044067344 train RMSE 1.1008113687035848 Train R2 180 : 0.6494015146219482 Validation RMSE 180 : 1.0815138342611104 Validation R2 180 : 0.6599711311316312 Dub RMSE 180 : 1.1378882754714212
# Unique RMSE 180 : 1.0685933907844305
# Dub R2 180 : 0.7258441012691258
# Unique R2 180 : 0.6481186774495278
# max of weights 0.2695266662024905
# Iteration 190 loss 0.3292002094049448 train RMSE 1.066441282350524 Train R2 190 : 0.6709528601282495 Validation RMSE 190 : 1.0470336494122743 Validation R2 190 : 0.6813067164028785 Dub RMSE 190 : 1.0822897690729707
# Unique RMSE 190 : 1.0420624146282322
# Dub R2 190 : 0.7519807124901352
# Unique R2 190 : 0.6653747474572715
# max of weights 0.2739887655201054
# Iteration 200 loss 0.3051791456002657 train RMSE 1.0267701687312742 Train R2 200 : 0.6949783204333538 Validation RMSE 200 : 1.001382372753687 Validation R2 200 : 0.7084913024325652 Dub RMSE 200 : 1.0755464973986208
# Unique RMSE 200 : 0.9861618128434116
# Dub R2 200 : 0.7550616826662968
# Unique R2 200 : 0.7003132025475702
# max of weights 0.2799464150019621
# Iteration 210 loss 0.2915834895508801 train RMSE 1.003618207154074 Train R2 210 : 0.7085787033094347 Validation RMSE 210 : 0.9824098394676521 Validation R2 210 : 0.7194327085175308 Dub RMSE 210 : 1.0318291807552724
# Unique RMSE 210 : 0.9712784240065011
# Dub R2 210 : 0.774568832063946
# Unique R2 210 : 0.7092908301688576
# max of weights 0.2870569164738435
# Iteration 220 loss 0.29272653611032734 train RMSE 1.0055798135722693 Train R2 220 : 0.7074384040591195 Validation RMSE 220 : 0.9869747301019479 Validation R2 220 : 0.7168192684778716 Dub RMSE 220 : 1.0411395772038996
# Unique RMSE 220 : 0.9781808088422429
# Dub R2 220 : 0.7704822588837228
# Unique R2 220 : 0.705144302429876
# max of weights 0.2931865823105432
# Iteration 230 loss 0.28310939381582834 train RMSE 0.9889094064375857 Train R2 230 : 0.7170581172358654 Validation RMSE 230 : 0.9640463592153821 Validation R2 230 : 0.7298235629315631 Dub RMSE 230 : 1.0338277883490294
# Unique RMSE 230 : 0.945969083386725
# Dub R2 230 : 0.7736946858414011
# Unique R2 230 : 0.724243896526789
# max of weights 0.3006948478262516
# Iteration 240 loss 0.27702367451954346 train RMSE 0.9782111912736784 Train R2 240 : 0.7231468447324041 Validation RMSE 240 : 0.950598167375955 Validation R2 240 : 0.737308767651672 Dub RMSE 240 : 1.0191665085122126
# Unique RMSE 240 : 0.9370426676272802
# Dub R2 240 : 0.7800678921222094
# Unique R2 240 : 0.7294235581506956
# max of weights 0.29682144225121376
# Iteration 250 loss 0.26879528154653926 train RMSE 0.9635589094943474 Train R2 250 : 0.7313785022848699 Validation RMSE 250 : 0.9425334993511122 Validation R2 250 : 0.7417470910846655 Dub RMSE 250 : 0.9909773503493984
# Unique RMSE 250 : 0.9288702236002316
# Dub R2 250 : 0.7920658572475032
# Unique R2 250 : 0.7341226568613659
# max of weights 0.299425469522788
# Iteration 260 loss 0.2666226550582131 train RMSE 0.9596498005013017 Train R2 260 : 0.7335536483203666 Validation RMSE 260 : 0.9348729201435897 Validation R2 260 : 0.7459280080118609 Dub RMSE 260 : 0.993564654236424
# Unique RMSE 260 : 0.9237020570713351
# Dub R2 260 : 0.7909786656531734
# Unique R2 260 : 0.7370730705121142
# max of weights 0.301721515788163
# Iteration 270 loss 0.26471489113085067 train RMSE 0.9562048081038231 Train R2 270 : 0.7354632159285996 Validation RMSE 270 : 0.9376089468722746 Validation R2 270 : 0.744438682637075 Dub RMSE 270 : 0.9721244350994673
# Unique RMSE 270 : 0.9300679959136837
# Dub R2 270 : 0.7999023129451913
# Unique R2 270 : 0.7334365204373345
# max of weights 0.3036787882295564
# Iteration 280 loss 0.2835905595280446 train RMSE 0.9897301606476875 Train R2 280 : 0.7165882620420603 Validation RMSE 280 : 0.9686021076522189 Validation R2 280 : 0.7272640093004348 Dub RMSE 280 : 1.0583426538198892
# Unique RMSE 280 : 0.9493195593853343
# Dub R2 280 : 0.7628348083536864
# Unique R2 280 : 0.7222870664296301
# max of weights 0.30838913538124496
# Iteration 290 loss 0.27422194105787884 train RMSE 0.9732331651072925 Train R2 290 : 0.7259574352112412 Validation RMSE 290 : 0.9550542453049966 Validation R2 290 : 0.7348401825771854 Dub RMSE 290 : 1.009987811336114
# Unique RMSE 290 : 0.946511795997282
# Dub R2 290 : 0.7840115067443199
# Unique R2 290 : 0.7239273972941216
# max of weights 0.30494586556576764
# Iteration 300 loss 0.2593046376705225 train RMSE 0.946369655710355 Train R2 300 : 0.7408770754224363 Validation RMSE 300 : 0.9289012893361639 Validation R2 300 : 0.7491634817580335 Dub RMSE 300 : 1.000316257400041
# Unique RMSE 300 : 0.9090093319823923
# Dub R2 300 : 0.7881282744231958
# Unique R2 300 : 0.7453709606297507
# max of weights 0.3078347860074837
# Iteration 310 loss 0.24978110271569803 train RMSE 0.9288120775803327 Train R2 310 : 0.7504026722671759 Validation RMSE 310 : 0.9129602515569092 Validation R2 310 : 0.7576989077921192 Dub RMSE 310 : 0.9644186826697068
# Unique RMSE 310 : 0.8975293423810855
# Dub R2 310 : 0.8030619745475963
# Unique R2 310 : 0.7517618309639087
# max of weights 0.31168615293905383
# Iteration 320 loss 0.2494136810169502 train RMSE 0.9281269768659338 Train R2 320 : 0.750770747244454 Validation RMSE 320 : 0.9066789839928514 Validation R2 320 : 0.7610215549039308 Dub RMSE 320 : 0.9977689618123382
# Unique RMSE 320 : 0.8851428408044518
# Dub R2 320 : 0.7892059590803312
# Unique R2 320 : 0.7585662554409227
# max of weights 0.3189199907236842
# Iteration 330 loss 0.24959391413023715 train RMSE 0.9284587330179344 Train R2 330 : 0.7505925429310902 Validation RMSE 330 : 0.9117360995826311 Validation R2 330 : 0.7583482558910764 Dub RMSE 330 : 0.9452900486968363
# Unique RMSE 330 : 0.8968540039417343
# Dub R2 330 : 0.8107967808097758
# Unique R2 330 : 0.7521352598832685
# max of weights 0.32654298488014377
# Iteration 340 loss 0.24896117854011185 train RMSE 0.9272771842382174 Train R2 340 : 0.7512269266854366 Validation RMSE 340 : 0.9029205035503318 Validation R2 340 : 0.7629987357373664 Dub RMSE 340 : 0.9927925060003658
# Unique RMSE 340 : 0.8828819732072287
# Dub R2 340 : 0.7913034210472611
# Unique R2 340 : 0.7597980399374005
# max of weights 0.33646568635190083
# Iteration 350 loss 0.23906176515791175 train RMSE 0.9086356767469818 Train R2 350 : 0.7611287988965081 Validation RMSE 350 : 0.8887664434167379 Validation R2 350 : 0.7703708965239959 Dub RMSE 350 : 0.9548718447518069
# Unique RMSE 350 : 0.8666488657615281
# Dub R2 350 : 0.806941678780515
# Unique R2 350 : 0.7685497820836967
# max of weights 0.3478666119428942
# Iteration 360 loss 0.2406768225634007 train RMSE 0.911699353467383 Train R2 360 : 0.7595152635390878 Validation RMSE 360 : 0.891771853290951 Validation R2 360 : 0.7688152652676425 Dub RMSE 360 : 0.9495596174172871
# Unique RMSE 360 : 0.876166303262297
# Dub R2 360 : 0.8090837817796613
# Unique R2 360 : 0.763438349784803
# max of weights 0.3561881440449825
# Iteration 370 loss 0.24212906855446928 train RMSE 0.9144459116349776 Train R2 370 : 0.7580641267715534 Validation RMSE 370 : 0.8980245994095752 Validation R2 370 : 0.7655619506031301 Dub RMSE 370 : 0.9444449371040672
# Unique RMSE 370 : 0.8822785068585962
# Dub R2 370 : 0.8111349338622286
# Unique R2 370 : 0.7601262927839951
# max of weights 0.3622667555669886
# Iteration 380 loss 0.24251294764430564 train RMSE 0.9151715910817451 Train R2 380 : 0.7576799869304575 Validation RMSE 380 : 0.9043838484168562 Validation R2 380 : 0.7622299069872852 Dub RMSE 380 : 0.9461731314292822
# Unique RMSE 380 : 0.8828821574871215
# Dub R2 380 : 0.8104431112891278
# Unique R2 380 : 0.7597979396648897
# max of weights 0.36655119961272903
# Iteration 390 loss 0.24846525136018088 train RMSE 0.9263419407255696 Train R2 390 : 0.7517284942334648 Validation RMSE 390 : 0.9091795801182837 Validation R2 390 : 0.7597015449533325 Dub RMSE 390 : 0.9857131466531114
# Unique RMSE 390 : 0.8938307116240453
# Dub R2 390 : 0.7942691373357178
# Unique R2 390 : 0.7538035459217085
# max of weights 0.3724570246870544
# Iteration 400 loss 0.23918698981217493 train RMSE 0.9088640104768961 Train R2 400 : 0.7610087305197821 Validation RMSE 400 : 0.8961562450118872 Validation R2 400 : 0.7665364399745745 Dub RMSE 400 : 0.9641934244373891
# Unique RMSE 400 : 0.8694654745794412
# Dub R2 400 : 0.8031539610084659
# Unique R2 400 : 0.7670429109720697
# max of weights 0.38188308642127056
# Iteration 410 loss 0.2377278939069188 train RMSE 0.9060825218004364 Train R2 410 : 0.762469310538267 Validation RMSE 410 : 0.8966039463925078 Validation R2 410 : 0.7663031144417803 Dub RMSE 410 : 0.9322322860112644
# Unique RMSE 410 : 0.8787090461614947
# Dub R2 410 : 0.8159877952001615
# Unique R2 410 : 0.7620632950944717
# max of weights 0.3889708825795928
# Iteration 420 loss 0.25773248280864375 train RMSE 0.9434649672986234 Train R2 420 : 0.7424652841444356 Validation RMSE 420 : 0.9219740182649714 Validation R2 420 : 0.7528907528106159 Dub RMSE 420 : 1.0363785505971295
# Unique RMSE 420 : 0.8807110485965451
# Dub R2 420 : 0.772576582451495
# Unique R2 420 : 0.7609778561556655
# max of weights 0.39528678805900175
# Iteration 430 loss 0.23673575857153828 train RMSE 0.9041833919893898 Train R2 430 : 0.7634639856430845 Validation RMSE 430 : 0.8934350519701665 Validation R2 430 : 0.7679521191489463 Dub RMSE 430 : 0.908604963226048
# Unique RMSE 430 : 0.8762431985086098
# Dub R2 430 : 0.8251971299107705
# Unique R2 430 : 0.7633968251004561
# max of weights 0.4031495033978565
# Iteration 440 loss 0.22782546868714487 train RMSE 0.8869869686814482 Train R2 440 : 0.7723756586904995 Validation RMSE 440 : 0.8684908737920094 Validation R2 440 : 0.7807285185151123 Dub RMSE 440 : 0.9495828133906139
# Unique RMSE 440 : 0.8427830938223566
# Dub R2 440 : 0.8090744542103037
# Unique R2 440 : 0.7811216136422121
# max of weights 0.41426978828831534
# Iteration 450 loss 0.2235120485593555 train RMSE 0.8785384946781994 Train R2 450 : 0.7766912119521059 Validation RMSE 450 : 0.8603965664981735 Validation R2 450 : 0.7847966786512088 Dub RMSE 450 : 0.9405698714467657
# Unique RMSE 450 : 0.8312437919329283
# Dub R2 450 : 0.8126815843438892
# Unique R2 450 : 0.7870743029018703
# max of weights 0.42358427072231875
# Iteration 460 loss 0.22396255300439877 train RMSE 0.8794219096393633 Train R2 460 : 0.7762418895600199 Validation RMSE 460 : 0.866148619598421 Validation R2 460 : 0.7819096408652477 Dub RMSE 460 : 0.9119514475637991
# Unique RMSE 460 : 0.8467868347545268
# Dub R2 460 : 0.8239071252289752
# Unique R2 460 : 0.7790370585024567
# max of weights 0.43145561835070007
# Iteration 470 loss 0.23435383706144183 train RMSE 0.8996084028815009 Train R2 470 : 0.7658515808304875 Validation RMSE 470 : 0.8859635527072763 Validation R2 470 : 0.7718169690874783 Dub RMSE 470 : 0.946647375942116
# Unique RMSE 470 : 0.8589832274100951
# Dub R2 470 : 0.810253042811296
# Unique R2 470 : 0.7726260975202389
# max of weights 0.4362707323849664
# Iteration 480 loss 0.23778323000314305 train RMSE 0.9061734825040294 Train R2 480 : 0.7624216172153773 Validation RMSE 480 : 0.9032223008681539 Validation R2 480 : 0.7628402759410028 Dub RMSE 480 : 0.9134011445983755
# Unique RMSE 480 : 0.8797161398259937
# Dub R2 480 : 0.8233468229784559
# Unique R2 480 : 0.7615175812050576
#
# Performance (RMSE) on logP:
# Train: 0.9022990103258304
# Test:  0.9084827821728971
# Dub: 0.9168222718007975
# Unique:  0.8755029552650632
#
# Performance (R2) on logP:
# Train: 0.7644488736027254
# Test:  0.7734555980129914
# Dub: 0.8220210423192322
# Unique:  0.7637964171813661
# --------------------------------------------------------------------------------
# Loading data...
# Convnet fingerprints with neural net
# FP 0 has linear regression coefficient -0.0361844281874
# radius: 1 atom list: [17, 15, 16, 13, 18, 14] activation 0.035076939989457406
# radius: 1 atom list: [0, 1] activation 0.03463331714431711
# radius: 1 atom list: [1, 0] activation 0.034581668455822535
# radius: 1 atom list: [7, 8] activation 0.034539298677015925
# radius: 1 atom list: [1, 0] activation 0.03451343073259317
# radius: 1 atom list: [5, 7] activation 0.03444674420465267
# radius: 1 atom list: [11, 8] activation 0.034421588092599986
# radius: 1 atom list: [14, 13] activation 0.03438503951770156
# radius: 1 atom list: [8, 9] activation 0.03433651060765811
# radius: 1 atom list: [11, 10] activation 0.03431340067307319
# radius: 1 atom list: [2, 1] activation 0.03425203110933336
# FP 1 has linear regression coefficient -0.0569720872828
# radius: 3 atom list: [1, 0, 2, 5, 3, 4, 6] activation 0.05489231585289884
# radius: 3 atom list: [1, 0, 2, 4, 3] activation 0.054711420339345465
# radius: 4 atom list: [2, 0, 1, 3, 4] activation 0.05426332704540832
# radius: 4 atom list: [15, 12, 17, 18, 11, 16, 14, 13] activation 0.05414604726265325
# radius: 4 atom list: [11, 12, 17, 18, 15, 16, 14, 13] activation 0.05414448890899299
# radius: 3 atom list: [5, 3, 6, 1, 10, 0, 2, 4] activation 0.054132384341981275
# radius: 3 atom list: [5, 2, 1, 4, 0, 3] activation 0.05409200788618791
# radius: 3 atom list: [0, 3, 2, 1, 4, 5] activation 0.05397761478632732
# radius: 3 atom list: [4, 7, 3, 5, 6, 8] activation 0.05396121546595216
# radius: 4 atom list: [10, 11, 12, 17, 18, 15, 13, 16, 14] activation 0.05395793563291679
# radius: 4 atom list: [5, 3, 6, 1, 10, 0, 2, 4] activation 0.05395501500820135
# FP 2 has linear regression coefficient -0.0412361646391
# radius: 1 atom list: [17, 15, 16, 13, 18, 14] activation 0.04258562978670929
# radius: 1 atom list: [0, 1] activation 0.04087644111778003
# radius: 1 atom list: [1, 0] activation 0.040507946831673566
# radius: 1 atom list: [1, 0] activation 0.04045114831901924
# radius: 1 atom list: [5, 7] activation 0.04036708998955966
# radius: 1 atom list: [14, 13] activation 0.040356403400755955
# radius: 1 atom list: [11, 8] activation 0.04024705980589887
# radius: 1 atom list: [11, 10] activation 0.04020997946184045
# radius: 1 atom list: [7, 8] activation 0.04019082723819943
# radius: 1 atom list: [2, 1] activation 0.03980751051062738
# radius: 1 atom list: [8, 9] activation 0.03978921206572947
# FP 3 has linear regression coefficient 0.0528134698553
# radius: 2 atom list: [3, 5, 13, 6, 9, 11, 7, 8] activation 0.04749188701803091
# radius: 2 atom list: [5, 3, 2, 1, 4, 0, 6] activation 0.04700179181625992
# radius: 2 atom list: [12, 14, 15, 16, 17, 11, 13, 18] activation 0.04677513709920737
# radius: 2 atom list: [3, 6, 2, 5, 7, 4, 11, 12] activation 0.04675236873307738
# radius: 2 atom list: [4, 5, 6, 1, 7, 11, 0, 2, 3] activation 0.046668104802147004
# radius: 2 atom list: [0, 2, 4, 6, 1, 3, 5, 7] activation 0.0465813739040506
# radius: 2 atom list: [7, 8, 9, 10, 11] activation 0.04643482146055267
# radius: 2 atom list: [8, 10, 4, 7, 3, 6, 2, 5] activation 0.04631060433057503
# radius: 2 atom list: [4, 8, 18, 14, 5, 6, 7, 15, 16, 17] activation 0.046307853420054446
# radius: 2 atom list: [6, 8, 9, 10, 7] activation 0.04621792776974893
# radius: 2 atom list: [10, 12, 13, 11] activation 0.046209776858977855
# FP 4 has linear regression coefficient 0.0321060920066
# radius: 1 atom list: [10, 8, 11, 7, 9] activation 0.03190584821120146
# radius: 1 atom list: [23, 22, 25, 20, 24] activation 0.03159648323915801
# radius: 1 atom list: [13, 14, 15, 9, 12] activation 0.031541463896062646
# radius: 1 atom list: [14, 13, 15, 16, 17] activation 0.03152503847751376
# radius: 1 atom list: [6, 8, 9, 10, 7] activation 0.03142612819843184
# radius: 1 atom list: [9, 10, 11, 8, 12] activation 0.031413500330218454
# radius: 1 atom list: [7, 8, 9, 10, 11] activation 0.03137488545815884
# radius: 1 atom list: [13, 10, 11, 12] activation 0.03129181758635267
# radius: 1 atom list: [6, 1, 4, 5] activation 0.03119230687022593
# radius: 1 atom list: [4, 6, 5, 3, 10] activation 0.031183014167647412
# radius: 1 atom list: [7, 9, 11, 10] activation 0.03108572096986201
# FP 5 has linear regression coefficient 0.0722361741064
# radius: 3 atom list: [10, 12, 13, 6, 11, 8, 7, 9] activation 0.10208420023439514
# radius: 3 atom list: [4, 8, 5, 14, 18, 6, 7, 15, 16, 17] activation 0.10203308075818124
# radius: 3 atom list: [5, 6, 4, 7, 8, 9] activation 0.1019997054077561
# radius: 3 atom list: [0, 2, 4, 6, 7, 1, 3, 5] activation 0.10186841524387555
# radius: 3 atom list: [1, 5, 0, 2, 4, 3, 6] activation 0.09988062228791954
# radius: 3 atom list: [5, 1, 3, 0, 2, 4] activation 0.09981814860021189
# radius: 3 atom list: [7, 2, 4, 6, 8, 9, 11, 15, 17, 19, 21, 5, 10, 18, 20] activation 0.0986035382422235
# radius: 3 atom list: [14, 15, 1, 8, 10, 12, 11, 13] activation 0.09848427249421748
# radius: 3 atom list: [9, 10, 11, 7, 8, 1, 4, 6] activation 0.09847244639947438
# radius: 3 atom list: [3, 6, 7, 8, 12, 15, 9, 13, 2, 4, 16, 14, 5, 17, 10] activation 0.09839453547537594
# radius: 3 atom list: [0, 2, 6, 8, 9, 10, 11, 3, 5, 4, 12, 1, 7] activation 0.09827745004168026
# FP 6 has linear regression coefficient 0.0525764369062
# radius: 2 atom list: [0, 2, 4, 6, 1, 3, 5, 7] activation 0.04611625306954562
# radius: 2 atom list: [4, 8, 18, 14, 5, 6, 7, 15, 16, 17] activation 0.04589162442042312
# radius: 2 atom list: [2, 4, 6, 7, 8, 5, 16, 18, 20, 19] activation 0.04573907744940619
# radius: 2 atom list: [5, 3, 2, 1, 4, 0, 6] activation 0.04541085161564673
# radius: 2 atom list: [7, 6, 9, 16, 18, 8, 19, 1, 3, 5] activation 0.04527843865621001
# radius: 2 atom list: [1, 4, 6, 7, 8, 14, 16, 3, 5, 17] activation 0.04518924344780344
# radius: 2 atom list: [2, 6, 14, 3, 4, 5, 7, 11, 13, 15] activation 0.04518491058300348
# radius: 2 atom list: [3, 5, 13, 6, 9, 11, 7, 8] activation 0.045130365012702636
# radius: 2 atom list: [4, 5, 6, 1, 7, 11, 0, 2, 3] activation 0.045116682931088475
# radius: 2 atom list: [10, 12, 13, 11] activation 0.044699232074384344
# radius: 2 atom list: [7, 8, 9, 10, 11] activation 0.04466575699632786
# FP 7 has linear regression coefficient 0.0418934662356
# radius: 2 atom list: [3, 5, 13, 6, 9, 11, 7, 8] activation 0.040953470742095516
# radius: 2 atom list: [12, 14, 15, 16, 17, 11, 13, 18] activation 0.040509755723145253
# radius: 2 atom list: [3, 6, 2, 5, 7, 4, 11, 12] activation 0.04048103278517118
# radius: 2 atom list: [8, 10, 4, 7, 3, 6, 2, 5] activation 0.040292644406531755
# radius: 2 atom list: [6, 8, 9, 10, 7, 11, 4, 5] activation 0.040282857321568784
# radius: 2 atom list: [14, 15, 1, 8, 10, 12, 11, 13] activation 0.039802530138448984
# radius: 2 atom list: [9, 10, 11, 7, 8, 1, 4, 6] activation 0.03976206299011197
# radius: 2 atom list: [10, 1, 4, 6, 11, 8, 7, 9] activation 0.03968459272300808
# radius: 2 atom list: [13, 11, 12, 14, 17, 15, 16] activation 0.03957228976631147
# radius: 2 atom list: [4, 6, 7, 1, 3, 5, 8] activation 0.03954493304756484
# radius: 2 atom list: [5, 8, 4, 6, 7, 1, 3] activation 0.039447733270060834
# FP 8 has linear regression coefficient 0.0498027384253
# radius: 2 atom list: [0, 2, 4, 6, 1, 3, 5, 7] activation 0.04650487268670257
# radius: 2 atom list: [4, 8, 18, 14, 5, 6, 7, 15, 16, 17] activation 0.046183454532097
# radius: 2 atom list: [2, 4, 6, 7, 8, 5, 16, 18, 20, 19] activation 0.04609188590470414
# radius: 2 atom list: [7, 6, 9, 16, 18, 8, 19, 1, 3, 5] activation 0.045597929816262484
# radius: 2 atom list: [1, 4, 6, 7, 8, 14, 16, 3, 5, 17] activation 0.045496231177267865
# radius: 2 atom list: [2, 6, 14, 3, 4, 5, 7, 11, 13, 15] activation 0.045491569110111804
# radius: 2 atom list: [16, 6, 7, 8, 10, 13, 15, 5, 17, 9] activation 0.04489547154399799
# radius: 2 atom list: [16, 3, 5, 6, 7, 13, 15, 17, 2, 4] activation 0.04487420207032549
# radius: 2 atom list: [11, 17, 10, 16, 5, 7, 8, 9, 13, 15] activation 0.044869335727740926
# radius: 2 atom list: [1, 6, 10, 12, 4, 5, 0, 2, 3, 16, 11] activation 0.04445970833298755
# radius: 2 atom list: [16, 3, 5, 6, 7, 13, 15, 2, 17, 4] activation 0.0443255314228029
# FP 9 has linear regression coefficient -0.0558331258503
# radius: 2 atom list: [1, 3, 4, 0, 2] activation 0.04840713450971293
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.04836947840783376
# radius: 2 atom list: [13, 16, 14, 15, 12] activation 0.04809917493749279
# radius: 2 atom list: [1, 0, 2, 3, 4] activation 0.048081359669665216
# radius: 2 atom list: [16, 17, 15, 12, 13, 18, 14] activation 0.04797546246876906
# radius: 2 atom list: [2, 1, 3, 4, 0] activation 0.04795325768900125
# radius: 2 atom list: [2, 0, 1, 4, 3] activation 0.047716749315487035
# radius: 2 atom list: [4, 3, 1] activation 0.04763303218720153
# radius: 2 atom list: [15, 16, 17, 18, 14, 13] activation 0.04759814702698729
# radius: 2 atom list: [15, 16, 17, 18, 14, 13] activation 0.04753071436208143
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.047454416762544464
# FP 10 has linear regression coefficient 0.0340694234472
# radius: 1 atom list: [10, 8, 11, 7, 9] activation 0.032229332784102616
# radius: 1 atom list: [7, 8, 9, 10, 11] activation 0.032132493885117394
# radius: 1 atom list: [4, 6, 5, 3, 10] activation 0.03210771316950944
# radius: 1 atom list: [6, 8, 9, 10, 7] activation 0.03204943383894036
# radius: 1 atom list: [13, 10, 11, 12] activation 0.0319731012891277
# radius: 1 atom list: [14, 13, 15, 16, 17] activation 0.03188008779509943
# radius: 1 atom list: [6, 1, 4, 5] activation 0.03186900533551618
# radius: 1 atom list: [7, 9, 11, 10] activation 0.03184415406017931
# radius: 1 atom list: [23, 22, 25, 20, 24] activation 0.03182602037844335
# radius: 1 atom list: [9, 10, 11, 8, 12] activation 0.031824795487110806
# radius: 1 atom list: [13, 14, 15, 9, 12] activation 0.03169925393765279
# FP 11 has linear regression coefficient 0.106986381014
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 0, 8] activation 0.533896043035139
# radius: 4 atom list: [1, 2, 3, 4, 0, 6, 7, 8, 5] activation 0.5329767147940565
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 9] activation 0.532055444570759
# radius: 4 atom list: [0, 1, 2, 3, 4, 5, 6, 7, 8] activation 0.5298924094979143
# radius: 4 atom list: [8, 0, 1, 2, 3, 4, 5, 6, 7] activation 0.5295810214644014
# radius: 4 atom list: [11, 12, 13, 14, 15, 16, 17, 9, 10] activation 0.5289646422477173
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 9] activation 0.5286526011713876
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 0] activation 0.5271614669652439
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 0] activation 0.5270637238237578
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 0] activation 0.5265931561278764
# radius: 4 atom list: [9, 10, 11, 12, 13, 14, 15, 17, 16] activation 0.5262279685392339
# FP 12 has linear regression coefficient -0.0595600005066
# radius: 4 atom list: [1, 0, 2, 4, 3] activation 0.06830230076705707
# radius: 4 atom list: [5, 3, 6, 7, 1, 9, 10, 0, 2, 4] activation 0.0682145312374958
# radius: 4 atom list: [0, 2, 5, 3, 1, 4, 6] activation 0.06805212760365918
# radius: 4 atom list: [9, 10, 11, 15, 13, 14, 16, 12] activation 0.06771510752312486
# radius: 4 atom list: [3, 9, 5, 6, 8, 4, 2, 7, 10, 15, 1] activation 0.06721610411803115
# radius: 4 atom list: [8, 9, 14, 17, 11, 12, 13, 15, 7, 10, 16] activation 0.06720842982671021
# radius: 4 atom list: [20, 23, 26, 29, 31, 25, 30, 27, 28, 21, 19] activation 0.06720327764917317
# radius: 4 atom list: [18, 19, 20, 22, 15, 16, 21, 23, 13, 17] activation 0.06718418971626286
# radius: 4 atom list: [18, 20, 15, 13, 14, 19, 21, 22, 16, 17] activation 0.06717650640719157
# radius: 4 atom list: [5, 2, 1, 4, 0, 3] activation 0.06707982717142506
# radius: 4 atom list: [0, 3, 1, 2, 4, 5, 6] activation 0.06684571036578799
# FP 13 has linear regression coefficient 0.0194972440748
# radius: 1 atom list: [1, 0, 2, 15] activation 0.02430273001196037
# radius: 1 atom list: [1, 2, 3, 9] activation 0.024210782253857106
# radius: 1 atom list: [3, 5, 4, 2] activation 0.02419477754216304
# radius: 1 atom list: [6, 7, 8, 15] activation 0.024193794069491847
# radius: 1 atom list: [7, 8, 4, 10] activation 0.02417552749250999
# radius: 1 atom list: [8, 10, 11, 17] activation 0.024171712245051432
# radius: 1 atom list: [10, 13, 11, 12] activation 0.024168939924922066
# radius: 1 atom list: [11, 9, 10, 13] activation 0.024155745818082008
# radius: 1 atom list: [4, 5, 1, 11] activation 0.024154894390286424
# radius: 1 atom list: [9, 10, 8, 20] activation 0.024154092392244725
# radius: 1 atom list: [22, 7, 9, 10] activation 0.024148703942317957
# FP 14 has linear regression coefficient 0.0324309150347
# radius: 1 atom list: [13, 10, 11, 12] activation 0.029307765147572617
# radius: 1 atom list: [6, 1, 4, 5] activation 0.029222203585835656
# radius: 1 atom list: [7, 8, 9, 10, 11] activation 0.029206883742614653
# radius: 1 atom list: [7, 9, 11, 10] activation 0.029205306441093502
# radius: 1 atom list: [6, 8, 9, 10, 7] activation 0.029158062925744577
# radius: 1 atom list: [10, 8, 11, 7, 9] activation 0.029119748721410866
# radius: 1 atom list: [14, 13, 15, 16, 17] activation 0.029057139107938692
# radius: 1 atom list: [23, 22, 25, 20, 24] activation 0.029033471756565614
# radius: 1 atom list: [4, 6, 5, 3, 10] activation 0.029030728417085747
# radius: 1 atom list: [9, 10, 11, 8, 12] activation 0.029007441699017884
# radius: 1 atom list: [9, 16, 6, 8] activation 0.029006104144985726
# FP 15 has linear regression coefficient -0.0500888458114
# radius: 2 atom list: [1, 3, 4, 0, 2] activation 0.043151891922624884
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.04310741944464118
# radius: 2 atom list: [13, 16, 14, 15, 12] activation 0.04302925027201574
# radius: 2 atom list: [1, 0, 2, 3, 4] activation 0.043012003255507275
# radius: 2 atom list: [2, 1, 3, 4, 0] activation 0.04296432166567163
# radius: 2 atom list: [2, 0, 1, 4, 3] activation 0.04284072259820147
# radius: 2 atom list: [16, 17, 15, 12, 13, 18, 14] activation 0.042737156981897124
# radius: 2 atom list: [0, 2, 1, 4, 3] activation 0.042699002363235455
# radius: 2 atom list: [11, 9, 10, 12, 13] activation 0.04269893831045811
# radius: 2 atom list: [6, 7, 8, 4, 5] activation 0.04263080806857282
# radius: 2 atom list: [4, 12, 0, 2, 1, 3] activation 0.04255866894380329
# FP 16 has linear regression coefficient 0.0314288849195
# radius: 1 atom list: [14, 13, 15, 16, 17] activation 0.032279674928269345
# radius: 1 atom list: [23, 22, 25, 20, 24] activation 0.03227882522800374
# radius: 1 atom list: [6, 8, 9, 10, 7] activation 0.03224685410261306
# radius: 1 atom list: [7, 8, 9, 10, 11] activation 0.03222850036669252
# radius: 1 atom list: [13, 14, 15, 9, 12] activation 0.03217018601750053
# radius: 1 atom list: [10, 8, 11, 7, 9] activation 0.03202898468512692
# radius: 1 atom list: [9, 10, 11, 8, 12] activation 0.03196617010961869
# radius: 1 atom list: [4, 6, 5, 3, 10] activation 0.03135502464548764
# radius: 1 atom list: [4, 5, 6, 7, 8] activation 0.03127855301432458
# radius: 1 atom list: [0, 2, 3, 4, 1] activation 0.031216595966351984
# radius: 1 atom list: [3, 1, 4, 0, 2] activation 0.031215489352381717
# FP 17 has linear regression coefficient -0.0530127645214
# radius: 2 atom list: [1, 3, 4, 0, 2] activation 0.047969597203528044
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.047921494822552896
# radius: 2 atom list: [13, 16, 14, 15, 12] activation 0.04781644796695214
# radius: 2 atom list: [1, 0, 2, 3, 4] activation 0.04770133703583243
# radius: 2 atom list: [2, 1, 3, 4, 0] activation 0.047591382821993655
# radius: 2 atom list: [16, 17, 15, 12, 13, 18, 14] activation 0.047548649450306485
# radius: 2 atom list: [2, 0, 1, 4, 3] activation 0.04741387872667751
# radius: 2 atom list: [15, 16, 17, 18, 14, 13] activation 0.04734247858016837
# radius: 2 atom list: [4, 3, 1] activation 0.04730742284045634
# radius: 2 atom list: [15, 16, 17, 18, 14, 13] activation 0.04727676369072113
# radius: 2 atom list: [11, 9, 10, 12, 13] activation 0.047192751614925615
# FP 18 has linear regression coefficient -0.0565993626899
# radius: 4 atom list: [5, 3, 6, 7, 1, 9, 10, 0, 2, 4] activation 0.05545957418362799
# radius: 4 atom list: [1, 0, 2, 4, 3] activation 0.055405813827123125
# radius: 4 atom list: [0, 2, 5, 3, 1, 4, 6] activation 0.0553838877264883
# radius: 4 atom list: [9, 10, 11, 15, 13, 14, 16, 12] activation 0.055340413854902244
# radius: 4 atom list: [3, 9, 5, 6, 8, 4, 2, 7, 10, 15, 1] activation 0.05531673518149662
# radius: 4 atom list: [8, 9, 14, 17, 11, 12, 13, 15, 7, 10, 16] activation 0.05531376000277646
# radius: 4 atom list: [20, 23, 26, 29, 31, 25, 30, 27, 28, 21, 19] activation 0.05531184745176048
# radius: 4 atom list: [18, 19, 20, 22, 15, 16, 21, 23, 13, 17] activation 0.055306773046082475
# radius: 4 atom list: [18, 20, 15, 13, 14, 19, 21, 22, 16, 17] activation 0.05530378797943112
# radius: 4 atom list: [0, 2, 3, 6, 4, 8, 10, 14, 1, 5, 9, 7] activation 0.055221968980840704
# radius: 4 atom list: [5, 2, 1, 4, 0, 3] activation 0.05515292652797444
# FP 19 has linear regression coefficient 0.0359651140484
# radius: 1 atom list: [7, 8, 9, 10, 11] activation 0.03539726660988986
# radius: 1 atom list: [6, 8, 9, 10, 7] activation 0.03534416960321314
# radius: 1 atom list: [14, 13, 15, 16, 17] activation 0.03523393782362693
# radius: 1 atom list: [23, 22, 25, 20, 24] activation 0.03520211036502185
# radius: 1 atom list: [13, 14, 15, 9, 12] activation 0.03503275158581125
# radius: 1 atom list: [9, 10, 11, 8, 12] activation 0.03502201516316051
# radius: 1 atom list: [10, 8, 11, 7, 9] activation 0.034970228299135805
# radius: 1 atom list: [4, 6, 5, 3, 10] activation 0.03438420247776102
# radius: 1 atom list: [4, 5, 6, 7, 8] activation 0.03410013573207391
# radius: 1 atom list: [3, 4, 1, 0, 2] activation 0.03409717247005949
# radius: 1 atom list: [3, 1, 4, 0, 2] activation 0.03402940169247286
# FP 20 has linear regression coefficient 0.0559059275281
# radius: 2 atom list: [3, 5, 13, 6, 9, 11, 7, 8] activation 0.0529723857060152
# radius: 2 atom list: [12, 14, 15, 16, 17, 11, 13, 18] activation 0.05179970964143397
# radius: 2 atom list: [3, 6, 2, 5, 7, 4, 11, 12] activation 0.051757882031100294
# radius: 2 atom list: [8, 10, 4, 7, 3, 6, 2, 5] activation 0.05111474068024075
# radius: 2 atom list: [6, 8, 9, 10, 7, 11, 4, 5] activation 0.05090418998289615
# radius: 2 atom list: [0, 2, 4, 6, 1, 3, 5, 7] activation 0.04986994392738898
# radius: 2 atom list: [4, 0, 1, 2, 3] activation 0.04984374414999002
# radius: 2 atom list: [14, 15, 1, 8, 10, 12, 11, 13] activation 0.049648465440949335
# radius: 2 atom list: [9, 10, 11, 7, 8, 1, 4, 6] activation 0.04956211301482788
# radius: 2 atom list: [4, 8, 18, 14, 5, 6, 7, 15, 16, 17] activation 0.049479218453010086
# radius: 2 atom list: [4, 5, 1, 2, 3] activation 0.04943126550355165
# FP 21 has linear regression coefficient -0.0734865625219
# radius: 3 atom list: [17, 11, 12, 13, 18, 15, 16, 14] activation 0.0973454385652269
# radius: 3 atom list: [2, 0, 1, 3, 4] activation 0.08957137304845925
# radius: 3 atom list: [15, 16, 17, 18, 14, 12, 13] activation 0.0884736986509571
# radius: 3 atom list: [15, 16, 17, 18, 14, 12, 13] activation 0.08831577625792046
# radius: 3 atom list: [13, 12, 14, 15, 16] activation 0.08654015892843425
# radius: 3 atom list: [1, 3, 4, 0, 2] activation 0.08635483035321499
# radius: 3 atom list: [3, 4, 0, 2, 1] activation 0.0862949859089417
# radius: 3 atom list: [1, 0, 2, 4, 3] activation 0.0861347039289557
# radius: 3 atom list: [1, 0, 2, 3, 4] activation 0.08571354157205407
# radius: 3 atom list: [2, 1, 3, 4, 0] activation 0.08547832866566236
# radius: 3 atom list: [1, 0, 2, 5, 3, 4, 6] activation 0.08543295080606224
# FP 22 has linear regression coefficient 0.0311809065582
# radius: 1 atom list: [13, 10, 11, 12] activation 0.03259757460566501
# radius: 1 atom list: [6, 1, 4, 5] activation 0.03233092371409051
# radius: 1 atom list: [7, 9, 11, 10] activation 0.03218914520173194
# radius: 1 atom list: [10, 8, 11, 7, 9] activation 0.03218432212117986
# radius: 1 atom list: [19, 17, 1, 18] activation 0.03215906369587562
# radius: 1 atom list: [4, 6, 5, 3, 10] activation 0.03207990059209567
# radius: 1 atom list: [7, 8, 9, 10, 11] activation 0.03206930289843616
# radius: 1 atom list: [6, 8, 9, 10, 7] activation 0.03195557733755485
# radius: 1 atom list: [9, 10, 11, 8, 12] activation 0.03186100474692384
# radius: 1 atom list: [14, 13, 15, 16, 17] activation 0.031725483938429895
# radius: 1 atom list: [6, 7, 8, 4] activation 0.031718781057323495
# FP 23 has linear regression coefficient -0.0560115108059
# radius: 3 atom list: [1, 0, 2, 5, 3, 4, 6] activation 0.05436883007829715
# radius: 3 atom list: [1, 0, 2, 4, 3] activation 0.05408557081659635
# radius: 3 atom list: [5, 2, 1, 4, 0, 3] activation 0.05355659281555774
# radius: 3 atom list: [5, 3, 6, 1, 10, 0, 2, 4] activation 0.053487909587773115
# radius: 3 atom list: [0, 3, 2, 1, 4, 5] activation 0.05345827231624292
# radius: 3 atom list: [4, 7, 3, 5, 6, 8] activation 0.053443727878763295
# radius: 3 atom list: [5, 0, 3, 1, 4, 2] activation 0.05333811400107774
# radius: 3 atom list: [4, 1, 3, 0, 2] activation 0.05332326785757437
# radius: 3 atom list: [10, 11, 15, 13, 14, 16, 12] activation 0.053308413293956566
# radius: 3 atom list: [3, 2, 5, 1, 4, 0] activation 0.053106516648296985
# radius: 3 atom list: [3, 0, 2, 4, 1] activation 0.05306893268079326
# FP 24 has linear regression coefficient 0.0806146025645
# radius: 3 atom list: [3, 6, 7, 8, 12, 15, 9, 13, 2, 4, 16, 14, 5, 17, 10] activation 0.1563331473872393
# radius: 3 atom list: [0, 6, 1, 2, 3, 4, 5] activation 0.15557389664179158
# radius: 3 atom list: [0, 2, 6, 8, 9, 10, 11, 3, 5, 4, 12, 1, 7] activation 0.15514014577701685
# radius: 3 atom list: [4, 5, 6, 0, 1, 2, 3] activation 0.1550610431008454
# radius: 3 atom list: [7, 1, 2, 3, 4, 5, 6] activation 0.15453977571943542
# radius: 3 atom list: [7, 2, 4, 6, 8, 9, 11, 15, 17, 19, 21, 5, 10, 18, 20] activation 0.15450507519248044
# radius: 3 atom list: [1, 2, 3, 4, 5, 6, 7] activation 0.15328424926262857
# radius: 3 atom list: [0, 6, 1, 2, 3, 4, 5] activation 0.1530992348519784
# radius: 3 atom list: [9, 10, 11, 12, 13, 14, 15] activation 0.15273457667595058
# radius: 3 atom list: [2, 3, 4, 5, 6, 7, 8] activation 0.15254669920887506
# radius: 3 atom list: [9, 2, 6, 8, 3, 5, 7, 16, 14, 4, 13, 15, 11, 12] activation 0.15208847639808468
# FP 25 has linear regression coefficient 0.0565982081837
# radius: 2 atom list: [7, 8, 9, 10, 11] activation 0.0478740406926074
# radius: 2 atom list: [10, 12, 13, 11] activation 0.04782254259381834
# radius: 2 atom list: [19, 17, 1, 18] activation 0.04768799538501211
# radius: 2 atom list: [6, 8, 9, 10, 7] activation 0.04761795859826844
# radius: 2 atom list: [6, 1, 4, 5] activation 0.04751442540690797
# radius: 2 atom list: [10, 8, 7, 11, 9] activation 0.04746509247112638
# radius: 2 atom list: [7, 9, 11, 10] activation 0.0473668307096377
# radius: 2 atom list: [7, 8, 9, 6] activation 0.04697519374831399
# radius: 2 atom list: [6, 1, 4, 5] activation 0.04657352641617795
# radius: 2 atom list: [3, 5, 13, 6, 9, 11, 7, 8] activation 0.04625786511587027
# radius: 2 atom list: [5, 4, 6, 7, 8] activation 0.04621138057974475
# FP 26 has linear regression coefficient -0.037356098093
# radius: 2 atom list: [12, 11, 15, 13, 14, 16] activation 0.033965294977200036
# radius: 2 atom list: [3, 1, 5, 0, 2, 4] activation 0.0338462970365178
# radius: 2 atom list: [3, 5, 6, 8, 4, 7] activation 0.03354415100366281
# radius: 2 atom list: [3, 2, 1, 4, 0] activation 0.03339256965607653
# radius: 2 atom list: [4, 11, 0, 3, 2, 1] activation 0.03329323990164905
# radius: 2 atom list: [2, 0, 1, 4, 3] activation 0.03328789510960107
# radius: 2 atom list: [4, 1, 3, 0, 2] activation 0.033187444201085825
# radius: 2 atom list: [1, 3, 5, 4, 6] activation 0.03317284756937457
# radius: 2 atom list: [2, 4, 6, 5, 7] activation 0.033013481554705786
# radius: 2 atom list: [2, 0, 3, 1, 4] activation 0.03283772637372656
# radius: 1 atom list: [0, 1] activation 0.03277192325099402
# FP 27 has linear regression coefficient 0.0451151998601
# radius: 2 atom list: [0, 2, 4, 6, 1, 3, 5, 7] activation 0.04760376508210179
# radius: 2 atom list: [4, 8, 18, 14, 5, 6, 7, 15, 16, 17] activation 0.04739265094759194
# radius: 2 atom list: [2, 4, 6, 7, 8, 5, 16, 18, 20, 19] activation 0.04709443574926156
# radius: 2 atom list: [7, 6, 9, 16, 18, 8, 19, 1, 3, 5] activation 0.04656626608565042
# radius: 2 atom list: [1, 4, 6, 7, 8, 14, 16, 3, 5, 17] activation 0.046476993066321796
# radius: 2 atom list: [2, 6, 14, 3, 4, 5, 7, 11, 13, 15] activation 0.046471730926672034
# radius: 2 atom list: [16, 6, 7, 8, 10, 13, 15, 5, 17, 9] activation 0.04585464867610038
# radius: 2 atom list: [16, 3, 5, 6, 7, 13, 15, 17, 2, 4] activation 0.04583284548534751
# radius: 2 atom list: [11, 17, 10, 16, 5, 7, 8, 9, 13, 15] activation 0.045827382537950705
# radius: 2 atom list: [5, 3, 2, 1, 4, 0, 6] activation 0.0458216881444299
# radius: 2 atom list: [1, 6, 10, 12, 4, 5, 0, 2, 3, 16, 11] activation 0.045534454590940916
# FP 28 has linear regression coefficient 0.0118773901003
# radius: 0 atom list: [13] activation 0.02125839855905888
# radius: 0 atom list: [6] activation 0.020691105086106904
# radius: 0 atom list: [5] activation 0.02065782300693821
# radius: 0 atom list: [13] activation 0.020330950993930123
# radius: 0 atom list: [20] activation 0.01982744811489602
# radius: 0 atom list: [7] activation 0.019782035681195843
# radius: 0 atom list: [5] activation 0.0197509227618087
# radius: 0 atom list: [10] activation 0.019656671511500586
# radius: 0 atom list: [8] activation 0.019642394691586476
# radius: 0 atom list: [1] activation 0.019406723075991516
# radius: 0 atom list: [3] activation 0.01895909707979164
# FP 29 has linear regression coefficient 0.0428131982341
# radius: 2 atom list: [3, 5, 13, 6, 9, 11, 7, 8] activation 0.042096099985001204
# radius: 2 atom list: [12, 14, 15, 16, 17, 11, 13, 18] activation 0.04165986603255584
# radius: 2 atom list: [3, 6, 2, 5, 7, 4, 11, 12] activation 0.041646399319144274
# radius: 2 atom list: [8, 10, 4, 7, 3, 6, 2, 5] activation 0.041367381792666275
# radius: 2 atom list: [6, 8, 9, 10, 7, 11, 4, 5] activation 0.04130080246933932
# radius: 2 atom list: [4, 0, 1, 2, 3] activation 0.04075652824505411
# radius: 2 atom list: [14, 15, 1, 8, 10, 12, 11, 13] activation 0.04075117896368426
# radius: 2 atom list: [9, 10, 11, 7, 8, 1, 4, 6] activation 0.040707325557921364
# radius: 2 atom list: [13, 11, 12, 14, 17, 15, 16] activation 0.040693320970390565
# radius: 2 atom list: [10, 1, 4, 6, 11, 8, 7, 9] activation 0.040667804962686877
# radius: 2 atom list: [4, 6, 7, 1, 3, 5, 8] activation 0.04063667217479468
# FP 30 has linear regression coefficient -0.0654404267092
# radius: 4 atom list: [15, 12, 17, 18, 11, 16, 14, 13] activation 0.0758339963176694
# radius: 4 atom list: [11, 12, 17, 18, 15, 16, 14, 13] activation 0.07580226062131382
# radius: 4 atom list: [10, 11, 12, 17, 18, 15, 13, 16, 14] activation 0.07523214791992064
# radius: 4 atom list: [5, 3, 6, 1, 10, 0, 2, 4] activation 0.0738208869699009
# radius: 4 atom list: [10, 11, 15, 13, 14, 16, 12] activation 0.07354716155346881
# radius: 4 atom list: [2, 0, 1, 4, 3] activation 0.0728858275380281
# radius: 4 atom list: [5, 2, 1, 4, 0, 3] activation 0.07268411824967377
# radius: 4 atom list: [3, 9, 5, 6, 8, 4, 2, 7] activation 0.07262639321480717
# radius: 4 atom list: [18, 19, 20, 22, 16, 21, 23, 17] activation 0.07261887691020891
# radius: 4 atom list: [1, 0, 2, 3, 4] activation 0.07259720369802294
# radius: 4 atom list: [1, 0, 3, 2, 4, 5] activation 0.07255967152190733
# FP 31 has linear regression coefficient 0.0268068272082
# radius: 1 atom list: [13, 10, 11, 12] activation 0.030001331237567368
# radius: 1 atom list: [19, 17, 1, 18] activation 0.029891210527152136
# radius: 1 atom list: [6, 1, 4, 5] activation 0.02987775940588512
# radius: 1 atom list: [7, 9, 11, 10] activation 0.029750178943773863
# radius: 1 atom list: [1, 19, 18, 17] activation 0.02965623963923219
# radius: 1 atom list: [10, 8, 11, 7, 9] activation 0.029615967817504744
# radius: 1 atom list: [13, 14, 15, 9, 12] activation 0.029426298762545926
# radius: 1 atom list: [6, 7, 8, 4] activation 0.029415575436320084
# radius: 1 atom list: [23, 22, 25, 20, 24] activation 0.02937787869356839
# radius: 1 atom list: [9, 10, 11, 8, 12] activation 0.029317985985345216
# radius: 1 atom list: [14, 13, 15, 16, 17] activation 0.029317105281479572
# FP 32 has linear regression coefficient -0.0669647712562
# radius: 4 atom list: [2, 0, 1, 3, 4] activation 0.07763065905459957
# radius: 4 atom list: [0, 2, 3, 6, 4, 8, 1, 5, 9, 7] activation 0.07506562070508356
# radius: 4 atom list: [6, 0, 2, 3, 1, 7, 4, 5] activation 0.07361534680919063
# radius: 4 atom list: [15, 12, 17, 18, 11, 16, 14, 13] activation 0.07357640371700483
# radius: 4 atom list: [11, 12, 17, 18, 15, 16, 14, 13] activation 0.07354792771674479
# radius: 4 atom list: [5, 8, 0, 2, 3, 6, 1, 4, 7] activation 0.07271383082489281
# radius: 4 atom list: [10, 11, 12, 17, 18, 15, 13, 16, 14] activation 0.07235738549727806
# radius: 4 atom list: [1, 3, 5, 7, 2, 0, 4, 6, 8] activation 0.07232422764569119
# radius: 4 atom list: [5, 3, 6, 1, 10, 0, 2, 4] activation 0.07199262256480693
# radius: 4 atom list: [10, 11, 15, 13, 14, 16, 12] activation 0.07172761071766319
# radius: 4 atom list: [7, 8, 9, 6, 1, 3, 4, 5] activation 0.07150609545081221
# FP 33 has linear regression coefficient -0.0619362168672
# radius: 3 atom list: [17, 11, 12, 13, 18, 15, 16, 14] activation 0.06970474169315395
# radius: 3 atom list: [15, 16, 17, 18, 14, 12, 13] activation 0.06615480520965686
# radius: 3 atom list: [15, 16, 17, 18, 14, 12, 13] activation 0.066088779510505
# radius: 3 atom list: [1, 0, 2, 4, 3] activation 0.06549519153815593
# radius: 3 atom list: [13, 12, 14, 15, 16] activation 0.06533187629970756
# radius: 3 atom list: [1, 3, 4, 0, 2] activation 0.06526549746156675
# radius: 3 atom list: [1, 0, 2, 5, 3, 4, 6] activation 0.06525457911135592
# radius: 3 atom list: [3, 4, 0, 2, 1] activation 0.06523925149370871
# radius: 3 atom list: [5, 3, 6, 1, 10, 0, 2, 4] activation 0.06504220766469382
# radius: 3 atom list: [1, 0, 2, 3, 4] activation 0.06498391968577635
# radius: 3 atom list: [2, 1, 3, 4, 0] activation 0.06487983028519677
# FP 34 has linear regression coefficient 0.0633465932312
# radius: 3 atom list: [5, 6, 4, 7, 8, 9] activation 0.06450237437010856
# radius: 3 atom list: [1, 5, 0, 2, 4, 3, 6] activation 0.06446594078110801
# radius: 3 atom list: [5, 1, 3, 0, 2, 4] activation 0.06441502746836417
# radius: 3 atom list: [10, 12, 13, 6, 11, 8, 7, 9] activation 0.06440998223412407
# radius: 3 atom list: [0, 2, 4, 6, 7, 1, 3, 5] activation 0.06437210902800866
# radius: 3 atom list: [4, 8, 5, 14, 18, 6, 7, 15, 16, 17] activation 0.06435940068098771
# radius: 3 atom list: [1, 4, 2, 3, 5, 6, 12, 15, 11, 13, 14, 16, 17] activation 0.0642827558210439
# radius: 3 atom list: [16, 15, 1, 4, 12, 11, 13, 2, 3, 5, 6, 14] activation 0.0642244750895175
# radius: 3 atom list: [7, 10, 15, 8, 9, 12, 13, 6, 2, 14, 11, 5, 0, 1] activation 0.06393000115611985
# radius: 3 atom list: [15, 0, 4, 5, 17, 1, 7, 3, 6, 2, 8, 11, 12] activation 0.06390823079009497
# radius: 3 atom list: [9, 10, 13, 14, 16, 3, 6, 12, 15, 11, 2, 8, 17, 1, 7] activation 0.06390596437167746
# FP 35 has linear regression coefficient 0.0541082916188
# radius: 2 atom list: [3, 5, 13, 6, 9, 11, 7, 8] activation 0.046077564206234996
# radius: 2 atom list: [0, 2, 4, 6, 1, 3, 5, 7] activation 0.04587008924137514
# radius: 2 atom list: [4, 8, 18, 14, 5, 6, 7, 15, 16, 17] activation 0.04563372593799655
# radius: 2 atom list: [2, 4, 6, 7, 8, 5, 16, 18, 20, 19] activation 0.045533968949391906
# radius: 2 atom list: [3, 6, 2, 5, 7, 4, 11, 12] activation 0.045478889857132665
# radius: 2 atom list: [12, 14, 15, 16, 17, 11, 13, 18] activation 0.045475338721004864
# radius: 2 atom list: [7, 6, 9, 16, 18, 8, 19, 1, 3, 5] activation 0.045088280003211134
# radius: 2 atom list: [8, 10, 4, 7, 3, 6, 2, 5] activation 0.04508012210448425
# radius: 2 atom list: [10, 12, 13, 11] activation 0.04502261216196935
# radius: 2 atom list: [1, 4, 6, 7, 8, 14, 16, 3, 5, 17] activation 0.04498752916578476
# radius: 2 atom list: [2, 6, 14, 3, 4, 5, 7, 11, 13, 15] activation 0.04498351312551987
# FP 36 has linear regression coefficient 0.0867025466438
# radius: 4 atom list: [12, 13, 14, 15, 5, 10, 9, 1, 2, 3, 4, 6, 7, 8, 11] activation 0.22337613166364917
# radius: 4 atom list: [3, 4, 5, 6, 8, 9, 10, 11, 14, 15, 16, 17, 18, 7, 13] activation 0.22311552573637577
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 0, 8] activation 0.22137275914059718
# radius: 4 atom list: [1, 2, 3, 4, 0, 6, 7, 8, 5] activation 0.2213656106123755
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 9] activation 0.22135699577165702
# radius: 4 atom list: [0, 1, 2, 3, 4, 5, 6, 7, 8] activation 0.22133203238359975
# radius: 4 atom list: [8, 0, 1, 2, 3, 4, 5, 6, 7] activation 0.2213282115829996
# radius: 4 atom list: [11, 12, 13, 14, 15, 16, 17, 9, 10] activation 0.22131846986958859
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 9] activation 0.2213141476743175
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 0] activation 0.22128919590338625
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 0] activation 0.22128749840375503
# FP 37 has linear regression coefficient -0.0774193267849
# radius: 4 atom list: [15, 12, 17, 18, 11, 16, 14, 13] activation 0.1039701519154775
# radius: 4 atom list: [11, 12, 17, 18, 15, 16, 14, 13] activation 0.10389529300827566
# radius: 4 atom list: [10, 11, 12, 17, 18, 15, 13, 16, 14] activation 0.1024478504091444
# radius: 4 atom list: [5, 3, 6, 1, 10, 0, 2, 4] activation 0.09969201304969834
# radius: 4 atom list: [10, 11, 15, 13, 14, 16, 12] activation 0.099046346396475
# radius: 4 atom list: [1, 0, 2, 4, 3] activation 0.0980229343203717
# radius: 4 atom list: [2, 0, 1, 4, 3] activation 0.09777452194846632
# radius: 4 atom list: [5, 3, 6, 7, 1, 9, 10, 0, 2, 4] activation 0.09757464068129271
# radius: 4 atom list: [0, 2, 5, 3, 1, 4, 6] activation 0.0972854507570859
# radius: 4 atom list: [5, 2, 1, 4, 0, 3] activation 0.09717764896085064
# radius: 4 atom list: [3, 9, 5, 6, 8, 4, 2, 7] activation 0.09695248692997441
# FP 38 has linear regression coefficient -0.0508587088006
# radius: 2 atom list: [13, 16, 14, 15, 12] activation 0.047259701499976
# radius: 2 atom list: [16, 17, 15, 12, 13, 18, 14] activation 0.04724182232239276
# radius: 2 atom list: [1, 3, 4, 0, 2] activation 0.047146976685745384
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.047106087133651345
# radius: 2 atom list: [1, 0, 2, 3, 4] activation 0.046859026755332614
# radius: 2 atom list: [2, 1, 3, 4, 0] activation 0.04674360503311878
# radius: 2 atom list: [2, 0, 1, 4, 3] activation 0.046559017771528
# radius: 2 atom list: [4, 3, 1] activation 0.04648084413545128
# radius: 2 atom list: [11, 9, 10, 12, 13] activation 0.04630263695607306
# radius: 2 atom list: [0, 2, 1, 4, 3] activation 0.04627988253425911
# radius: 2 atom list: [6, 7, 8, 4, 5] activation 0.0461693151149788
# FP 39 has linear regression coefficient -0.0328169221013
# radius: 1 atom list: [11, 10] activation 0.03033577520777275
# radius: 1 atom list: [14, 13] activation 0.030315247806860054
# radius: 1 atom list: [5, 7] activation 0.03030717945225362
# radius: 1 atom list: [11, 8] activation 0.030303030409206476
# radius: 1 atom list: [25, 26] activation 0.03029395776608435
# radius: 1 atom list: [11, 10] activation 0.030290954728714747
# radius: 1 atom list: [3, 4] activation 0.030285894789725164
# radius: 1 atom list: [1, 0] activation 0.030282081977832404
# radius: 1 atom list: [2, 1] activation 0.03027788530082953
# radius: 1 atom list: [0, 1] activation 0.0302712122768965
# radius: 1 atom list: [7, 8] activation 0.030263650973588622
# FP 40 has linear regression coefficient -0.0553563379241
# radius: 4 atom list: [2, 0, 1, 3, 4] activation 0.05194706535627649
# radius: 4 atom list: [0, 2, 3, 6, 4, 8, 1, 5, 9, 7] activation 0.0515203128805054
# radius: 4 atom list: [6, 0, 2, 3, 1, 7, 4, 5] activation 0.05124763069359662
# radius: 4 atom list: [10, 11, 15, 13, 14, 16, 12] activation 0.051214505076698925
# radius: 4 atom list: [5, 3, 6, 1, 10, 0, 2, 4] activation 0.05121257372423939
# radius: 4 atom list: [2, 0, 1, 4, 3] activation 0.05121162365736044
# radius: 4 atom list: [1, 0, 2, 3, 4] activation 0.05120407040450992
# radius: 4 atom list: [5, 2, 1, 4, 0, 3] activation 0.05120331759445122
# radius: 4 atom list: [1, 0, 2, 3, 4] activation 0.05120155848435943
# radius: 4 atom list: [3, 9, 5, 6, 8, 4, 2, 7] activation 0.05120049612264007
# radius: 4 atom list: [18, 19, 20, 22, 16, 21, 23, 17] activation 0.05120025309170476
# FP 41 has linear regression coefficient -0.0646690666583
# radius: 3 atom list: [17, 11, 12, 13, 18, 15, 16, 14] activation 0.07226110944744576
# radius: 3 atom list: [2, 0, 1, 3, 4] activation 0.0690948291071131
# radius: 3 atom list: [15, 16, 17, 18, 14, 12, 13] activation 0.06871012823228399
# radius: 3 atom list: [15, 16, 17, 18, 14, 12, 13] activation 0.06863895020074762
# radius: 3 atom list: [13, 12, 14, 15, 16] activation 0.0678135228981167
# radius: 3 atom list: [1, 3, 4, 0, 2] activation 0.06774141803495194
# radius: 3 atom list: [3, 4, 0, 2, 1] activation 0.06771270149187057
# radius: 3 atom list: [1, 0, 2, 4, 3] activation 0.06755451139233261
# radius: 3 atom list: [1, 0, 2, 3, 4] activation 0.06743146551631947
# radius: 3 atom list: [2, 1, 3, 4, 0] activation 0.06731671752178485
# radius: 3 atom list: [1, 0, 2, 5, 3, 4, 6] activation 0.06725917219941739
# FP 42 has linear regression coefficient -0.0364158521815
# radius: 1 atom list: [17, 15, 16, 13, 18, 14] activation 0.0367162427541028
# radius: 1 atom list: [0, 1] activation 0.03638426795732444
# radius: 1 atom list: [5, 7] activation 0.03611356154812544
# radius: 1 atom list: [11, 10] activation 0.036075448805605294
# radius: 1 atom list: [1, 0] activation 0.036073524348587675
# radius: 1 atom list: [1, 0] activation 0.03603938355287672
# radius: 1 atom list: [14, 13] activation 0.03600680530598255
# radius: 1 atom list: [11, 8] activation 0.03590481224532427
# radius: 1 atom list: [7, 8] activation 0.0358236739565298
# radius: 1 atom list: [2, 1] activation 0.03575875882523213
# radius: 1 atom list: [9, 8] activation 0.03572773524081331
# FP 43 has linear regression coefficient -0.0503109283627
# radius: 1 atom list: [17, 15, 16, 13, 18, 14] activation 0.04895973196856322
# radius: 3 atom list: [15, 16, 17, 18, 14, 12, 13] activation 0.04599942070844004
# radius: 3 atom list: [1, 3, 4, 0, 2] activation 0.04599942010997797
# radius: 3 atom list: [15, 16, 17, 18, 14, 12, 13] activation 0.04599900597638531
# radius: 3 atom list: [3, 4, 0, 2, 1] activation 0.0459977234018403
# radius: 3 atom list: [1, 0, 2, 3, 4] activation 0.045983777145336135
# radius: 3 atom list: [13, 12, 14, 15, 16] activation 0.045978463225977886
# radius: 3 atom list: [2, 1, 3, 4, 0] activation 0.04597700669955626
# radius: 3 atom list: [1, 3, 4, 0, 2] activation 0.045950855889321525
# radius: 3 atom list: [3, 4, 0, 2, 1] activation 0.045948296979635754
# radius: 3 atom list: [0, 2, 1, 4, 3] activation 0.0459455571578123
# FP 44 has linear regression coefficient -0.0569323455433
# radius: 4 atom list: [1, 0, 2, 4, 3] activation 0.058278246648876764
# radius: 4 atom list: [5, 3, 6, 7, 1, 9, 10, 0, 2, 4] activation 0.05823187362699039
# radius: 4 atom list: [0, 2, 5, 3, 1, 4, 6] activation 0.05818943715427202
# radius: 4 atom list: [9, 10, 11, 15, 13, 14, 16, 12] activation 0.058066854027315935
# radius: 4 atom list: [3, 9, 5, 6, 8, 4, 2, 7, 10, 15, 1] activation 0.05787239677217952
# radius: 4 atom list: [8, 9, 14, 17, 11, 12, 13, 15, 7, 10, 16] activation 0.0578697204225246
# radius: 4 atom list: [20, 23, 26, 29, 31, 25, 30, 27, 28, 21, 19] activation 0.05786793733128262
# radius: 4 atom list: [18, 19, 20, 22, 15, 16, 21, 23, 13, 17] activation 0.057861008671463585
# radius: 4 atom list: [18, 20, 15, 13, 14, 19, 21, 22, 16, 17] activation 0.05785832194323812
# radius: 4 atom list: [5, 2, 1, 4, 0, 3] activation 0.057845346165469984
# radius: 4 atom list: [15, 12, 17, 18, 11, 16, 14, 13] activation 0.05775992025407088
# FP 45 has linear regression coefficient 0.0504047010561
# radius: 2 atom list: [0, 2, 4, 6, 1, 3, 5, 7] activation 0.04914246708946112
# radius: 2 atom list: [4, 8, 18, 14, 5, 6, 7, 15, 16, 17] activation 0.048774904791333416
# radius: 2 atom list: [2, 4, 6, 7, 8, 5, 16, 18, 20, 19] activation 0.04847990166910043
# radius: 2 atom list: [7, 6, 9, 16, 18, 8, 19, 1, 3, 5] activation 0.04788460009867911
# radius: 2 atom list: [1, 4, 6, 7, 8, 14, 16, 3, 5, 17] activation 0.04775450158015263
# radius: 2 atom list: [2, 6, 14, 3, 4, 5, 7, 11, 13, 15] activation 0.04774910663348324
# radius: 2 atom list: [16, 6, 7, 8, 10, 13, 15, 5, 17, 9] activation 0.04703059166431172
# radius: 2 atom list: [16, 3, 5, 6, 7, 13, 15, 17, 2, 4] activation 0.047004266119215515
# radius: 2 atom list: [11, 17, 10, 16, 5, 7, 8, 9, 13, 15] activation 0.04699867519378224
# radius: 2 atom list: [1, 6, 10, 12, 4, 5, 0, 2, 3, 16, 11] activation 0.0466842336091686
# radius: 2 atom list: [19, 21, 24, 22, 8, 10, 11, 12, 13, 17] activation 0.04638808064498079
# FP 46 has linear regression coefficient -0.050421739311
# radius: 2 atom list: [16, 17, 15, 12, 13, 18, 14] activation 0.04792086764417281
# radius: 2 atom list: [13, 16, 14, 15, 12] activation 0.047804431813470376
# radius: 2 atom list: [1, 3, 4, 0, 2] activation 0.0477342196278325
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.04770814122283221
# radius: 2 atom list: [1, 0, 2, 3, 4] activation 0.04743739312768711
# radius: 2 atom list: [2, 1, 3, 4, 0] activation 0.047329850427885456
# radius: 2 atom list: [2, 0, 1, 4, 3] activation 0.04709188128970795
# radius: 2 atom list: [0, 2, 1, 4, 3] activation 0.04683334607449393
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.046801516370008615
# radius: 2 atom list: [11, 9, 10, 12, 13] activation 0.046801516370008595
# radius: 2 atom list: [4, 3, 1] activation 0.046761589512018246
# FP 47 has linear regression coefficient 0.0014819965447
# radius: 3 atom list: [12, 3, 1, 6, 11, 2, 7, 8, 9, 10, 4, 5] activation 0.017107332207625593
# radius: 3 atom list: [8, 3, 9, 5, 2, 4, 7, 1, 13, 6, 10, 11, 12] activation 0.01709957185802328
# radius: 3 atom list: [12, 6, 7, 10, 11, 16, 8, 9, 13, 14, 15] activation 0.017094465624611883
# radius: 3 atom list: [0, 2, 1, 3, 4, 6, 13, 15, 14, 5, 12, 11, 7] activation 0.017092626745016614
# radius: 3 atom list: [6, 7, 10, 11, 16, 8, 9, 12, 14, 15, 13] activation 0.017089308336732705
# radius: 3 atom list: [1, 5, 11, 8, 9, 10, 2, 0, 7, 3, 6, 4] activation 0.01707127607842672
# radius: 3 atom list: [0, 2, 7, 9, 1, 3, 6, 8, 4, 5] activation 0.017061736019666898
# radius: 3 atom list: [6, 7, 10, 11, 18, 1, 3, 4, 5, 8, 9, 12, 2] activation 0.017050506584620567
# radius: 3 atom list: [10, 11, 16, 12, 8, 9, 13, 14, 15, 17, 4, 6, 7] activation 0.017048473826910382
# radius: 3 atom list: [11, 5, 6, 9, 10, 15, 4, 7, 8, 12, 13, 14, 16] activation 0.017048252782354646
# radius: 3 atom list: [11, 14, 15, 17, 1, 3, 12, 13, 16, 0, 18, 2, 4] activation 0.017047918739558826
# FP 48 has linear regression coefficient 0.0365008815635
# radius: 2 atom list: [0, 2, 4, 6, 1, 3, 5, 7] activation 0.03243596751937238
# radius: 2 atom list: [4, 8, 18, 14, 5, 6, 7, 15, 16, 17] activation 0.032331821659810606
# radius: 2 atom list: [2, 4, 6, 7, 8, 5, 16, 18, 20, 19] activation 0.032297858024060204
# radius: 2 atom list: [7, 6, 9, 16, 18, 8, 19, 1, 3, 5] activation 0.03225750800151804
# radius: 2 atom list: [1, 4, 6, 7, 8, 14, 16, 3, 5, 17] activation 0.03224805459525203
# radius: 2 atom list: [2, 6, 14, 3, 4, 5, 7, 11, 13, 15] activation 0.03224749884406437
# radius: 2 atom list: [16, 6, 7, 8, 10, 13, 15, 5, 17, 9] activation 0.032176811807369386
# radius: 2 atom list: [16, 3, 5, 6, 7, 13, 15, 17, 2, 4] activation 0.03217389892153548
# radius: 2 atom list: [11, 17, 10, 16, 5, 7, 8, 9, 13, 15] activation 0.03217315227009092
# radius: 2 atom list: [1, 6, 10, 12, 4, 5, 0, 2, 3, 16, 11] activation 0.032142725637851144
# radius: 1 atom list: [7, 8, 9, 10, 11] activation 0.032120764209850834
# FP 49 has linear regression coefficient 0.0421535499979
# radius: 1 atom list: [7, 8, 9, 10, 11] activation 0.036825407613601174
# radius: 1 atom list: [13, 10, 11, 12] activation 0.03667096703071386
# radius: 1 atom list: [6, 8, 9, 10, 7] activation 0.03665558484455848
# radius: 1 atom list: [19, 17, 1, 18] activation 0.03657372006847494
# radius: 1 atom list: [10, 8, 11, 7, 9] activation 0.03632760972224399
# radius: 1 atom list: [14, 13, 15, 16, 17] activation 0.0363138774731963
# radius: 1 atom list: [6, 1, 4, 5] activation 0.03630705155791034
# radius: 1 atom list: [9, 10, 11, 8, 12] activation 0.03628290219799778
# radius: 1 atom list: [23, 22, 25, 20, 24] activation 0.03624746765132571
# radius: 1 atom list: [4, 6, 5, 3, 10] activation 0.0362247516419971
# radius: 1 atom list: [7, 9, 11, 10] activation 0.036140212023344234

# %% [markdown]
# ### Compare error for SMILES with duplicates and without

# %%
task_params = {'target_name' : 'logP',
               'data_file'   : 'logp_mean'}

num_epochs = 1
batch_size = 100
normalize = 1
dropout = 0
activation = relu
params = {'fp_length': 20,
            'fp_depth': 3,
            'init_scale':np.exp(-4),
            'l2_penalty':np.exp(-2),
            'conv_width':10}

conv_layer_sizes = [params['conv_width']] * params['fp_depth']
conv_arch_params = {'num_hidden_features' : conv_layer_sizes,
                    'fp_length' : params['fp_length'],
                    'normalize' : normalize,
                    'return_atom_activations':False}

all_radii = range(params['fp_depth'] + 1)

# Plotting parameters
num_figs_per_fp = 11
figsize = (100, 100)
highlight_color = (30.0/255.0, 100.0/255.0, 255.0/255.0)  # A nice light blue.

# %%
dub_smiles, dub_targets, uniq_smiles, uniq_targets =  get_averaged_and_unique_smiles(task_params['data_file']+'.csv')
trained_network_weights = train_neural_fingerprint()
# Out:
# Loading data...
# Regression on 9631 training points.
# --------------------------------------------------------------------------------
# Mean predictor
#
# Performance (RMSE) on logP:
# Train: 1.8591219922763682
# Test:  1.9087278157747403
# Dub: 2.196473320235497
# Unique:  1.8589662274903223
#
# Performance (R2) on logP:
# Train: 0.0
# Test:  -1.8278865013598988e-05
# Dub: -0.004552022728161242
# Unique:  -1.558775978693916e-05
# --------------------------------------------------------------------------------
# Task params {'fp_length': 20, 'l2_penalty': 0.1353352832366127, 'fp_depth': 3, 'conv_width': 10, 'init_scale': 0.01831563888873418}
# Convnet fingerprints with neural net
# Total number of weights in the network: 9891
# max of weights 0.06962983567500523
# Iteration 0 loss 1.0016070624790232 train RMSE 1.8605440963555582 Train R2 0 : -0.001530451462992577 Validation RMSE 0 : 1.8694340847349085 Validation R2 0 : -0.015949090875271965 Dub RMSE 0 : 2.1786428990626363
# Unique RMSE 0 : 1.8633197123142058
# Dub R2 0 : 0.011691183692076335
# Unique R2 0 : -0.004704914956825235
# max of weights 0.06545489587756849
# Iteration 10 loss 0.9844090804943687 train RMSE 1.844517436468231 Train R2 10 : 0.01564952913106754 Validation RMSE 10 : 1.8452773109479814 Validation R2 10 : 0.010137398845821988 Dub RMSE 10 : 2.1780891348518865
# Unique RMSE 10 : 1.8455459708496607
# Dub R2 10 : 0.012193533569782256
# Unique R2 10 : 0.0143709278138332
# max of weights 0.06555756945552184
# Iteration 20 loss 0.9818559194152431 train RMSE 1.8421260984443975 Train R2 20 : 0.018200211264344346 Validation RMSE 20 : 1.8427597154631827 Validation R2 20 : 0.012836585115506338 Dub RMSE 20 : 2.176234301155161
# Unique RMSE 20 : 1.8431488061973522
# Dub R2 20 : 0.01387522468513136
# Unique R2 20 : 0.016929716111351745
# max of weights 0.07621777703634383
# Iteration 30 loss 0.9773537413687311 train RMSE 1.8378903049559732 Train R2 30 : 0.022710130413737484 Validation RMSE 30 : 1.8407159965484123 Validation R2 30 : 0.015025004774358308 Dub RMSE 30 : 2.168916574063039
# Unique RMSE 30 : 1.8394457582780546
# Dub R2 30 : 0.020495890049204046
# Unique R2 30 : 0.02087589718921945
# max of weights 0.08835585034253784
# Iteration 40 loss 0.9718683011025246 train RMSE 1.8327080100584932 Train R2 40 : 0.0282136840965177 Validation RMSE 40 : 1.8344423868014108 Validation R2 40 : 0.021727633943896207 Dub RMSE 40 : 2.165285863218581
# Unique RMSE 40 : 1.8340722705355024
# Dub R2 40 : 0.023772474923208442
# Unique R2 40 : 0.026588081447527223
# max of weights 0.10015072532324364
# Iteration 50 loss 0.9637902492191536 train RMSE 1.825047108812554 Train R2 50 : 0.03632103021170252 Validation RMSE 50 : 1.8278926501307504 Validation R2 50 : 0.02870085678499723 Dub RMSE 50 : 2.155478466003436
# Unique RMSE 50 : 1.8267406057122264
# Dub R2 50 : 0.03259585346546301
# Unique R2 50 : 0.03435491329306661
# max of weights 0.11317907351185415
# Iteration 60 loss 0.9525217957630684 train RMSE 1.8143051824565561 Train R2 60 : 0.04763175646432394 Validation RMSE 60 : 1.8145114033714236 Validation R2 60 : 0.04286976322498015 Dub RMSE 60 : 2.1478394076120475
# Unique RMSE 60 : 1.815507624511732
# Dub R2 60 : 0.039440701721664695
# Unique R2 60 : 0.04619427646982477
# max of weights 0.12638353987544276
# Iteration 70 loss 0.9371381793629079 train RMSE 1.7995394596241894 Train R2 70 : 0.0630703741894526 Validation RMSE 70 : 1.8024077550875297 Validation R2 70 : 0.05559619722747444 Dub RMSE 70 : 2.1267294986658305
# Unique RMSE 70 : 1.8014877324106593
# Dub R2 70 : 0.05822951065488391
# Unique R2 70 : 0.06086854264467434
# max of weights 0.14101587780149222
# Iteration 80 loss 0.9150656606802474 train RMSE 1.7781469175946687 Train R2 80 : 0.08521400767563647 Validation RMSE 80 : 1.7793716904572057 Validation R2 80 : 0.07958224866639874 Dub RMSE 80 : 2.1053538025172207
# Unique RMSE 80 : 1.779926761815795
# Dub R2 80 : 0.07706578653159213
# Unique R2 80 : 0.08321386705182299
# max of weights 0.15748973754636855
# Iteration 90 loss 0.8898173138154553 train RMSE 1.7533588822037989 Train R2 90 : 0.11054115372224871 Validation RMSE 90 : 1.7523840659937266 Validation R2 90 : 0.10729036181553442 Dub RMSE 90 : 2.0800195815626017
# Unique RMSE 90 : 1.7548460551390528
# Dub R2 90 : 0.09914391874677364
# Unique R2 90 : 0.10886845511119791
#
# Performance (RMSE) on logP:
# Train: 1.7379551077245743
# Test:  1.7950493103818461
# Dub: 2.0559413511508855
# Unique:  1.7401598901583188
#
# Performance (R2) on logP:
# Train: 0.12610082020086888
# Test:  0.11555119431844796
# Dub: 0.11987975532790074
# Unique:  0.12372165724881179
# --------------------------------------------------------------------------------

# %% [markdown]
# ## logP_wo_parameters

# %% [markdown]
# ### Visualization

# %%
task_params = {'target_name' : 'logP',
               'data_file'   : 'logP_wo_parameters'}

num_epochs = 5
batch_size = 100
normalize = 1
dropout = 0
activation = relu
params = {'fp_length': 50,
            'fp_depth': 4,
            'init_scale':np.exp(-4),
            'l2_penalty':np.exp(-2),
            'conv_width':20}

conv_layer_sizes = [params['conv_width']] * params['fp_depth']
conv_arch_params = {'num_hidden_features' : conv_layer_sizes,
                    'fp_length' : params['fp_length'],
                    'normalize' : normalize,
                    'return_atom_activations':False}

all_radii = range(params['fp_depth'] + 1)

# Plotting parameters
num_figs_per_fp = 11
figsize = (100, 100)
highlight_color = (30.0/255.0, 100.0/255.0, 255.0/255.0)  # A nice light blue.

# %%
trained_network_weights = train_neural_fingerprint()
with open('results.pkl', 'w') as f:
    pickle.dump(trained_network_weights, f)

# Plotting.
with open('results.pkl') as f:
    trained_weights = pickle.load(f)
plot(trained_weights)
# Out:
# Loading data...
# Regression on 8838 training points.
# --------------------------------------------------------------------------------
# Mean predictor
#
# Performance (RMSE) on logP:
# Train: 1.8146042407352028
# Test:  1.8141849992522239
# Dub: 2.1832152392353295
# Unique:  1.8014880653973313
#
# Performance (R2) on logP:
# Train: 0.0
# Test:  -0.0002990500750039704
# Dub: -0.009233034859763123
# Unique:  -7.835254551791238e-05
# --------------------------------------------------------------------------------
# Task params {'fp_length': 50, 'l2_penalty': 0.1353352832366127, 'fp_depth': 4, 'conv_width': 20, 'init_scale': 0.01831563888873418}
# Convnet fingerprints with neural net
# Total number of weights in the network: 30571
# max of weights 0.08535001578936458
# Iteration 0 loss 1.0041956952405227 train RMSE 1.8183273856100233 Train R2 0 : -0.004107743500010308 Validation RMSE 0 : 1.789294284026002 Validation R2 0 : -0.0034116315193561952 Dub RMSE 0 : 2.1911715822316413
# Unique RMSE 0 : 1.8048158473406302
# Dub R2 0 : -0.016602382276143413
# Unique R2 0 : -0.003776535836648165
# max of weights 0.08585993000392719
# Iteration 10 loss 1.00273735062751 train RMSE 1.8170183194398009 Train R2 10 : -0.0026624918518804996 Validation RMSE 10 : 1.8001877783747764 Validation R2 10 : -0.0156666672483865 Dub RMSE 10 : 2.1497013873740247
# Unique RMSE 10 : 1.806769606205297
# Dub R2 10 : 0.021513984942945874
# Unique R2 10 : -0.005950939167965741
# max of weights 0.08939940050440684
# Iteration 20 loss 0.9836876077117314 train RMSE 1.799677497854971 Train R2 20 : 0.016384123481161916 Validation RMSE 20 : 1.7752101542533445 Validation R2 20 : 0.012322571868921828 Dub RMSE 20 : 2.1562788382822995
# Unique RMSE 20 : 1.7874589806602554
# Dub R2 20 : 0.01551706852546253
# Unique R2 20 : 0.01543721395216291
# max of weights 0.09489799237897517
# Iteration 30 loss 0.9833846078515265 train RMSE 1.7993935252022293 Train R2 30 : 0.016694510173216548 Validation RMSE 30 : 1.7788326857296788 Validation R2 30 : 0.00828750804844236 Dub RMSE 30 : 2.141176321309471
# Unique RMSE 30 : 1.7882021488472368
# Dub R2 30 : 0.029259356205449283
# Unique R2 30 : 0.014618344421258755
# max of weights 0.10255027161161659
# Iteration 40 loss 0.9789600105920917 train RMSE 1.7953256460413733 Train R2 40 : 0.021135391505738177 Validation RMSE 40 : 1.765948562157426 Validation R2 40 : 0.02260147146833935 Dub RMSE 40 : 2.162003930488877
# Unique RMSE 40 : 1.7817401067834637
# Dub R2 40 : 0.010282367138795823
# Unique R2 40 : 0.021727241393700192
# max of weights 0.11554277664331668
# Iteration 50 loss 0.9508568890834527 train RMSE 1.76933497000723 Train R2 50 : 0.04927201121959279 Validation RMSE 50 : 1.7416254132670173 Validation R2 50 : 0.04934029034063503 Dub RMSE 50 : 2.1207435048630936
# Unique RMSE 50 : 1.7563279685845943
# Dub R2 50 : 0.047698122453492475
# Unique R2 50 : 0.04943354834946334
# max of weights 0.13074227017093978
# Iteration 60 loss 0.924175327734089 train RMSE 1.744278738253183 Train R2 60 : 0.07600859573400298 Validation RMSE 60 : 1.7200251146880923 Validation R2 60 : 0.07277494498611026 Dub RMSE 60 : 2.0677879773317787
# Unique RMSE 60 : 1.7323635107324011
# Dub R2 60 : 0.09466280944827887
# Unique R2 60 : 0.07519684421711459
# max of weights 0.14503248426568785
# Iteration 70 loss 0.869150199791663 train RMSE 1.6914757460429384 Train R2 70 : 0.1311041824953738 Validation RMSE 70 : 1.6604506914191162 Validation R2 70 : 0.13589294958093767 Dub RMSE 70 : 2.014490266393595
# Unique RMSE 70 : 1.6780407737928973
# Dub R2 70 : 0.1407318862110234
# Unique R2 70 : 0.13228667505999225
# max of weights 0.15898135367213925
# Iteration 80 loss 0.8180032623484047 train RMSE 1.6408456424470546 Train R2 80 : 0.1823421452515025 Validation RMSE 80 : 1.6011223620712074 Validation R2 80 : 0.19653931960117854 Dub RMSE 80 : 1.9610569181803537
# Unique RMSE 80 : 1.6253864243187444
# Dub R2 80 : 0.18571066401970637
# Unique R2 80 : 0.18588734771004334
# max of weights 0.17504794359463996
# Iteration 90 loss 0.7120476975992351 train RMSE 1.5307241577409374 Train R2 90 : 0.2884096834155818 Validation RMSE 90 : 1.5023118843579728 Validation R2 90 : 0.2926476713394701 Dub RMSE 90 : 1.7811071628487498
# Unique RMSE 90 : 1.5195840481418976
# Dub R2 90 : 0.3282952030249038
# Unique R2 90 : 0.2884249698426756
# max of weights 0.18707570746613555
# Iteration 100 loss 0.6251057482994511 train RMSE 1.4340403512257014 Train R2 100 : 0.3754619534756043 Validation RMSE 100 : 1.4080530137643505 Validation R2 100 : 0.378625259354767 Dub RMSE 100 : 1.6378394090047492
# Unique RMSE 100 : 1.4245341847131099
# Dub R2 100 : 0.4320096164796349
# Unique R2 100 : 0.37465886274480675
# max of weights 0.20358407219331232
# Iteration 110 loss 0.5386698465809319 train RMSE 1.3309672148258058 Train R2 110 : 0.4620141257854835 Validation RMSE 110 : 1.3075959530434766 Validation R2 110 : 0.46412596123139616 Dub RMSE 110 : 1.4824238723763856
# Unique RMSE 110 : 1.3235858344056441
# Dub R2 110 : 0.5346891819677307
# Unique R2 110 : 0.4601470621845043
# max of weights 0.2195889182002014
# Iteration 120 loss 0.4604752464477912 train RMSE 1.2302874517792128 Train R2 120 : 0.5403266286934135 Validation RMSE 120 : 1.2121252348622888 Validation R2 120 : 0.5395202171451317 Dub RMSE 120 : 1.3454422452311519
# Unique RMSE 120 : 1.224677351228461
# Dub R2 120 : 0.6167091346716194
# Unique R2 120 : 0.5378163047500442
# max of weights 0.2349046598036898
# Iteration 130 loss 0.41039478743725516 train RMSE 1.1611944240679455 Train R2 130 : 0.5905074164922848 Validation RMSE 130 : 1.1496296142952154 Validation R2 130 : 0.5857796157586285 Dub RMSE 130 : 1.279565775692149
# Unique RMSE 130 : 1.157315332354393
# Dub R2 130 : 0.6533241567668323
# Unique R2 130 : 0.5872618039637363
# max of weights 0.24487250191473459
# Iteration 140 loss 0.38976787445143163 train RMSE 1.1314390167928026 Train R2 140 : 0.6112248845954782 Validation RMSE 140 : 1.1122532486327161 Validation R2 140 : 0.6122757650446727 Dub RMSE 140 : 1.2240656293969119
# Unique RMSE 140 : 1.1244538293968893
# Dub R2 140 : 0.6827455251585666
# Unique R2 140 : 0.6103681023255155
# max of weights 0.2535262606711354
# Iteration 150 loss 0.3578480425779544 train RMSE 1.0838994532275772 Train R2 150 : 0.6432087858995011 Validation RMSE 150 : 1.096007059724523 Validation R2 150 : 0.623519674694885 Dub RMSE 150 : 1.1244872938227994
# Unique RMSE 150 : 1.086671931683169
# Dub R2 150 : 0.732263578520981
# Unique R2 150 : 0.636111653815606
# max of weights 0.2595232220865467
# Iteration 160 loss 0.32092511391232303 train RMSE 1.0262125280352403 Train R2 160 : 0.6801761982139947 Validation RMSE 160 : 1.018607041064921 Validation R2 160 : 0.6748161791007448 Dub RMSE 160 : 1.1331337791388658
# Unique RMSE 160 : 1.0237052590127
# Dub R2 160 : 0.7281303538985954
# Unique R2 160 : 0.6770605384551752
# max of weights 0.26001546542985143
# Iteration 170 loss 0.3165150847682941 train RMSE 1.0190501561248095 Train R2 170 : 0.6846249904075541 Validation RMSE 170 : 1.0095585841240486 Validation R2 170 : 0.6805678433142603 Dub RMSE 170 : 1.1140431857449737
# Unique RMSE 170 : 1.0147777463472443
# Dub R2 170 : 0.7372138921971731
# Unique R2 170 : 0.6826685489567101
# max of weights 0.2625035174762853
# Iteration 180 loss 0.2938717927255363 train RMSE 0.9817368597744867 Train R2 180 : 0.7072975543190523 Validation RMSE 180 : 0.9886039228923427 Validation R2 180 : 0.6936906590814373 Dub RMSE 180 : 1.040227052870118
# Unique RMSE 180 : 0.9835092236934255
# Dub R2 180 : 0.7708844119562753
# Unique R2 180 : 0.7019232361337353
# max of weights 0.26316719466813576
# Iteration 190 loss 0.2957111993350621 train RMSE 0.9847832120223481 Train R2 190 : 0.7054782110027972 Validation RMSE 190 : 0.9938182025630725 Validation R2 190 : 0.690450949807162 Dub RMSE 190 : 1.0634677807566315
# Unique RMSE 190 : 0.9862444663171609
# Dub R2 190 : 0.7605322557725819
# Unique R2 190 : 0.7002629649647358
# max of weights 0.2705223700351065
# Iteration 200 loss 0.27382960379776883 train RMSE 0.947455534704637 Train R2 200 : 0.7273824369597839 Validation RMSE 200 : 0.9395396473745845 Validation R2 200 : 0.7233403616344428 Dub RMSE 200 : 1.0327866419596492
# Unique RMSE 200 : 0.9465660182628091
# Dub R2 200 : 0.7741502710383283
# Unique R2 200 : 0.7238957659699262
# max of weights 0.2839390721679027
# Iteration 210 loss 0.26910066111933695 train RMSE 0.9391457416936162 Train R2 210 : 0.7321435280109672 Validation RMSE 210 : 0.9252831050278234 Validation R2 210 : 0.7316727086695543 Dub RMSE 210 : 1.0276134919551276
# Unique RMSE 210 : 0.9355832468004047
# Dub R2 210 : 0.7764071329678303
# Unique R2 210 : 0.7302657340651766
# max of weights 0.29924127979947723
# Iteration 220 loss 0.2662970245563597 train RMSE 0.9341719544410656 Train R2 220 : 0.7349731915420841 Validation RMSE 220 : 0.9348240407195697 Validation R2 220 : 0.7261105354250803 Dub RMSE 220 : 1.045236524229758
# Unique RMSE 220 : 0.9354413136187543
# Dub R2 220 : 0.7686723725641172
# Unique R2 220 : 0.7303475682338172
# max of weights 0.30709707324042174
# Iteration 230 loss 0.2731290863017289 train RMSE 0.9460847815034842 Train R2 230 : 0.7281706978548129 Validation RMSE 230 : 0.9307927540351654 Validation R2 230 : 0.7284676555111353 Dub RMSE 230 : 1.0728119665611775
# Unique RMSE 230 : 0.9412803276043998
# Dub R2 230 : 0.7563055896953436
# Unique R2 230 : 0.7269707271293335
# max of weights 0.314969642136341
# Iteration 240 loss 0.2667066548971162 train RMSE 0.9348061533052286 Train R2 240 : 0.7346132219373245 Validation RMSE 240 : 0.9483458709557352 Validation R2 240 : 0.7181298431061142 Dub RMSE 240 : 0.9914430276737133
# Unique RMSE 240 : 0.9406095391417323
# Dub R2 240 : 0.791870387661262
# Unique R2 240 : 0.7273597284144919
# max of weights 0.32396726117407243
# Iteration 250 loss 0.24394067559276 train RMSE 0.893790703508227 Train R2 250 : 0.7573904885092491 Validation RMSE 250 : 0.8832530301541519 Validation R2 250 : 0.7554960644252087 Dub RMSE 250 : 1.0235588577553894
# Unique RMSE 250 : 0.8927398862324074
# Dub R2 250 : 0.7781681038792136
# Unique R2 250 : 0.7544040924616764
# max of weights 0.33063368089879314
# Iteration 260 loss 0.24634935723946702 train RMSE 0.8982002501707018 Train R2 260 : 0.7549907389936616 Validation RMSE 260 : 0.8951941558131146 Validation R2 260 : 0.7488402405221333 Dub RMSE 260 : 1.0115680091863115
# Unique RMSE 260 : 0.8982035755664133
# Dub R2 260 : 0.7833351192740665
# Unique R2 260 : 0.7513887327960783
# max of weights 0.3370957531698449
# Iteration 270 loss 0.23366623143711118 train RMSE 0.8746329696285184 Train R2 270 : 0.7676793332367509 Validation RMSE 270 : 0.8792717277772888 Validation R2 270 : 0.7576953213660341 Dub RMSE 270 : 0.965024202770755
# Unique RMSE 270 : 0.878290587413206
# Dub R2 270 : 0.8028145978192961
# Unique R2 270 : 0.76228986152922
# max of weights 0.3431538100544856
# Iteration 280 loss 0.24606905230933024 train RMSE 0.8976608910110601 Train R2 280 : 0.7552849012640558 Validation RMSE 280 : 0.9133575415427928 Validation R2 280 : 0.738544838368017 Dub RMSE 280 : 0.9732000946492155
# Unique RMSE 280 : 0.9036606311826125
# Dub R2 280 : 0.7994592501839263
# Unique R2 280 : 0.7483586696003282
# max of weights 0.3524384964089902
# Iteration 290 loss 0.23178332264288826 train RMSE 0.8710482673560098 Train R2 290 : 0.7695797733656364 Validation RMSE 290 : 0.8717011509434118 Validation R2 290 : 0.761849871199209 Dub RMSE 290 : 0.9589867112567105
# Unique RMSE 290 : 0.8748589158811384
# Dub R2 290 : 0.8052741860940766
# Unique R2 290 : 0.7641438025465452
# max of weights 0.3574220637109623
# Iteration 300 loss 0.23503016092073503 train RMSE 0.8771368810174313 Train R2 300 : 0.7663472475554131 Validation RMSE 300 : 0.8632912822962208 Validation R2 300 : 0.7664228836059261 Dub RMSE 300 : 0.9875224631140465
# Unique RMSE 300 : 0.8749644173899738
# Dub R2 300 : 0.7935131894997989
# Unique R2 300 : 0.7640869140937634
# max of weights 0.3660653193770359
# Iteration 310 loss 0.229808142201943 train RMSE 0.8672587436139955 Train R2 310 : 0.7715803135120702 Validation RMSE 310 : 0.8721544433309709 Validation R2 310 : 0.7616021264112766 Dub RMSE 310 : 0.9823327298436727
# Unique RMSE 310 : 0.872048334616082
# Dub R2 310 : 0.7956777896722049
# Unique R2 310 : 0.7656567966742858
# max of weights 0.3648093610016024
# Iteration 320 loss 0.23637423191422063 train RMSE 0.879599658829229 Train R2 320 : 0.7650333302767407 Validation RMSE 320 : 0.8671635119963099 Validation R2 320 : 0.7643227982234859 Dub RMSE 320 : 1.019190677943093
# Unique RMSE 320 : 0.8773968720832209
# Dub R2 320 : 0.7800574606630412
# Unique R2 320 : 0.762773385114202
# max of weights 0.3671449211217113
# Iteration 330 loss 0.23337906946155945 train RMSE 0.8739508376380435 Train R2 330 : 0.7680415687507148 Validation RMSE 330 : 0.8847283843662398 Validation R2 330 : 0.7546785610053377 Dub RMSE 330 : 0.928954567599862
# Unique RMSE 330 : 0.8817070557102747
# Dub R2 330 : 0.8172794901639745
# Unique R2 330 : 0.7604369242055439
# max of weights 0.37134458687307076
# Iteration 340 loss 0.21293096304399745 train RMSE 0.8345295126759653 Train R2 340 : 0.7884955268619777 Validation RMSE 340 : 0.8314472139169565 Validation R2 340 : 0.7833369030053067 Dub RMSE 340 : 0.9565430855554108
# Unique RMSE 340 : 0.8366464784920957
# Dub R2 340 : 0.8062652962940389
# Unique R2 340 : 0.7842974779976497
# max of weights 0.37316234731692516
# Iteration 350 loss 0.21738989405024894 train RMSE 0.8432744256988914 Train R2 350 : 0.7840396532807818 Validation RMSE 350 : 0.8456020792513916 Validation R2 350 : 0.7758970020872101 Dub RMSE 350 : 0.964623126845349
# Unique RMSE 350 : 0.8459950072985605
# Dub R2 350 : 0.8029784691145571
# Unique R2 350 : 0.7794501086640534
# max of weights 0.3757497777034769
# Iteration 360 loss 0.20686844862505638 train RMSE 0.8224715767692723 Train R2 360 : 0.7945633361450404 Validation RMSE 360 : 0.8257627675174528 Validation R2 360 : 0.7862893444839077 Dub RMSE 360 : 0.9397330724088484
# Unique RMSE 360 : 0.8270591773302826
# Dub R2 360 : 0.8130147401202671
# Unique R2 360 : 0.7892127110111455
# max of weights 0.3783184049102351
# Iteration 370 loss 0.21681249115862355 train RMSE 0.8421268214882998 Train R2 370 : 0.7846270501142404 Validation RMSE 370 : 0.8594421323090154 Validation R2 370 : 0.768501136977324 Dub RMSE 370 : 0.9297800664455705
# Unique RMSE 370 : 0.8499651227013649
# Dub R2 370 : 0.8169546032558639
# Unique R2 370 : 0.7773752428398282
# max of weights 0.3837437388708765
# Iteration 380 loss 0.20932382238447955 train RMSE 0.827340189664821 Train R2 380 : 0.7921239767030004 Validation RMSE 380 : 0.833189499398382 Validation R2 380 : 0.7824279229203739 Dub RMSE 380 : 0.9127829943150112
# Unique RMSE 380 : 0.8345039613173445
# Dub R2 380 : 0.8235858444900264
# Unique R2 380 : 0.7854008224295372
# max of weights 0.38464359573320206
# Iteration 390 loss 0.21219093952962292 train RMSE 0.8330069451502313 Train R2 390 : 0.7892665866551377 Validation RMSE 390 : 0.8198045906138018 Validation R2 390 : 0.7893622176827045 Dub RMSE 390 : 0.961058667775122
# Unique RMSE 390 : 0.8320669176680773
# Dub R2 390 : 0.8044318401681742
# Unique R2 390 : 0.7866524016518702
# max of weights 0.3893164477507604
# Iteration 400 loss 0.20465803707754263 train RMSE 0.817965332402832 Train R2 400 : 0.796808305558381 Validation RMSE 400 : 0.8270373982180852 Validation R2 400 : 0.785629076400797 Dub RMSE 400 : 0.929613029336716
# Unique RMSE 400 : 0.8256835908722406
# Dub R2 400 : 0.8170203663938291
# Unique R2 400 : 0.7899133017714755
# max of weights 0.3839547066104063
# Iteration 410 loss 0.20756155247529565 train RMSE 0.8237534758114682 Train R2 410 : 0.7939224525031724 Validation RMSE 410 : 0.8163934739657904 Validation R2 410 : 0.7911114521553395 Dub RMSE 410 : 0.9677737756662765
# Unique RMSE 410 : 0.8246020066032552
# Dub R2 410 : 0.8016893451544023
# Unique R2 410 : 0.7904633372706104
# max of weights 0.3838823439922559
# Iteration 420 loss 0.20520146793341962 train RMSE 0.8190019575910579 Train R2 420 : 0.7962929607376955 Validation RMSE 420 : 0.8254284061255313 Validation R2 420 : 0.7864623775346464 Dub RMSE 420 : 0.8853046460110988
# Unique RMSE 420 : 0.8280429793390944
# Dub R2 420 : 0.8340474858904818
# Unique R2 420 : 0.7887109420906404
# max of weights 0.38561314676670166
# Iteration 430 loss 0.19036692978301092 train RMSE 0.7886065171428359 Train R2 430 : 0.8111326526609737 Validation RMSE 430 : 0.7927506391818682 Validation R2 430 : 0.8030351255078045 Dub RMSE 430 : 0.908456218894913
# Unique RMSE 430 : 0.7943374116619756
# Dub R2 430 : 0.8252543578784484
# Unique R2 430 : 0.8055619383687276
# max of weights 0.3858943170010474
# Iteration 440 loss 0.1918334863355846 train RMSE 0.7916566735776115 Train R2 440 : 0.8096688325990715 Validation RMSE 440 : 0.7999606324212283 Validation R2 440 : 0.7994360787163144 Dub RMSE 440 : 0.9136218989966348
# Unique RMSE 440 : 0.7981911872944559
# Dub R2 440 : 0.8232614241840815
# Unique R2 440 : 0.8036707059025162
#
# Performance (RMSE) on logP:
# Train: 0.7882765129488928
# Test:  0.8399708726205302
# Dub: 0.9039245630138911
# Unique:  0.7956045013820937
#
# Performance (R2) on logP:
# Train: 0.8112906883214202
# Test:  0.7855652499189894
# Dub: 0.8269933784575323
# Unique:  0.8049411266965805
# --------------------------------------------------------------------------------
# Loading data...
# Convnet fingerprints with neural net
# FP 0 has linear regression coefficient -0.0344252496511
# radius: 1 atom list: [13, 15, 16, 17, 18, 14] activation 0.0313388872803712
# radius: 1 atom list: [8, 9] activation 0.03093855947174184
# radius: 1 atom list: [3, 0, 2, 1] activation 0.030921512976782688
# radius: 1 atom list: [14, 13] activation 0.030684394844317474
# radius: 1 atom list: [0, 1] activation 0.030624310566950055
# radius: 1 atom list: [5, 6] activation 0.030352147398152642
# radius: 1 atom list: [9, 11, 8, 10] activation 0.030338804153475184
# radius: 1 atom list: [6, 9] activation 0.030304268392541783
# radius: 1 atom list: [1, 3, 0, 2] activation 0.03029578635001031
# radius: 1 atom list: [4, 3] activation 0.030264942708296032
# radius: 1 atom list: [9, 6] activation 0.030259553000086755
# FP 1 has linear regression coefficient -0.0584129545551
# radius: 3 atom list: [2, 5, 6, 1, 4, 3, 0] activation 0.05397502172403535
# radius: 3 atom list: [1, 3, 0, 2, 4] activation 0.053816874404087736
# radius: 3 atom list: [4, 0, 1, 2, 3] activation 0.05374126591195196
# radius: 3 atom list: [0, 3, 5, 2, 1, 4] activation 0.053718382043473296
# radius: 3 atom list: [3, 6, 10, 0, 5, 2, 1, 4] activation 0.05361294820256859
# radius: 3 atom list: [1, 4, 0, 3, 5, 2] activation 0.05359336559228286
# radius: 3 atom list: [6, 7, 0, 2, 3, 1, 5, 4, 8, 9] activation 0.05357917168204698
# radius: 3 atom list: [1, 4, 0, 3, 2, 5] activation 0.053578364409001294
# radius: 3 atom list: [7, 8, 6, 11, 13, 9, 10, 12] activation 0.053554339120157814
# radius: 3 atom list: [16, 5, 0, 2, 1, 4, 3, 6] activation 0.05355433912015779
# radius: 3 atom list: [6, 7, 9, 3, 8, 5, 4, 10] activation 0.053552183859916835
# FP 2 has linear regression coefficient -0.0395456062788
# radius: 1 atom list: [13, 15, 16, 17, 18, 14] activation 0.03699924752726367
# radius: 1 atom list: [8, 9] activation 0.03595965545540508
# radius: 1 atom list: [14, 13] activation 0.03565304362421488
# radius: 1 atom list: [3, 0, 2, 1] activation 0.03559796293464452
# radius: 1 atom list: [6, 9] activation 0.035157117791050456
# radius: 1 atom list: [1, 0] activation 0.0350303507403211
# radius: 1 atom list: [0, 1] activation 0.03496382013651029
# radius: 1 atom list: [9, 6] activation 0.03492574245942847
# radius: 1 atom list: [4, 3] activation 0.034856281242398264
# radius: 1 atom list: [0, 1] activation 0.0348242380182903
# radius: 1 atom list: [4, 3] activation 0.034787880098310346
# FP 3 has linear regression coefficient 0.0533146098312
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.04706745881189107
# radius: 2 atom list: [6, 9, 11, 7, 8, 3, 5, 13] activation 0.045733091672549485
# radius: 2 atom list: [4, 3, 8, 2, 5, 7, 9, 13] activation 0.04522344416979549
# radius: 2 atom list: [2, 5, 8, 10, 6, 4, 7, 3] activation 0.04506109715891897
# radius: 2 atom list: [10, 11, 8, 13, 12, 7, 9, 14] activation 0.04480244264305558
# radius: 2 atom list: [19, 20, 27, 16, 17, 18] activation 0.044570900797055495
# radius: 2 atom list: [7, 4, 5, 6, 8, 11] activation 0.04453718989045743
# radius: 2 atom list: [1, 2, 3, 5, 4, 7] activation 0.04453212641678778
# radius: 2 atom list: [16, 18, 19, 20, 15, 14] activation 0.04438146178519373
# radius: 2 atom list: [6, 12, 7, 3, 8, 9, 10, 11] activation 0.04425206331732616
# radius: 2 atom list: [6, 2, 7, 8, 14, 9, 10] activation 0.04421273714419842
# FP 4 has linear regression coefficient 0.0317828941997
# radius: 1 atom list: [3, 4, 5, 11, 17] activation 0.030694502880681818
# radius: 1 atom list: [8, 12, 10, 11, 9] activation 0.03004900278428653
# radius: 1 atom list: [8, 9, 10, 11, 7] activation 0.0298803020930663
# radius: 1 atom list: [10, 9, 7, 8, 6] activation 0.029620033303819186
# radius: 1 atom list: [9, 7, 8, 10, 11] activation 0.029535210111918713
# radius: 1 atom list: [8, 3, 2, 5, 4] activation 0.029514982989797923
# radius: 1 atom list: [5, 4, 6, 8, 7] activation 0.029350069500868443
# radius: 1 atom list: [2, 4, 7, 3, 5] activation 0.029342372084627026
# radius: 1 atom list: [6, 8, 7, 9, 10] activation 0.029326027103890585
# radius: 1 atom list: [15, 10, 13, 12, 14] activation 0.029187070861612683
# radius: 1 atom list: [4, 9, 14, 15] activation 0.029093877340379676
# FP 5 has linear regression coefficient 0.0740739799102
# radius: 3 atom list: [2, 15, 4, 1, 3, 0, 5, 13, 16, 17, 19, 20] activation 0.0922683512483116
# radius: 3 atom list: [7, 11, 10, 12, 16, 4, 8, 17, 9, 6, 13, 15] activation 0.0917017770539037
# radius: 3 atom list: [10, 11, 12, 13, 14, 15, 16] activation 0.09132188865416825
# radius: 3 atom list: [1, 3, 5, 6, 8, 2, 4, 16, 18, 12, 14, 7, 15, 17] activation 0.0912897507356283
# radius: 3 atom list: [14, 10, 3, 5, 7, 8, 2, 6, 4, 9, 19, 17, 18, 16] activation 0.09111611347419118
# radius: 3 atom list: [9, 0, 11, 15, 1, 3, 4, 10, 12, 14, 2, 5] activation 0.09103216921967527
# radius: 3 atom list: [8, 10, 15, 4, 13, 12, 2, 9, 14, 16, 17, 7, 3, 5, 6] activation 0.09078781719574952
# radius: 3 atom list: [1, 3, 5, 6, 7, 0, 13, 16, 4, 2, 15, 17] activation 0.09078196732887835
# radius: 3 atom list: [2, 4, 8, 1, 13, 15, 3, 5, 6, 10, 12, 14, 16, 7] activation 0.09060313041344285
# radius: 3 atom list: [4, 9, 17, 2, 6, 18, 3, 5, 7, 8, 10, 14, 16, 19] activation 0.09056762201588577
# radius: 3 atom list: [19, 2, 3, 5, 13, 8, 4, 6, 7, 9, 16, 18, 15, 17] activation 0.09041731488211581
# FP 6 has linear regression coefficient 0.0554311922804
# radius: 3 atom list: [5, 10, 2, 3, 4, 6, 7, 8, 11, 12, 14, 15] activation 0.048302930978631906
# radius: 3 atom list: [15, 16, 8, 10, 9, 4, 5, 6, 7, 11, 12, 13] activation 0.04828063057567443
# radius: 3 atom list: [7, 6, 11, 9, 8, 10, 12, 13] activation 0.04821978807075333
# radius: 3 atom list: [5, 6, 4, 7, 9, 8] activation 0.048212975570741244
# radius: 3 atom list: [6, 3, 5, 8, 1, 4, 7] activation 0.048181569777448044
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.048168699637680744
# radius: 3 atom list: [1, 3, 4, 11, 5, 10, 12, 17, 0, 2] activation 0.04813673149154373
# radius: 3 atom list: [16, 18, 19, 20, 17, 11, 15, 13, 14] activation 0.04806972469951964
# radius: 3 atom list: [2, 5, 8, 10, 6, 4, 7, 9, 3] activation 0.047920946028688245
# radius: 3 atom list: [1, 0, 2, 10, 3, 5, 4, 9, 11, 15] activation 0.04789802222432357
# radius: 3 atom list: [8, 0, 3, 5, 1, 2, 4, 6, 7, 19, 16, 18, 20] activation 0.0478940143101539
# FP 7 has linear regression coefficient 0.0436403010435
# radius: 2 atom list: [6, 9, 11, 7, 8, 3, 5, 13] activation 0.04192025176260978
# radius: 2 atom list: [4, 3, 8, 2, 5, 7, 9, 13] activation 0.04141964376271767
# radius: 2 atom list: [10, 11, 8, 13, 12, 7, 9, 14] activation 0.041195198060070895
# radius: 2 atom list: [2, 5, 8, 10, 6, 4, 7, 3] activation 0.041155347514681494
# radius: 2 atom list: [6, 12, 7, 3, 8, 9, 10, 11] activation 0.040898504104527965
# radius: 2 atom list: [6, 2, 7, 8, 14, 9, 10] activation 0.040857484443325466
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.04083139603050253
# radius: 2 atom list: [19, 20, 27, 16, 17, 18] activation 0.04048213885074323
# radius: 2 atom list: [8, 13, 15, 7, 3, 5, 6] activation 0.040451667948553795
# radius: 2 atom list: [19, 6, 8, 17, 5, 7, 9] activation 0.040449793526340434
# radius: 2 atom list: [7, 4, 5, 6, 8, 11] activation 0.04034662372789255
# FP 8 has linear regression coefficient 0.0498610378862
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.04436364671306817
# radius: 2 atom list: [19, 5, 2, 4, 6, 7, 8, 16, 18, 20] activation 0.04320683833752992
# radius: 2 atom list: [11, 2, 13, 3, 4, 6, 7, 5, 14, 15] activation 0.042805080236925606
# radius: 2 atom list: [15, 9, 3, 5, 6, 7, 12, 14, 16, 8] activation 0.04271806679259634
# radius: 2 atom list: [4, 16, 2, 17, 3, 5, 6, 7, 13, 15] activation 0.04259826826381979
# radius: 2 atom list: [8, 5, 12, 14, 2, 4, 6, 7, 13, 15] activation 0.042330277966307533
# radius: 2 atom list: [16, 10, 5, 7, 8, 9, 13, 15, 11, 17] activation 0.0423042897806678
# radius: 2 atom list: [17, 2, 18, 3, 5, 6, 7, 14, 16, 4] activation 0.04221466834453979
# radius: 2 atom list: [8, 9, 10, 11, 7] activation 0.04207948179004244
# radius: 2 atom list: [4, 2, 0, 1, 3] activation 0.041899955565856406
# radius: 2 atom list: [7, 8, 9, 10, 11] activation 0.04184039830674033
# FP 9 has linear regression coefficient -0.0588043182796
# radius: 4 atom list: [6, 7, 0, 2, 3, 1, 5, 4, 8, 9] activation 0.0538680650648846
# radius: 4 atom list: [3, 6, 7, 8, 1, 4, 0, 2, 5] activation 0.053819608776944125
# radius: 4 atom list: [1, 2, 3, 0, 4] activation 0.05381705158116561
# radius: 4 atom list: [3, 1, 4, 7, 15, 8, 0, 2, 5, 6] activation 0.05381700335095583
# radius: 4 atom list: [62, 60, 2, 3, 4, 59, 1, 0, 61] activation 0.0538110758080164
# radius: 4 atom list: [0, 4, 1, 2, 3] activation 0.05380892007869663
# radius: 4 atom list: [3, 4, 6, 7, 9, 10, 1, 5, 0, 2] activation 0.05380718708410882
# radius: 4 atom list: [19, 21, 22, 23, 4, 25, 24, 26, 6, 5, 8] activation 0.053800711312149876
# radius: 4 atom list: [3, 2, 4, 5, 6, 0, 1] activation 0.05380032447785957
# radius: 4 atom list: [17, 18, 3, 15, 19, 14, 16] activation 0.053799911008895154
# radius: 4 atom list: [9, 13, 7, 8, 11, 15, 10, 12, 14] activation 0.053798353522733385
# FP 10 has linear regression coefficient 0.0346545188939
# radius: 1 atom list: [3, 4, 5, 11, 17] activation 0.02982716015375249
# radius: 1 atom list: [6, 13, 4, 5] activation 0.029588987376228337
# radius: 1 atom list: [12, 13, 4, 9] activation 0.029537658555525332
# radius: 1 atom list: [2, 7, 9, 10] activation 0.02949865069695775
# radius: 1 atom list: [4, 9, 14, 15] activation 0.02948677062351673
# radius: 1 atom list: [1, 20, 2, 3] activation 0.029482792385944614
# radius: 1 atom list: [3, 4, 11, 1] activation 0.02946182429512376
# radius: 1 atom list: [7, 9, 10, 2] activation 0.029391466879223643
# radius: 1 atom list: [8, 9, 11, 6] activation 0.02935544868076129
# radius: 1 atom list: [3, 4, 20, 1] activation 0.029334267492749994
# radius: 1 atom list: [8, 12, 10, 11, 9] activation 0.029323481765244325
# FP 11 has linear regression coefficient 0.107895931713
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 9] activation 0.5625134675861508
# radius: 4 atom list: [0, 1, 2, 3, 4, 5, 6, 7, 8] activation 0.5589780476098642
# radius: 4 atom list: [7, 8, 9, 10, 2, 3, 4, 5, 6] activation 0.5578630610514448
# radius: 4 atom list: [3, 4, 5, 6, 7, 8, 9, 10, 11] activation 0.5576448228482443
# radius: 4 atom list: [13, 5, 6, 7, 8, 9, 10, 11, 12] activation 0.5572379795748345
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 9] activation 0.5568780470534647
# radius: 4 atom list: [9, 10, 11, 12, 13, 14, 15, 16, 17] activation 0.5564978344660908
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 8, 9] activation 0.5558515660466598
# radius: 4 atom list: [1, 2, 3, 4, 5, 6, 7, 0, 8] activation 0.5554219584806276
# radius: 4 atom list: [2, 3, 4, 5, 6, 7, 0, 8, 1] activation 0.5543005155339857
# radius: 4 atom list: [8, 1, 2, 3, 4, 5, 6, 7, 0] activation 0.5540810200277402
# FP 12 has linear regression coefficient -0.06188806459
# radius: 4 atom list: [1, 0, 3, 4, 2] activation 0.08303455061701313
# radius: 4 atom list: [4, 0, 1, 2, 3] activation 0.0796767205586386
# radius: 4 atom list: [9, 10, 12, 6, 7, 8, 11] activation 0.07965454869589238
# radius: 4 atom list: [3, 6, 7, 9, 10, 0, 5, 2, 1, 4] activation 0.07952505948053483
# radius: 4 atom list: [0, 3, 5, 2, 1, 4] activation 0.07933874519837134
# radius: 4 atom list: [1, 4, 0, 3, 5, 2] activation 0.07921685022615889
# radius: 4 atom list: [1, 4, 0, 3, 2, 5, 6] activation 0.07896159702618727
# radius: 4 atom list: [0, 3, 1, 2, 4] activation 0.07895346420762563
# radius: 4 atom list: [5, 3, 0, 4, 6, 1, 2] activation 0.07883448200268789
# radius: 4 atom list: [15, 16, 5, 0, 2, 1, 4, 3, 6, 7] activation 0.07876273952864053
# radius: 4 atom list: [2, 5, 6, 1, 4, 3, 0] activation 0.0787601647975948
# FP 13 has linear regression coefficient 0.0205534171478
# radius: 1 atom list: [1, 20, 2, 3] activation 0.02664711763001749
# radius: 1 atom list: [6, 13, 4, 5] activation 0.026638644471911173
# radius: 1 atom list: [8, 9, 11, 6] activation 0.02663065617265131
# radius: 1 atom list: [3, 4, 11, 1] activation 0.026622765950054247
# radius: 1 atom list: [3, 4, 20, 1] activation 0.026606044114534776
# radius: 1 atom list: [5, 6, 7, 15] activation 0.026519243757848997
# radius: 1 atom list: [7, 4, 6, 8] activation 0.026502459937496187
# radius: 1 atom list: [5, 8, 1, 4] activation 0.02650127132673895
# radius: 1 atom list: [1, 4, 5, 6] activation 0.026408813702213138
# radius: 1 atom list: [3, 4, 5, 11, 17] activation 0.02624432736458539
# radius: 1 atom list: [14, 15, 16, 12] activation 0.026201053830289815
# FP 14 has linear regression coefficient 0.033492502904
# radius: 1 atom list: [3, 4, 5, 11, 17] activation 0.029055721026454814
# radius: 1 atom list: [8, 12, 10, 11, 9] activation 0.028554802123865627
# radius: 1 atom list: [8, 9, 10, 11, 7] activation 0.028525391816126983
# radius: 1 atom list: [8, 3, 2, 5, 4] activation 0.028299625025311966
# radius: 1 atom list: [9, 7, 8, 10, 11] activation 0.02814248023377779
# radius: 1 atom list: [2, 4, 7, 3, 5] activation 0.028133481318312687
# radius: 1 atom list: [10, 9, 7, 8, 6] activation 0.02804855278469719
# radius: 1 atom list: [5, 4, 6, 8, 7] activation 0.02790121378021962
# radius: 1 atom list: [6, 8, 7, 9, 10] activation 0.0278290292729941
# radius: 1 atom list: [3, 4, 5, 2, 1] activation 0.027802553878728455
# radius: 1 atom list: [12, 13, 9, 10, 11] activation 0.02771944383033887
# FP 15 has linear regression coefficient -0.0488990266938
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.03905412953243424
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.03901171005710125
# radius: 2 atom list: [2, 1, 4, 3, 0] activation 0.03900408497021885
# radius: 2 atom list: [0, 2, 1, 3, 4] activation 0.03895963454541366
# radius: 2 atom list: [4, 0, 2, 3, 1] activation 0.03885127347517907
# radius: 2 atom list: [3, 1, 4, 0, 2] activation 0.03881538372385526
# radius: 2 atom list: [1, 0, 2, 4, 3] activation 0.03880286973928023
# radius: 2 atom list: [0, 2, 4, 1, 3, 12] activation 0.038716241416157704
# radius: 2 atom list: [9, 11, 7, 8, 10] activation 0.03869488812006034
# radius: 2 atom list: [18, 16, 17, 14, 15] activation 0.038655695273560525
# radius: 2 atom list: [7, 8, 9, 10, 11] activation 0.03862473126002487
# FP 16 has linear regression coefficient 0.0328093368038
# radius: 1 atom list: [3, 4, 5, 11, 17] activation 0.031242414581346505
# radius: 1 atom list: [8, 12, 10, 11, 9] activation 0.03037200569551256
# radius: 1 atom list: [8, 9, 10, 11, 7] activation 0.030268436173761713
# radius: 1 atom list: [9, 7, 8, 10, 11] activation 0.029768876467418406
# radius: 1 atom list: [8, 3, 2, 5, 4] activation 0.029743177737263298
# radius: 1 atom list: [2, 4, 7, 3, 5] activation 0.029530375351988644
# radius: 1 atom list: [5, 4, 6, 8, 7] activation 0.029434423740335322
# radius: 1 atom list: [12, 13, 9, 10, 11] activation 0.029393568830045284
# radius: 1 atom list: [9, 11, 12, 13, 10] activation 0.029340952390585782
# radius: 1 atom list: [3, 4, 5, 2, 1] activation 0.029332538591753554
# radius: 1 atom list: [10, 9, 7, 8, 6] activation 0.029211740722918867
# FP 17 has linear regression coefficient -0.053380530104
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.04648548882591396
# radius: 2 atom list: [0, 2, 1, 3, 4] activation 0.04625236657458367
# radius: 2 atom list: [2, 1, 4, 3, 0] activation 0.04623559884371096
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.04612986550676859
# radius: 2 atom list: [3, 1, 4, 0, 2] activation 0.0456358269942443
# radius: 2 atom list: [1, 0, 2, 4, 3] activation 0.045592563451677254
# radius: 2 atom list: [4, 0, 2, 3, 1] activation 0.04559094688417126
# radius: 2 atom list: [0, 2, 4, 1, 3, 12] activation 0.04519011826823116
# radius: 2 atom list: [14, 16, 9, 15, 10, 11] activation 0.04518654256499342
# radius: 2 atom list: [9, 11, 7, 8, 10] activation 0.045167796722560535
# radius: 2 atom list: [10, 9, 18, 19, 20, 11] activation 0.04513701241792367
# FP 18 has linear regression coefficient -0.0566370070571
# radius: 4 atom list: [14, 5, 8, 17, 15, 16, 18, 19, 6, 7, 9] activation 0.047519148031711214
# radius: 4 atom list: [10, 11, 12, 5, 6, 9, 13, 14, 15, 7, 8] activation 0.047518435424660506
# radius: 4 atom list: [4, 0, 1, 2, 3, 5, 6, 14, 15] activation 0.047516670841201446
# radius: 4 atom list: [0, 1, 2, 3, 4, 5] activation 0.047514240916352035
# radius: 4 atom list: [0, 1, 2, 3, 6, 13, 14, 4, 5] activation 0.04751148743392476
# radius: 4 atom list: [50, 44, 45, 46, 47, 48, 49] activation 0.04751073588883061
# radius: 4 atom list: [7, 2, 6, 11, 1, 3, 8, 9, 10] activation 0.047510507734301356
# radius: 4 atom list: [2, 0, 15, 3, 12, 13, 14, 1] activation 0.047510214528214696
# radius: 4 atom list: [0, 14, 1, 3, 2, 11, 12, 13] activation 0.0475093822661178
# radius: 4 atom list: [4, 5, 6, 0, 3, 1, 2, 8, 7] activation 0.04750905451278071
# radius: 4 atom list: [2, 3, 4, 5, 0, 1] activation 0.047508443176458935
# FP 19 has linear regression coefficient 0.0356258124184
# radius: 1 atom list: [3, 4, 5, 11, 17] activation 0.03271984450383495
# radius: 1 atom list: [8, 12, 10, 11, 9] activation 0.03169045634089369
# radius: 1 atom list: [8, 9, 10, 11, 7] activation 0.03150194710279588
# radius: 1 atom list: [10, 9, 7, 8, 6] activation 0.031135917140737737
# radius: 1 atom list: [9, 7, 8, 10, 11] activation 0.03102363003050561
# radius: 1 atom list: [8, 3, 2, 5, 4] activation 0.030934912807005954
# radius: 1 atom list: [5, 4, 6, 8, 7] activation 0.030871948149888414
# radius: 1 atom list: [6, 8, 7, 9, 10] activation 0.030866175764210704
# radius: 1 atom list: [2, 4, 7, 3, 5] activation 0.030709365588294887
# radius: 1 atom list: [9, 11, 12, 13, 10] activation 0.030581230946703175
# radius: 1 atom list: [12, 13, 9, 10, 11] activation 0.030571501425606717
# FP 20 has linear regression coefficient 0.05599217232
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.05379574130016277
# radius: 2 atom list: [6, 9, 11, 7, 8, 3, 5, 13] activation 0.050575542157599816
# radius: 2 atom list: [4, 3, 8, 2, 5, 7, 9, 13] activation 0.04997157543329566
# radius: 2 atom list: [2, 5, 8, 10, 6, 4, 7, 3] activation 0.049847885318194084
# radius: 2 atom list: [1, 2, 3, 5, 4, 7] activation 0.04934607800104771
# radius: 2 atom list: [7, 4, 5, 6, 8, 11] activation 0.049338900857688286
# radius: 2 atom list: [10, 11, 8, 13, 12, 7, 9, 14] activation 0.049338654956004445
# radius: 2 atom list: [19, 20, 27, 16, 17, 18] activation 0.049302491338176616
# radius: 3 atom list: [6, 12, 7, 3, 8, 9, 10, 11] activation 0.04928046394671868
# radius: 2 atom list: [8, 9, 10, 11, 7] activation 0.049200652659648
# radius: 2 atom list: [16, 18, 19, 20, 15, 14] activation 0.04913391692437695
# FP 21 has linear regression coefficient -0.0779306634441
# radius: 3 atom list: [1, 3, 0, 2, 4] activation 0.14401444836964047
# radius: 3 atom list: [12, 13, 14, 15, 16, 17, 18, 11] activation 0.14184402735888663
# radius: 3 atom list: [0, 3, 5, 2, 4, 1] activation 0.13958221113852617
# radius: 3 atom list: [5, 7, 9, 6, 8, 4] activation 0.13686290441458088
# radius: 3 atom list: [1, 0, 3, 4, 2] activation 0.13660700525616748
# radius: 3 atom list: [3, 4, 0, 2, 1] activation 0.13233427668786224
# radius: 3 atom list: [9, 10, 12, 8, 11] activation 0.13148676857436106
# radius: 3 atom list: [0, 2, 1, 3, 4] activation 0.13125161434071145
# radius: 3 atom list: [3, 6, 10, 0, 5, 2, 1, 4] activation 0.13105323803729582
# radius: 3 atom list: [2, 1, 4, 3, 0] activation 0.13096483104388437
# radius: 3 atom list: [2, 1, 4, 11, 0, 3] activation 0.13021828486150858
# FP 22 has linear regression coefficient 0.0321566698091
# radius: 1 atom list: [3, 4, 5, 11, 17] activation 0.030695852647778594
# radius: 1 atom list: [10, 9, 7, 8, 6] activation 0.029932305017104206
# radius: 1 atom list: [8, 12, 10, 11, 9] activation 0.029842348560594843
# radius: 1 atom list: [8, 9, 10, 11, 7] activation 0.029665371693688103
# radius: 1 atom list: [0, 1, 3, 4, 2] activation 0.02963847646753767
# radius: 1 atom list: [6, 8, 7, 9, 10] activation 0.029579809145639888
# radius: 1 atom list: [15, 10, 13, 12, 14] activation 0.029515839830882865
# radius: 1 atom list: [5, 4, 6, 8, 7] activation 0.029371460914648102
# radius: 1 atom list: [9, 7, 8, 10, 11] activation 0.029347203442301482
# radius: 1 atom list: [10, 12, 13, 14, 11] activation 0.02933320183949457
# radius: 1 atom list: [1, 2, 20, 3, 0] activation 0.029264643130119332
# FP 23 has linear regression coefficient -0.0553450664899
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.04451843100519789
# radius: 2 atom list: [0, 2, 1, 3, 4] activation 0.044340653059656635
# radius: 2 atom list: [2, 1, 4, 3, 0] activation 0.04431923384763695
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.04420444108275557
# radius: 2 atom list: [3, 1, 4, 0, 2] activation 0.043822932997818656
# radius: 2 atom list: [1, 0, 2, 4, 3] activation 0.043785238479644155
# radius: 2 atom list: [4, 0, 2, 3, 1] activation 0.043746416463603964
# radius: 2 atom list: [14, 16, 9, 15, 10, 11] activation 0.04351568244441727
# radius: 2 atom list: [10, 9, 18, 19, 20, 11] activation 0.04347306714709316
# radius: 2 atom list: [4, 1, 3] activation 0.04347106707399604
# radius: 2 atom list: [0, 2, 4, 1, 3, 12] activation 0.04341235745293607
# FP 24 has linear regression coefficient 0.08298864824
# radius: 3 atom list: [10, 11, 12, 13, 14, 15, 16] activation 0.14518770883551121
# radius: 3 atom list: [2, 15, 4, 1, 3, 0, 5, 13, 16, 17, 19, 20] activation 0.14268867861172296
# radius: 3 atom list: [8, 10, 15, 4, 13, 12, 2, 9, 14, 16, 17, 7, 3, 5, 6] activation 0.14265490624569696
# radius: 3 atom list: [8, 2, 3, 4, 5, 6, 7, 11] activation 0.14253697896883966
# radius: 3 atom list: [1, 3, 5, 6, 8, 2, 4, 16, 18, 12, 14, 7, 15, 17] activation 0.1424757753200174
# radius: 3 atom list: [0, 1, 2, 3, 4, 5, 6] activation 0.14234479829077512
# radius: 3 atom list: [14, 10, 3, 5, 7, 8, 2, 6, 4, 9, 19, 17, 18, 16] activation 0.14198932014343102
# radius: 3 atom list: [4, 5, 6, 7, 8, 9, 10] activation 0.1416680224292479
# radius: 3 atom list: [1, 2, 3, 4, 5, 6, 7] activation 0.14143165724124812
# radius: 3 atom list: [7, 8, 9, 10, 11, 5, 6] activation 0.14122650410791723
# radius: 3 atom list: [7, 11, 10, 12, 16, 4, 8, 17, 9, 6, 13, 15] activation 0.1411271456321658
# FP 25 has linear regression coefficient 0.0579258188931
# radius: 3 atom list: [16, 17, 18, 19, 20, 9, 13, 15] activation 0.05017485363796414
# radius: 3 atom list: [1, 2, 3, 4, 5, 6, 0] activation 0.05017059814489322
# radius: 3 atom list: [1, 2, 3, 4, 5, 7, 8, 6, 9] activation 0.05016526372523533
# radius: 3 atom list: [8, 15, 5, 0, 1, 2, 3, 4, 6] activation 0.05016154598591325
# radius: 3 atom list: [3, 4, 5, 6, 7, 8, 9] activation 0.050158850642867354
# radius: 3 atom list: [9, 13, 15, 16, 17, 18, 19, 20] activation 0.05015828665479569
# radius: 3 atom list: [2, 3, 4, 5, 6, 7, 8] activation 0.050156142308187886
# radius: 3 atom list: [0, 6, 1, 2, 3, 4, 7, 5] activation 0.05015536384056594
# radius: 3 atom list: [1, 2, 3, 4, 5, 6, 0] activation 0.05015158438298626
# radius: 3 atom list: [1, 2, 3, 4, 6, 5, 19, 22, 0] activation 0.050150541105349854
# radius: 3 atom list: [1, 2, 3, 4, 6, 0, 5, 24] activation 0.05014838147821148
# FP 26 has linear regression coefficient -0.0345567401401
# radius: 1 atom list: [13, 15, 16, 17, 18, 14] activation 0.02976808166175102
# radius: 1 atom list: [8, 9] activation 0.0297647332263545
# radius: 1 atom list: [14, 13] activation 0.02959940843702355
# radius: 1 atom list: [6, 9] activation 0.029476443470680392
# radius: 1 atom list: [0, 1] activation 0.02942436035670219
# radius: 1 atom list: [0, 1] activation 0.029414708426719987
# radius: 1 atom list: [9, 6] activation 0.02938070116688458
# radius: 1 atom list: [9, 8] activation 0.029369752321044135
# radius: 1 atom list: [5, 6] activation 0.02934069587703134
# radius: 1 atom list: [0, 1] activation 0.02932766446414055
# radius: 1 atom list: [4, 3] activation 0.02926625195757025
# FP 27 has linear regression coefficient 0.0454823299142
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.04214878145086412
# radius: 2 atom list: [19, 5, 2, 4, 6, 7, 8, 16, 18, 20] activation 0.0415464815239891
# radius: 2 atom list: [11, 2, 13, 3, 4, 6, 7, 5, 14, 15] activation 0.041209584045162034
# radius: 2 atom list: [15, 9, 3, 5, 6, 7, 12, 14, 16, 8] activation 0.04113599579595472
# radius: 2 atom list: [4, 16, 2, 17, 3, 5, 6, 7, 13, 15] activation 0.04103444337850793
# radius: 2 atom list: [8, 5, 12, 14, 2, 4, 6, 7, 13, 15] activation 0.04080793505571921
# radius: 2 atom list: [16, 10, 5, 7, 8, 9, 13, 15, 11, 17] activation 0.040786457460417404
# radius: 2 atom list: [17, 2, 18, 3, 5, 6, 7, 14, 16, 4] activation 0.040710128032307856
# radius: 2 atom list: [4, 6, 7, 13, 5, 14, 3, 8, 12, 1] activation 0.04036995750173401
# radius: 2 atom list: [16, 3, 5, 6, 13, 15, 2, 7, 17, 4] activation 0.04034765474524912
# radius: 2 atom list: [8, 9, 10, 11, 7] activation 0.04010627661556169
# FP 28 has linear regression coefficient 0.0117177058721
# radius: 0 atom list: [7] activation 0.021051218351482034
# radius: 0 atom list: [1] activation 0.02040506103953964
# radius: 0 atom list: [2] activation 0.020276048958243757
# radius: 1 atom list: [6, 8, 10, 9] activation 0.019790083489879304
# radius: 1 atom list: [4, 5, 2, 3] activation 0.019690984998490535
# radius: 1 atom list: [10, 20, 11, 2] activation 0.019655525408856116
# radius: 1 atom list: [0, 1, 2, 5] activation 0.019652355936255732
# radius: 1 atom list: [10, 11, 13, 12] activation 0.019619358346004572
# radius: 1 atom list: [23, 32, 33, 26] activation 0.019609014568225513
# radius: 1 atom list: [5, 3, 21, 4] activation 0.01960372438877581
# radius: 0 atom list: [0] activation 0.019597722055035908
# FP 29 has linear regression coefficient 0.0444452379226
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.04190176852593113
# radius: 2 atom list: [6, 9, 11, 7, 8, 3, 5, 13] activation 0.04109712898387294
# radius: 2 atom list: [4, 3, 8, 2, 5, 7, 9, 13] activation 0.04087444771535745
# radius: 2 atom list: [2, 5, 8, 10, 6, 4, 7, 3] activation 0.040735628137439264
# radius: 2 atom list: [10, 11, 8, 13, 12, 7, 9, 14] activation 0.04061669021584914
# radius: 2 atom list: [19, 20, 27, 16, 17, 18] activation 0.04044547050392962
# radius: 2 atom list: [7, 4, 5, 6, 8, 11] activation 0.04043980880981251
# radius: 2 atom list: [1, 2, 3, 5, 4, 7] activation 0.04043891973593219
# radius: 2 atom list: [16, 18, 19, 20, 15, 14] activation 0.04034866230043708
# radius: 2 atom list: [6, 12, 7, 3, 8, 9, 10, 11] activation 0.04026123054837467
# radius: 2 atom list: [8, 9, 10, 11, 7] activation 0.04024539948891183
# FP 30 has linear regression coefficient -0.0681865562185
# radius: 4 atom list: [1, 0, 3, 4, 2] activation 0.08771732762307295
# radius: 4 atom list: [3, 6, 10, 5, 0, 2, 4, 1] activation 0.08662117564797012
# radius: 4 atom list: [12, 13, 14, 15, 16, 17, 18, 11] activation 0.08640270135314496
# radius: 4 atom list: [12, 13, 14, 15, 16, 17, 18, 11] activation 0.0861842563460751
# radius: 4 atom list: [7, 10, 6, 11, 13, 9, 8, 12] activation 0.0858189754750836
# radius: 4 atom list: [6, 7, 9, 3, 8, 5, 4, 10] activation 0.08579559482537773
# radius: 4 atom list: [9, 10, 12, 7, 8, 11] activation 0.08543832948278783
# radius: 4 atom list: [1, 4, 0, 3, 5, 2] activation 0.08450421862977472
# radius: 4 atom list: [1, 4, 0, 3, 2, 5] activation 0.0844860725446972
# radius: 4 atom list: [3, 0, 2, 4, 1] activation 0.08442296068213899
# radius: 4 atom list: [3, 4, 7, 6, 8, 5] activation 0.0843906802288645
# FP 31 has linear regression coefficient 0.0292987847658
# radius: 1 atom list: [3, 4, 5, 11, 17] activation 0.030770747961751686
# radius: 1 atom list: [8, 12, 10, 11, 9] activation 0.029955237431418716
# radius: 1 atom list: [10, 9, 7, 8, 6] activation 0.02989206295200224
# radius: 1 atom list: [8, 9, 10, 11, 7] activation 0.029620299879213143
# radius: 1 atom list: [6, 8, 7, 9, 10] activation 0.029571981901012356
# radius: 1 atom list: [15, 10, 13, 12, 14] activation 0.02953935099005656
# radius: 1 atom list: [0, 1, 3, 4, 2] activation 0.029509519885684454
# radius: 1 atom list: [5, 4, 6, 8, 7] activation 0.02938714934036105
# radius: 1 atom list: [9, 7, 8, 10, 11] activation 0.029365526781277122
# radius: 1 atom list: [10, 12, 13, 14, 11] activation 0.029328424135695943
# radius: 1 atom list: [1, 2, 20, 3, 0] activation 0.029229741003053478
# FP 32 has linear regression coefficient -0.070243802056
# radius: 3 atom list: [1, 3, 0, 2, 4] activation 0.08559115322427846
# radius: 3 atom list: [12, 13, 14, 15, 16, 17, 18, 11] activation 0.08289698591099966
# radius: 3 atom list: [0, 3, 5, 2, 4, 1] activation 0.08231406633213682
# radius: 3 atom list: [3, 6, 10, 0, 5, 2, 1, 4] activation 0.08214701324256912
# radius: 3 atom list: [5, 7, 9, 6, 8, 4] activation 0.08171097459302877
# radius: 3 atom list: [1, 0, 3, 4, 2] activation 0.08167051370990555
# radius: 3 atom list: [9, 10, 12, 7, 8, 11] activation 0.08137868728565374
# radius: 3 atom list: [2, 5, 6, 1, 4, 3, 0] activation 0.08084143712745066
# radius: 3 atom list: [7, 8, 6, 11, 13, 9, 10, 12] activation 0.08083855122421171
# radius: 3 atom list: [16, 5, 0, 2, 1, 4, 3, 6] activation 0.08083855122421163
# radius: 3 atom list: [6, 7, 9, 3, 8, 5, 4, 10] activation 0.080779478496207
# FP 33 has linear regression coefficient -0.0636854241235
# radius: 4 atom list: [1, 0, 3, 4, 2] activation 0.07085588748766014
# radius: 4 atom list: [9, 10, 12, 6, 7, 8, 11] activation 0.06975410591788314
# radius: 4 atom list: [4, 0, 1, 2, 3] activation 0.06973083710885723
# radius: 4 atom list: [3, 6, 7, 9, 10, 0, 5, 2, 1, 4] activation 0.06967392221136677
# radius: 4 atom list: [0, 3, 5, 2, 1, 4] activation 0.06959974228453264
# radius: 4 atom list: [1, 4, 0, 3, 5, 2] activation 0.06957669353985681
# radius: 4 atom list: [1, 4, 0, 3, 2, 5, 6] activation 0.06946736317713209
# radius: 4 atom list: [0, 3, 1, 2, 4] activation 0.0694657319596404
# radius: 4 atom list: [5, 3, 0, 4, 6, 1, 2] activation 0.06941462279482148
# radius: 4 atom list: [2, 5, 6, 1, 4, 3, 0] activation 0.06939826404139547
# radius: 4 atom list: [2, 3, 4, 7, 6, 8, 5] activation 0.06937025274296224
# FP 34 has linear regression coefficient 0.060980806256
# radius: 3 atom list: [2, 15, 4, 1, 3, 0, 5, 13, 16, 17, 19, 20] activation 0.05991063523438734
# radius: 3 atom list: [7, 11, 10, 12, 16, 4, 8, 17, 9, 6, 13, 15] activation 0.059870016442385904
# radius: 3 atom list: [9, 0, 11, 15, 1, 3, 4, 10, 12, 14, 2, 5] activation 0.05980929854109542
# radius: 3 atom list: [1, 3, 5, 6, 7, 0, 13, 16, 4, 2, 15, 17] activation 0.05978350738203306
# radius: 3 atom list: [10, 11, 12, 13, 14, 15, 16] activation 0.05977964690110219
# radius: 3 atom list: [8, 2, 3, 4, 5, 6, 7, 11] activation 0.05974698779073925
# radius: 3 atom list: [1, 3, 5, 6, 8, 2, 4, 16, 18, 12, 14, 7, 15, 17] activation 0.059742158379629436
# radius: 3 atom list: [13, 4, 6, 7, 17, 16, 18, 8, 9, 10, 14, 15, 12, 5, 11] activation 0.059736174981347395
# radius: 3 atom list: [0, 1, 2, 3, 4, 5, 6] activation 0.05973110046989354
# radius: 3 atom list: [14, 10, 3, 5, 7, 8, 2, 6, 4, 9, 19, 17, 18, 16] activation 0.05973007778110389
# radius: 3 atom list: [3, 5, 6, 7, 12, 15, 11, 9, 13, 8, 10, 14] activation 0.05971341664107662
# FP 35 has linear regression coefficient 0.0531419323451
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.04350341307349414
# radius: 2 atom list: [6, 9, 11, 7, 8, 3, 5, 13] activation 0.04337906913442465
# radius: 2 atom list: [4, 3, 8, 2, 5, 7, 9, 13] activation 0.04289892701631521
# radius: 2 atom list: [2, 5, 8, 10, 6, 4, 7, 3] activation 0.042731622518448316
# radius: 2 atom list: [10, 11, 8, 13, 12, 7, 9, 14] activation 0.04259862396515845
# radius: 2 atom list: [19, 20, 27, 16, 17, 18] activation 0.04230715252537105
# radius: 2 atom list: [7, 4, 5, 6, 8, 11] activation 0.04223262219454417
# radius: 2 atom list: [1, 2, 3, 5, 4, 7] activation 0.04222962467470544
# radius: 2 atom list: [6, 12, 7, 3, 8, 9, 10, 11] activation 0.04219897422080734
# radius: 2 atom list: [6, 2, 7, 8, 14, 9, 10] activation 0.04219855440400378
# radius: 2 atom list: [16, 18, 19, 20, 15, 14] activation 0.042096920517820324
# FP 36 has linear regression coefficient 0.083833327673
# radius: 4 atom list: [4, 5, 6, 7, 9, 10, 11, 12, 15, 16, 17, 18, 19, 8, 14] activation 0.16948691033198168
# radius: 4 atom list: [5, 10, 1, 2, 3, 4, 6, 7, 8, 11, 12, 13, 14, 15, 9] activation 0.16919120262378726
# radius: 4 atom list: [14, 15, 16, 10, 7, 11, 3, 4, 5, 6, 8, 9, 12, 13] activation 0.16603656111571113
# radius: 4 atom list: [4, 9, 11, 1, 2, 3, 5, 7, 8, 0, 6, 10] activation 0.16545127753636382
# radius: 4 atom list: [18, 23, 27, 16, 17, 21, 19, 20, 22, 24, 25, 26] activation 0.16545127753636374
# radius: 4 atom list: [8, 4, 9, 13, 3, 5, 1, 6, 7, 10, 11, 12] activation 0.16543107520626618
# radius: 4 atom list: [10, 4, 9, 11, 6, 2, 1, 0, 3, 5, 7, 8] activation 0.16442106740699855
# radius: 4 atom list: [16, 17, 19, 20, 12, 18, 21, 11, 15, 10, 13, 14] activation 0.16431588098049046
# radius: 4 atom list: [10, 13, 12, 6, 7, 8, 9, 11, 14, 15, 16, 17, 18] activation 0.16259644118384659
# radius: 4 atom list: [5, 6, 1, 2, 3, 0, 7, 10, 14, 4, 8, 9, 11, 12, 13] activation 0.16161491351066035
# radius: 4 atom list: [0, 6, 8, 12, 14, 16, 18, 20, 2, 1, 3, 4, 5, 7, 9, 11, 13, 15, 17, 19] activation 0.15923629593383132
# FP 37 has linear regression coefficient -0.0815410189956
# radius: 4 atom list: [1, 0, 3, 4, 2] activation 0.16048375344839882
# radius: 4 atom list: [1, 0, 3, 4, 2] activation 0.1597530708166684
# radius: 4 atom list: [3, 6, 10, 5, 0, 2, 4, 1] activation 0.15408853577083106
# radius: 4 atom list: [12, 13, 14, 15, 16, 17, 18, 11] activation 0.1504633188001129
# radius: 4 atom list: [7, 10, 6, 11, 13, 9, 8, 12] activation 0.15031566504997004
# radius: 4 atom list: [6, 7, 9, 3, 8, 5, 4, 10] activation 0.15020861735811397
# radius: 4 atom list: [12, 13, 14, 15, 16, 17, 18, 11] activation 0.14947696873259814
# radius: 4 atom list: [9, 10, 12, 7, 8, 11] activation 0.14859890000005302
# radius: 4 atom list: [1, 4, 0, 3, 5, 2] activation 0.14456234131574475
# radius: 4 atom list: [1, 4, 0, 3, 2, 5] activation 0.1444803496205937
# radius: 4 atom list: [3, 0, 2, 4, 1] activation 0.14419784062043337
# FP 38 has linear regression coefficient -0.052200534436
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.04559504008578385
# radius: 2 atom list: [0, 2, 1, 3, 4] activation 0.04536851181583643
# radius: 2 atom list: [2, 1, 4, 3, 0] activation 0.04531306866248966
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.04520075219442636
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.04519994750778442
# radius: 2 atom list: [3, 1, 4, 0, 2] activation 0.04466434160428692
# radius: 2 atom list: [1, 0, 2, 4, 3] activation 0.04461559409884495
# radius: 2 atom list: [4, 0, 2, 3, 1] activation 0.04460808435120479
# radius: 2 atom list: [5, 3, 0, 2, 1, 4] activation 0.044541279256152
# radius: 2 atom list: [4, 1, 3] activation 0.0444156536916346
# radius: 2 atom list: [14, 16, 9, 15, 10, 11] activation 0.04421303095590709
# FP 39 has linear regression coefficient -0.0300051546573
# radius: 0 atom list: [9] activation 0.02778436140908203
# radius: 0 atom list: [6] activation 0.026220066473245495
# radius: 0 atom list: [0] activation 0.02616089388830774
# radius: 0 atom list: [0] activation 0.026130225508295506
# radius: 1 atom list: [9, 10, 11] activation 0.026033691474252437
# radius: 1 atom list: [12, 13, 14] activation 0.02584708512426708
# radius: 0 atom list: [0] activation 0.02569643953247748
# radius: 1 atom list: [5, 6, 7] activation 0.025630726137729022
# radius: 1 atom list: [2, 0, 1] activation 0.025578774469886482
# radius: 1 atom list: [5, 6, 7] activation 0.02555642605486306
# radius: 1 atom list: [1, 4, 3] activation 0.025504810813665717
# FP 40 has linear regression coefficient -0.0563752465087
# radius: 1 atom list: [13, 15, 16, 17, 18, 14] activation 0.04687280064093085
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.04637297279991273
# radius: 4 atom list: [1, 3, 4, 5, 7, 8, 9, 6] activation 0.04595414250688878
# radius: 4 atom list: [5, 6, 7, 1, 0, 2, 3, 4] activation 0.04593870327962981
# radius: 4 atom list: [4, 6, 7, 9, 10, 5, 1, 0, 2, 3] activation 0.045909415731351245
# radius: 4 atom list: [2, 4, 11, 9, 12, 13, 14, 5, 7, 8, 10] activation 0.045885791147683215
# radius: 4 atom list: [1, 5, 8, 4, 0, 2, 3, 6, 7] activation 0.04588510112393415
# radius: 4 atom list: [7, 5, 6, 1, 4, 0, 2, 3] activation 0.04586450640142915
# radius: 2 atom list: [1, 5, 4, 0, 2, 3] activation 0.045851638008198206
# radius: 4 atom list: [1, 0, 2, 3, 6, 4, 5] activation 0.04585001165017501
# radius: 4 atom list: [12, 15, 16, 17, 14, 19, 10, 11, 13, 18] activation 0.04581901859759215
# FP 41 has linear regression coefficient -0.0663897879875
# radius: 3 atom list: [0, 3, 5, 2, 4, 1] activation 0.07617033757606785
# radius: 3 atom list: [12, 13, 14, 15, 16, 17, 18, 11] activation 0.07595944923530812
# radius: 3 atom list: [5, 7, 9, 6, 8, 4] activation 0.07570583388005331
# radius: 3 atom list: [1, 0, 3, 4, 2] activation 0.07567480056644373
# radius: 3 atom list: [3, 4, 0, 2, 1] activation 0.07519102280422482
# radius: 3 atom list: [0, 2, 1, 3, 4] activation 0.07497976156894631
# radius: 3 atom list: [2, 1, 4, 3, 0] activation 0.07492472810620456
# radius: 3 atom list: [9, 10, 12, 8, 11] activation 0.07473874633919973
# radius: 3 atom list: [12, 13, 14, 15, 16, 17, 18] activation 0.07453409692750006
# radius: 3 atom list: [1, 5, 4, 0, 2, 3] activation 0.07449689820474636
# radius: 3 atom list: [2, 1, 4, 11, 0, 3] activation 0.07448607649981476
# FP 42 has linear regression coefficient -0.0328491768258
# radius: 1 atom list: [3, 0, 2, 1] activation 0.029423407420615146
# radius: 1 atom list: [8, 9] activation 0.029249642420145727
# radius: 1 atom list: [13, 15, 16, 17, 18, 14] activation 0.029197679603348594
# radius: 1 atom list: [14, 13] activation 0.029183451559456456
# radius: 1 atom list: [4, 3] activation 0.028999730634659337
# radius: 1 atom list: [0, 1] activation 0.028988184316521493
# radius: 1 atom list: [5, 6] activation 0.028954561196100303
# radius: 1 atom list: [1, 0] activation 0.028888515320767073
# radius: 1 atom list: [0, 1] activation 0.028878572949771482
# radius: 1 atom list: [6, 9] activation 0.028849958886534084
# radius: 1 atom list: [9, 6] activation 0.028845631333595075
# FP 43 has linear regression coefficient -0.0489970425867
# radius: 1 atom list: [13, 15, 16, 17, 18, 14] activation 0.04561838767952953
# radius: 1 atom list: [8, 9] activation 0.04330952499701909
# radius: 1 atom list: [14, 13] activation 0.04263997561049765
# radius: 1 atom list: [6, 9] activation 0.042370227383235946
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.04209597272749489
# radius: 2 atom list: [1, 5, 4, 0, 2, 3] activation 0.041654431847088856
# radius: 2 atom list: [1, 5, 4, 0, 2, 3] activation 0.041573970873826326
# radius: 2 atom list: [5, 3, 0, 2, 1, 4] activation 0.04139793560876907
# radius: 1 atom list: [9, 6] activation 0.04137176019100259
# radius: 1 atom list: [0, 1] activation 0.04121446366546742
# radius: 2 atom list: [9, 10, 12, 8, 11] activation 0.041163243567079184
# FP 44 has linear regression coefficient -0.0610694088037
# radius: 3 atom list: [1, 3, 0, 2, 4] activation 0.0729770981230456
# radius: 3 atom list: [3, 6, 10, 0, 5, 2, 1, 4] activation 0.07072608830927427
# radius: 3 atom list: [9, 10, 12, 7, 8, 11] activation 0.07038084053650276
# radius: 3 atom list: [2, 5, 6, 1, 4, 3, 0] activation 0.07015258630619285
# radius: 3 atom list: [7, 8, 6, 11, 13, 9, 10, 12] activation 0.0699339769775989
# radius: 3 atom list: [16, 5, 0, 2, 1, 4, 3, 6] activation 0.06993397697759887
# radius: 3 atom list: [6, 7, 9, 3, 8, 5, 4, 10] activation 0.06989795287326178
# radius: 3 atom list: [4, 0, 1, 2, 3] activation 0.06983185961297682
# radius: 3 atom list: [1, 4, 0, 3, 5, 2] activation 0.06959945607227963
# radius: 3 atom list: [1, 4, 0, 3, 2, 5] activation 0.06956901036550009
# radius: 3 atom list: [0, 3, 1, 2, 4] activation 0.06946674471342539
# FP 45 has linear regression coefficient 0.053610815953
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.04926985129682855
# radius: 2 atom list: [19, 5, 2, 4, 6, 7, 8, 16, 18, 20] activation 0.047151334776222166
# radius: 2 atom list: [11, 2, 13, 3, 4, 6, 7, 5, 14, 15] activation 0.04661709823280267
# radius: 2 atom list: [15, 9, 3, 5, 6, 7, 12, 14, 16, 8] activation 0.04650101677546939
# radius: 2 atom list: [4, 16, 2, 17, 3, 5, 6, 7, 13, 15] activation 0.04634502385805638
# radius: 2 atom list: [8, 5, 12, 14, 2, 4, 6, 7, 13, 15] activation 0.04599150949498032
# radius: 2 atom list: [16, 10, 5, 7, 8, 9, 13, 15, 11, 17] activation 0.04595615490890285
# radius: 2 atom list: [6, 9, 11, 7, 8, 3, 5, 13] activation 0.045886032912021986
# radius: 2 atom list: [8, 9, 10, 11, 7] activation 0.04585881583999521
# radius: 2 atom list: [17, 2, 18, 3, 5, 6, 7, 14, 16, 4] activation 0.045837782075464156
# radius: 2 atom list: [4, 3, 8, 2, 5, 7, 9, 13] activation 0.045585000789878614
# FP 46 has linear regression coefficient -0.0505720753373
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.04508959823519077
# radius: 2 atom list: [3, 4, 0, 2, 1] activation 0.0448239806105627
# radius: 2 atom list: [0, 2, 1, 3, 4] activation 0.04461977785963227
# radius: 2 atom list: [2, 1, 4, 3, 0] activation 0.04457701743175387
# radius: 2 atom list: [1, 0, 3, 4, 2] activation 0.04445078868742134
# radius: 2 atom list: [5, 3, 0, 2, 1, 4] activation 0.0443803862788628
# radius: 2 atom list: [1, 5, 4, 0, 2, 3] activation 0.04435511289518074
# radius: 2 atom list: [1, 5, 4, 0, 2, 3] activation 0.04428968497608033
# radius: 2 atom list: [3, 1, 4, 0, 2] activation 0.04398365224406065
# radius: 2 atom list: [5, 7, 9, 6, 8, 4] activation 0.043971410867491366
# radius: 2 atom list: [1, 0, 2, 4, 3] activation 0.04393858192846713
# FP 47 has linear regression coefficient 0.000821820606705
# radius: 4 atom list: [0, 5, 1, 4, 6, 11, 2, 3, 7, 8, 9, 10] activation 0.017476365103158913
# radius: 4 atom list: [0, 4, 5, 10, 2, 7, 8, 11, 13, 1, 6, 9, 12, 3] activation 0.017475699476601346
# radius: 4 atom list: [4, 3, 11, 12, 5, 6, 7, 1, 8, 9, 10] activation 0.01747553143229054
# radius: 4 atom list: [1, 5, 7, 8, 0, 6, 9, 10, 3, 4, 2] activation 0.017473911463905856
# radius: 4 atom list: [5, 8, 10, 11, 12, 4, 6, 7, 13, 14, 9] activation 0.01747291562495866
# radius: 4 atom list: [9, 12, 13, 1, 3, 4, 5, 6, 7, 10, 11, 2, 0, 8] activation 0.017472325869777063
# radius: 4 atom list: [0, 5, 1, 4, 6, 11, 2, 3, 7, 8, 9, 10] activation 0.01747193421496829
# radius: 4 atom list: [8, 14, 16, 3, 10, 0, 4, 5, 1, 6, 9, 15, 2, 7] activation 0.017471826219680738
# radius: 4 atom list: [5, 6, 8, 14, 15, 4, 7, 1, 0, 2, 3] activation 0.01747137276860092
# radius: 4 atom list: [4, 5, 11, 16, 0, 2, 1, 3, 10, 12, 13, 14, 15] activation 0.017471358696600384
# radius: 4 atom list: [4, 5, 6, 7, 1, 3, 8, 0, 2, 9] activation 0.017470862634645503
# FP 48 has linear regression coefficient 0.0375473950992
# radius: 2 atom list: [19, 5, 2, 4, 6, 7, 8, 16, 18, 20] activation 0.033382497670657485
# radius: 2 atom list: [11, 2, 13, 3, 4, 6, 7, 5, 14, 15] activation 0.03326103779923442
# radius: 2 atom list: [15, 9, 3, 5, 6, 7, 12, 14, 16, 8] activation 0.03323464511047115
# radius: 2 atom list: [4, 16, 2, 17, 3, 5, 6, 7, 13, 15] activation 0.03319982565121788
# radius: 2 atom list: [8, 5, 12, 14, 2, 4, 6, 7, 13, 15] activation 0.03310813776394294
# radius: 2 atom list: [16, 10, 5, 7, 8, 9, 13, 15, 11, 17] activation 0.03310076297680289
# radius: 2 atom list: [17, 2, 18, 3, 5, 6, 7, 14, 16, 4] activation 0.03307165680677762
# radius: 2 atom list: [4, 6, 7, 13, 5, 14, 3, 8, 12, 1] activation 0.03293312026437591
# radius: 2 atom list: [16, 3, 5, 6, 13, 15, 2, 7, 17, 4] activation 0.032924923000722334
# radius: 2 atom list: [3, 8, 10, 7, 12, 4, 5, 6, 11, 13] activation 0.03274224204936087
# radius: 2 atom list: [2, 4, 9, 13, 0, 1, 5, 7, 8, 6] activation 0.03274205528056148
# FP 49 has linear regression coefficient 0.0432181585342
# radius: 2 atom list: [19, 5, 2, 4, 6, 7, 8, 16, 18, 20] activation 0.03414045798484961
# radius: 2 atom list: [6, 0, 2, 3, 4, 5, 11, 7, 1] activation 0.034006703161875436
# radius: 2 atom list: [11, 2, 13, 3, 4, 6, 7, 5, 14, 15] activation 0.03400399389535744
# radius: 2 atom list: [15, 9, 3, 5, 6, 7, 12, 14, 16, 8] activation 0.033973348809610594
# radius: 2 atom list: [4, 16, 2, 17, 3, 5, 6, 7, 13, 15] activation 0.0339325395037279
# radius: 2 atom list: [8, 5, 12, 14, 2, 4, 6, 7, 13, 15] activation 0.033833807029474014
# radius: 2 atom list: [16, 10, 5, 7, 8, 9, 13, 15, 11, 17] activation 0.033824309169021745
# radius: 2 atom list: [17, 2, 18, 3, 5, 6, 7, 14, 16, 4] activation 0.03379092357841867
# radius: 2 atom list: [4, 6, 7, 13, 5, 14, 3, 8, 12, 1] activation 0.03363921027142654
# radius: 2 atom list: [16, 3, 5, 6, 13, 15, 2, 7, 17, 4] activation 0.033628887158166886
# radius: 2 atom list: [1, 2, 3, 5, 4, 7] activation 0.03362058909983044

# %% [markdown]
# ### Compare error for SMILES with duplicates and without

# %%
task_params = {'target_name' : 'logP',
               'data_file'   : 'logP_wo_parameters'}

num_epochs = 1
batch_size = 100
normalize = 1
dropout = 0
activation = relu
params = {'fp_length': 20,
            'fp_depth': 3,
            'init_scale':np.exp(-4),
            'l2_penalty':np.exp(-2),
            'conv_width':10}

conv_layer_sizes = [params['conv_width']] * params['fp_depth']
conv_arch_params = {'num_hidden_features' : conv_layer_sizes,
                    'fp_length' : params['fp_length'],
                    'normalize' : normalize,
                    'return_atom_activations':False}

all_radii = range(params['fp_depth'] + 1)

# Plotting parameters
num_figs_per_fp = 11
figsize = (100, 100)
highlight_color = (30.0/255.0, 100.0/255.0, 255.0/255.0)  # A nice light blue.

# %%
dub_smiles, dub_targets, uniq_smiles, uniq_targets =  get_averaged_and_unique_smiles(task_params['data_file']+'.csv')
trained_network_weights = train_neural_fingerprint()
# Out:
# Loading data...
# Regression on 8838 training points.
# --------------------------------------------------------------------------------
# Mean predictor
#
# Performance (RMSE) on logP:
# Train: 1.8146042407352028
# Test:  1.8141849992522239
# Dub: 2.1832152392353295
# Unique:  1.8014880653973313
#
# Performance (R2) on logP:
# Train: 0.0
# Test:  -0.0002990500750039704
# Dub: -0.009233034859763123
# Unique:  -7.835254551791238e-05
# --------------------------------------------------------------------------------
# Task params {'fp_length': 20, 'l2_penalty': 0.1353352832366127, 'fp_depth': 3, 'conv_width': 10, 'init_scale': 0.01831563888873418}
# Convnet fingerprints with neural net
# Total number of weights in the network: 9891
# max of weights 0.06962983567500523
# Iteration 0 loss 1.0063718238912063 train RMSE 1.8203069398792293 Train R2 0 : -0.006295212875175871 Validation RMSE 0 : 1.803738578845338 Validation R2 0 : -0.019677344906125382 Dub RMSE 0 : 2.15276806272327
# Unique RMSE 0 : 1.8101555237011158
# Dub R2 0 : 0.01872025805950328
# Unique R2 0 : -0.009724810930348493
# max of weights 0.06291737273251675
# Iteration 10 loss 0.9892761827724832 train RMSE 1.8047953920010138 Train R2 10 : 0.010781786610853272 Validation RMSE 10 : 1.7828520832239105 Validation R2 10 : 0.003800756530195848 Dub RMSE 10 : 2.154682704834169
# Unique RMSE 10 : 1.79327250062894
# Dub R2 10 : 0.01697400862541154
# Unique R2 10 : 0.009022427974837988
# max of weights 0.0643746022650365
# Iteration 20 loss 0.9936623850900014 train RMSE 1.8087962511592037 Train R2 20 : 0.006391139899777132 Validation RMSE 20 : 1.789590513843066 Validation R2 20 : -0.003743902238360519 Dub RMSE 20 : 2.149508402230029
# Unique RMSE 20 : 1.7979637746358315
# Dub R2 20 : 0.021689660308425784
# Unique R2 20 : 0.003830770553743479
# max of weights 0.07494494099394199
# Iteration 30 loss 0.9841626809838835 train RMSE 1.8001251939037475 Train R2 30 : 0.015894684995585995 Validation RMSE 30 : 1.7765940574037655 Validation R2 30 : 0.01078204138052441 Dub RMSE 30 : 2.154557874739599
# Unique RMSE 30 : 1.788151413193206
# Dub R2 30 : 0.01708790722644138
# Unique R2 30 : 0.014674258987262823
# max of weights 0.08647151325076202
# Iteration 40 loss 0.9854070026945189 train RMSE 1.8012517129326346 Train R2 40 : 0.014662592635711569 Validation RMSE 40 : 1.7741640619686612 Validation R2 40 : 0.013486262053234332 Dub RMSE 40 : 2.166318536323498
# Unique RMSE 40 : 1.788283311046167
# Dub R2 40 : 0.006328163014144406
# Unique R2 40 : 0.014528894179900886
# max of weights 0.09854355357832215
# Iteration 50 loss 0.9762453915404032 train RMSE 1.7928375006353292 Train R2 50 : 0.023846732216699196 Validation RMSE 50 : 1.767200929986074 Validation R2 50 : 0.02121468531065762 Dub RMSE 50 : 2.1513492152737994
# Unique RMSE 50 : 1.7802789965343107
# Dub R2 50 : 0.020013316488610156
# Unique R2 50 : 0.02333104239229089
# max of weights 0.11219241424736431
# Iteration 60 loss 0.9710062362402663 train RMSE 1.78798701081244 Train R2 60 : 0.02912151757992032 Validation RMSE 60 : 1.7665676440696825 Validation R2 60 : 0.02191606553403047 Dub RMSE 60 : 2.12963793599751
# Unique RMSE 60 : 1.776554106632763
# Dub R2 60 : 0.039693434012920026
# Unique R2 60 : 0.02741374904072824
# max of weights 0.12542339997309382
# Iteration 70 loss 0.956201059040201 train RMSE 1.7742570702556275 Train R2 70 : 0.0439750068738447 Validation RMSE 70 : 1.7504013233226385 Validation R2 70 : 0.039735557138683375 Dub RMSE 70 : 2.1191449699601757
# Unique RMSE 70 : 1.762203704557399
# Dub R2 70 : 0.04913319846799791
# Unique R2 70 : 0.04306273347513434
# max of weights 0.14043623011911144
# Iteration 80 loss 0.9580864791748905 train RMSE 1.7759463053494677 Train R2 80 : 0.04215371527240197 Validation RMSE 80 : 1.743513019682277 Validation R2 80 : 0.047278487849775175 Dub RMSE 80 : 2.141840363337796
# Unique RMSE 80 : 1.7614806060404837
# Dub R2 80 : 0.0286571521399841
# Unique R2 80 : 0.04384790711631392
#
# Performance (RMSE) on logP:
# Train: 1.743346296981253
# Test:  1.739897882448295
# Dub: 2.087245508777991
# Unique:  1.730342388322963
#
# Performance (R2) on logP:
# Train: 0.07699621017507619
# Test:  0.07994406273254906
# Dub: 0.07754451002149954
# Unique:  0.07735349323671858
# --------------------------------------------------------------------------------
